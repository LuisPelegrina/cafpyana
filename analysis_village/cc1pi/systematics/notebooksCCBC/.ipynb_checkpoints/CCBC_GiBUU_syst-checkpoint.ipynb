# %%
# %load_ext autoreload
# %autoreload

# %%
import pandas as pd
import numpy as np
from os import path, makedirs
from datetime import datetime
from functools import partial
import gc

# local imports
import sys
sys.path.append('../../../')
from pyanalib.split_df_helpers import *
from analysis_village.cc1pi.systematics.final_variable_configs import VariableConfig
from analysis_village.cc1pi.systematics.utils import *
from analysis_village.cc1pi.systematics.constants import *
from pyanalib.covariance import *
from analysis_village.cc1pi.DataFrameUtils.DFLoading import *
from analysis_village.cc1pi.Constants import CTE as CTE
from analysis_village.cc1pi.CutMasks.MaskUtils import *
from analysis_village.cc1pi.CutMasks.CutMasks import *

from makedf.mcstat import get_MCstat_unc

from analysis_village.cc1pi.var_configs import *

# turn off PerformanceWarning 
# triggered by mismatched column levels
import warnings
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning)
# Out:
# mc_tot_pot: 5.947e+18
# Integrated flux: 9.604e+10
# Integrated flux: 1.615e+02
# # of targets:  1.4154995096228214e+30
# 96036210000.0
# xsec unit:  7.356229506477044e-42
# Importing cafpyana utils...

# %%
save_result = True
save_fig = save_result
save_fig_dir = "/exp/sbnd/data/users/lpelegri/Graphs/syst/detector"

if save_fig:
    if not path.exists(save_fig_dir):
        makedirs(save_fig_dir)
    print("saving plots in ", save_fig_dir)
# Out:
# saving plots in  /exp/sbnd/data/users/lpelegri/Graphs/syst/detector

# %% [markdown]
# # Load df

# %%
pot_weight_col = ('slc', 'wgt', '', '', '', '')

#Load data
keys2load = ["cc1pi", "hdr", "histpotdf"] ## keys from the configuration file
data_df = load_df("/exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_data_rollingdev_bnblight.df", keys2load, 100)
data_evt_df = data_df['cc1pi']
data_hdr_df = data_df['hdr']

# BNB data
# data_tot_pot = data_hdr_df['TOR875'].sum()
data_tot_pot = data_hdr_df['pot'].sum()
print("data_tot_pot: %.3e" %(data_tot_pot))
pot_str = f"{data_tot_pot} $\\times 10^{18}$"
data_evt_df[pot_weight_col] = np.ones(len(data_evt_df))
data_gates = data_hdr_df.nbnbinfo.sum()
print("data tot gates : %.3e" %(data_gates))
# Out:
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_data_rollingdev_bnblight.df
# Keys: ['/cc1pi_0', '/hdr_0', '/histpotdf_0', '/pot_0', '/split']
# n_split: 1
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_data_rollingdev_bnblight.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# data_tot_pot: 5.948e+18
# data tot gates : 1.251e+06

# %%
def proton_BDT_sideband_mask(df, group_levels):
    BDT_proton_df = df[(is_MIP_candidate_mask(df)) & (df.pfp.trk.bdt_proton_score < -2)]
    
    # Count how many pfps per slice
    candidate_counts = BDT_proton_df.groupby(level=group_levels).size()
 
    # Get only slices with at least 2 pfps
    valid_slices = candidate_counts[candidate_counts == 1].index

    # Apply the mask to original DataFrame
    final_mask = pd.Series(df.index.droplevel('rec.slc.reco.pfp..index').isin(valid_slices), index=df.index)

    return final_mask

# %%
#Load CV dataframe
keys2load = ["cc1pi", "hdr", "histpotdf", "nudf"] ## keys from the configuration file
mc_bnb_df = load_df("/exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_5e18_CV_grid_new_cc1pi.df", keys2load, 100)
mc_bnb_evt_df = mc_bnb_df['cc1pi']
mc_bnb_nu_df = mc_bnb_df['nudf']
mc_bnb_hdr_df = mc_bnb_df['hdr']

# BNB MC
mc_tot_pot = mc_bnb_hdr_df['pot'].sum()
print("mc_tot_pot: %.3e" %(mc_tot_pot))
mc_pot_scale = data_tot_pot / mc_tot_pot
print("mc_pot_scale: %.3e" %(mc_pot_scale))
mc_bnb_evt_df[pot_weight_col] = mc_pot_scale * np.ones(len(mc_bnb_evt_df))

mc_evt_df = perform_truth_matching(mc_bnb_evt_df, mc_bnb_nu_df)
# Out:
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_5e18_CV_grid_new_cc1pi.df
# Keys: ['/cc1pi_0', '/hdr_0', '/histgenevtdf_0', '/histpotdf_0', '/nudf_0', '/pot_0', '/split']
# n_split: 1
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_5e18_CV_grid_new_cc1pi.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# mc_tot_pot: 1.355e+19
# mc_pot_scale: 4.388e-01

# %%
#Load GiBUU dataframe
pot_weight_col = ('slc', 'wgt', '', '', '', '')

keys2load = ["cc1pi", "hdr", "histpotdf", "nudf"] ## keys from the configuration file
mc_GiBUU_df = load_df("/exp/sbnd/data/users/lpelegri/cafpyana_data/mc_GIBUU_gen1.df", keys2load, 100, filter_df = False)
#mc_GiBUU_df = load_df("/exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_5e18_CV_grid_new_cc1pi.df", keys2load, 100, filter_df = False)
#mc_GiBUU_df = load_df("/exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_5e18_CV_grid_new_cc1pi.df", keys2load, 100, filter_df = False)

mc_GiBUU_evt_df = mc_GiBUU_df['cc1pi']
mc_GiBUU_nu_df = mc_GiBUU_df['nudf']
mc_GiBUU_hdr_df = mc_GiBUU_df['hdr']

#Add weight column
mc_GiBUU_tot_pot = mc_GiBUU_hdr_df['pot'].sum()
print("mc_tot_pot: %.3e" %(mc_GiBUU_tot_pot))
mc_pot_scale = data_tot_pot / mc_GiBUU_tot_pot
print("mc_pot_scale: %.3e" %(mc_pot_scale))
mc_GiBUU_evt_df[pot_weight_col] = mc_pot_scale * np.ones(len(mc_GiBUU_evt_df))

#Do truth matchign
mc_GiBUU_evt_df = perform_truth_matching(mc_GiBUU_evt_df, mc_GiBUU_nu_df)
# Out:
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/mc_GIBUU_gen1.df
# Keys: ['/cc1pi_0', '/hdr_0', '/histpotdf_0', '/nudf_0', '/pot_0', '/split']
# n_split: 1
# dataframes
# loaded!
# mc_tot_pot: 1.766e+19
# mc_pot_scale: 3.368e-01

# %% [markdown]
# # Prepare maks

# %%
'''
def proton_BDT_sideband_mask(df, group_levels):
    BDT_proton_df = df[(is_MIP_candidate_mask(df)) & (df.pfp.trk.bdt_proton_score < -2)]
    
    # Count how many pfps per slice
    candidate_counts = BDT_proton_df.groupby(level=group_levels).size()
 
    # Get only slices with at least 2 pfps
    valid_slices = candidate_counts[candidate_counts == 1].index

    # Apply the mask to original DataFrame
    final_mask = pd.Series(df.index.droplevel('rec.slc.reco.pfp..index').isin(valid_slices), index=df.index)

    return final_mask
'''
# Out:
# "\ndef proton_BDT_sideband_mask(df, group_levels):\n    BDT_proton_df = df[(is_MIP_candidate_mask(df)) & (df.pfp.trk.bdt_proton_score < -2)]\n    \n    # Count how many pfps per slice\n    candidate_counts = BDT_proton_df.groupby(level=group_levels).size()\n \n    # Get only slices with at least 2 pfps\n    valid_slices = candidate_counts[candidate_counts == 1].index\n\n    # Apply the mask to original DataFrame\n    final_mask = pd.Series(df.index.droplevel('rec.slc.reco.pfp..index').isin(valid_slices), index=df.index)\n\n    return final_mask\n"

# %%
def shower_cut_mask(df, group_levels):
    is_pandora_primary_mask = (df.pfp.parent_is_primary == True)
    is_shower_mask = (df.pfp.trackScore >= 0) & (df.pfp.trackScore < CTE.max_shower_track_score)
    energy_mask = (df.pfp.shw.bestplane_energy > 0.200) &  (df.pfp.shw.bestplane_energy < 0.500)
    shower_df = df[is_pandora_primary_mask & is_shower_mask & energy_mask] 
        
    # Count how many pfps per slice
    shower_counts = shower_df.groupby(level=group_levels).size()
    
    # Get only slices with at least 2 pfps
    non_valid_slices = shower_counts[(shower_counts > 0)].index

    # Apply the mask to original DataFrame
    final_mask = pd.Series(~df.index.droplevel('rec.slc.reco.pfp..index').isin(non_valid_slices), index=df.index)
   
    return final_mask

# %%
'''
group_levels = ['__ntuple', 'entry', 'rec.slc..index']
def build_event_cumulative_masks(evt_df, sideband = "shower"):
    # Define which BDT mask to use
    
    cut_sequence = [
        ("cosmic",      evt_df.slc.cut.obvious_cosmic),
        ("t0",          evt_df.slc.cut.t0),
        ("FV",          evt_df.slc.cut.inside_FV),
        ("nu_score",    evt_df.slc.nu_score > CTE.min_nu_score),
        ("track",       evt_df.slc.cut.track),
        ("chi2",        evt_df.slc.cut.MIP_candidates),
        ("shower",      evt_df.slc.cut.shower),
        ("angle",       evt_df.slc.cut.angle),
        ("proton_BDT",  evt_df.slc.cut.proton_BDT),
        ("containment", evt_df.slc.cut.containment),
        ("michel",      evt_df.slc.cut.michel),
        ("extra_pion",  evt_df.slc.cut.extra_pion),
        #("bad_tracks",  evt_df.slc.cut_var.n_bad_trks == 0),
        ("energy",      evt_df.slc.cut.energy),
    ]
    
    if sideband == "shower": 
        cut_sequence = [
            ("cosmic",      evt_df.slc.cut.obvious_cosmic),
            ("t0",          evt_df.slc.cut.t0),
            ("FV",          evt_df.slc.cut.inside_FV),
            ("nu_score",    evt_df.slc.nu_score > CTE.min_nu_score),
            ("track",       evt_df.slc.cut.track),
            ("chi2",        evt_df.slc.cut.MIP_candidates),
            ("shower",      shower_cut_mask(evt_df, group_levels) == False),
            ("angle",       evt_df.slc.cut.angle),
            #("proton_BDT",  evt_df.slc.cut.proton_BDT_sideband),
            ("containment", evt_df.slc.cut.containment),
            ("michel",      evt_df.slc.cut.michel),
            #("extra_pion",  evt_df.slc.cut.extra_pion),
            #("bad_tracks",  evt_df.slc.cut_var.n_bad_trks == 0),
            #("energy",      evt_df.slc.cut.energy),
            ("energy",      evt_df.slc.cut.obvious_cosmic),
        ]

    elif sideband == "proton": 
        cut_sequence = [
            ("cosmic",      evt_df.slc.cut.obvious_cosmic),
            ("t0",          evt_df.slc.cut.t0),
            ("FV",          evt_df.slc.cut.inside_FV),
            ("nu_score",    evt_df.slc.nu_score > CTE.min_nu_score),
            ("track",       evt_df.slc.cut.track),
            ("chi2",        evt_df.slc.cut.MIP_candidates),
            ("shower",      evt_df.slc.cut.shower),
            ("angle",       evt_df.slc.cut.angle),
            ("proton_BDT",  proton_BDT_sideband_mask(evt_df,group_levels)),
            ("containment", evt_df.slc.cut.containment),
            ("michel",      evt_df.slc.cut.michel),
            #("extra_pion",  evt_df.slc.cut.extra_pion),
            #("bad_tracks",  evt_df.slc.cut_var.n_bad_trks == 0),
            #("energy",      evt_df.slc.cut.energy),
            ("energy",      evt_df.slc.cut.obvious_cosmic),
        ]

            
        

    # 2️⃣ Build cumulative masks
    cumulative_masks = {}
    current_mask = None

    for name, mask in cut_sequence:

        if current_mask is None:
            current_mask = mask.copy()
        else:
            current_mask = current_mask & mask

        cumulative_masks[name] = current_mask.copy()

    return cumulative_masks
'''
# Out:
# '\ngroup_levels = [\'__ntuple\', \'entry\', \'rec.slc..index\']\ndef build_event_cumulative_masks(evt_df, sideband = "shower"):\n    # Define which BDT mask to use\n    \n    cut_sequence = [\n        ("cosmic",      evt_df.slc.cut.obvious_cosmic),\n        ("t0",          evt_df.slc.cut.t0),\n        ("FV",          evt_df.slc.cut.inside_FV),\n        ("nu_score",    evt_df.slc.nu_score > CTE.min_nu_score),\n        ("track",       evt_df.slc.cut.track),\n        ("chi2",        evt_df.slc.cut.MIP_candidates),\n        ("shower",      evt_df.slc.cut.shower),\n        ("angle",       evt_df.slc.cut.angle),\n        ("proton_BDT",  evt_df.slc.cut.proton_BDT),\n        ("containment", evt_df.slc.cut.containment),\n        ("michel",      evt_df.slc.cut.michel),\n        ("extra_pion",  evt_df.slc.cut.extra_pion),\n        #("bad_tracks",  evt_df.slc.cut_var.n_bad_trks == 0),\n        ("energy",      evt_df.slc.cut.energy),\n    ]\n    \n    if sideband == "shower": \n        cut_sequence = [\n            ("cosmic",      evt_df.slc.cut.obvious_cosmic),\n            ("t0",          evt_df.slc.cut.t0),\n            ("FV",          evt_df.slc.cut.inside_FV),\n            ("nu_score",    evt_df.slc.nu_score > CTE.min_nu_score),\n            ("track",       evt_df.slc.cut.track),\n            ("chi2",        evt_df.slc.cut.MIP_candidates),\n            ("shower",      shower_cut_mask(evt_df, group_levels) == False),\n            ("angle",       evt_df.slc.cut.angle),\n            #("proton_BDT",  evt_df.slc.cut.proton_BDT_sideband),\n            ("containment", evt_df.slc.cut.containment),\n            ("michel",      evt_df.slc.cut.michel),\n            #("extra_pion",  evt_df.slc.cut.extra_pion),\n            #("bad_tracks",  evt_df.slc.cut_var.n_bad_trks == 0),\n            #("energy",      evt_df.slc.cut.energy),\n            ("energy",      evt_df.slc.cut.obvious_cosmic),\n        ]\n\n    elif sideband == "proton": \n        cut_sequence = [\n            ("cosmic",      evt_df.slc.cut.obvious_cosmic),\n            ("t0",          evt_df.slc.cut.t0),\n            ("FV",          evt_df.slc.cut.inside_FV),\n            ("nu_score",    evt_df.slc.nu_score > CTE.min_nu_score),\n            ("track",       evt_df.slc.cut.track),\n            ("chi2",        evt_df.slc.cut.MIP_candidates),\n            ("shower",      evt_df.slc.cut.shower),\n            ("angle",       evt_df.slc.cut.angle),\n            ("proton_BDT",  proton_BDT_sideband_mask(evt_df,group_levels)),\n            ("containment", evt_df.slc.cut.containment),\n            ("michel",      evt_df.slc.cut.michel),\n            #("extra_pion",  evt_df.slc.cut.extra_pion),\n            #("bad_tracks",  evt_df.slc.cut_var.n_bad_trks == 0),\n            #("energy",      evt_df.slc.cut.energy),\n            ("energy",      evt_df.slc.cut.obvious_cosmic),\n        ]\n\n            \n        \n\n    # 2️⃣ Build cumulative masks\n    cumulative_masks = {}\n    current_mask = None\n\n    for name, mask in cut_sequence:\n\n        if current_mask is None:\n            current_mask = mask.copy()\n        else:\n            current_mask = current_mask & mask\n\n        cumulative_masks[name] = current_mask.copy()\n\n    return cumulative_masks\n'

# %%
mc_evt_df[('slc', 'cut', 'proton_BDT_sideband', '', '', '')] = proton_BDT_sideband_mask(mc_evt_df, ['__ntuple', 'entry', 'rec.slc..index'])

# %%
# --- CV ---
#proton sideband

mc_GiBUU_evt_df_sideband = mc_GiBUU_evt_df[build_event_cumulative_masks(mc_GiBUU_evt_df, plot_sideband = True)["energy"]]
mc_evt_df_sideband = mc_evt_df[build_event_cumulative_masks(mc_evt_df, plot_sideband = True)["energy"]]

mc_GiBUU_evt_df = mc_GiBUU_evt_df[build_event_cumulative_masks(mc_GiBUU_evt_df, plot_sideband = False)["energy"]]
mc_evt_df = mc_evt_df[build_event_cumulative_masks(mc_evt_df, plot_sideband = False)["energy"]]

# %% [markdown]
# # Get all the syst uncert

# %%
from analysis_village.cc1pi.HelperFunctions import HelperFunctions

HelperFunctions.print_purity(mc_evt_df, ('truth','nu_categ','','','',''))
HelperFunctions.print_purity(mc_evt_df_sideband, ('truth','nu_categ','','','',''))
HelperFunctions.print_purity(mc_GiBUU_evt_df, ('truth','nu_categ','','','',''))
HelperFunctions.print_purity(mc_GiBUU_evt_df_sideband, ('truth','nu_categ','','','',''))
# Out:
# Total weighted slices: 1487.009
# Purity (weighted / total weighted)
#
# $\nu_{\mu}$CC1$\pi^{\pm}$: purity: 70.6403%  counts: 1050.428
# $\nu_{\mu}$CC0$\pi^{\pm}$0p: purity: 1.2098%  counts: 17.990
# $\nu_{\mu}$CC0$\pi^{\pm}$1p: purity: 10.7996%  counts: 160.592
# $\nu_{\mu}$CC0$\pi^{\pm}2^{+}p$: purity: 3.4819%  counts: 51.775
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 3.8950%  counts: 57.918
# NC: purity: 3.8654%  counts: 57.480
# cosmic: purity: 0.3246%  counts: 4.827
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 4.7212%  counts: 70.204
# out-AV $\nu$: purity: 1.0623%  counts: 15.796
# Total weighted slices: 88.633
# Purity (weighted / total weighted)
#
# $\nu_{\mu}$CC1$\pi^{\pm}$: purity: 6.4356%  counts: 5.704
# $\nu_{\mu}$CC0$\pi^{\pm}$1p: purity: 62.8713%  counts: 55.724
# $\nu_{\mu}$CC0$\pi^{\pm}2^{+}p$: purity: 23.2673%  counts: 20.622
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 0.9901%  counts: 0.878
# NC: purity: 2.9703%  counts: 2.633
# cosmic: purity: 0.4950%  counts: 0.439
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 2.4752%  counts: 2.194
# out-AV $\nu$: purity: 0.4950%  counts: 0.439
# Total weighted slices: 1601.171
# Purity (weighted / total weighted)
#
# $\nu_{\mu}$CC1$\pi^{\pm}$: purity: 77.5768%  counts: 1242.137
# $\nu_{e}$CC: purity: 0.0631%  counts: 1.010
# $\nu_{\mu}$CC0$\pi^{\pm}$0p: purity: 1.0517%  counts: 16.840
# $\nu_{\mu}$CC0$\pi^{\pm}$1p: purity: 6.9626%  counts: 111.482
# $\nu_{\mu}$CC0$\pi^{\pm}2^{+}p$: purity: 2.8818%  counts: 46.142
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 2.3769%  counts: 38.059
# NC: purity: 2.0825%  counts: 33.344
# cosmic: purity: 0.3366%  counts: 5.389
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 5.4480%  counts: 87.233
# out-AV $\nu$: purity: 1.2200%  counts: 19.535
# Total weighted slices: 390.694
# Purity (weighted / total weighted)
#
# $\nu_{\mu}$CC1$\pi^{\pm}$: purity: 29.3966%  counts: 114.851
# $\nu_{\mu}$CC0$\pi^{\pm}$0p: purity: 0.3448%  counts: 1.347
# $\nu_{\mu}$CC0$\pi^{\pm}$1p: purity: 46.9828%  counts: 183.559
# $\nu_{\mu}$CC0$\pi^{\pm}2^{+}p$: purity: 15.0862%  counts: 58.941
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 1.5517%  counts: 6.062
# NC: purity: 2.5862%  counts: 10.104
# cosmic: purity: 0.1724%  counts: 0.674
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 3.4483%  counts: 13.472
# out-AV $\nu$: purity: 0.4310%  counts: 1.684

# %%
def overlay_hists(mc_df=None,
                  data_df=None,
                  var_config=""): 
    
    if mc_df is not None:
        vardf, _        = get_clipped_evts(mc_df, var_config.var_evt_reco_col, var_config.bins)

        cuts = [
                mc_df.truth.nu_categ == topo
                for topo in topology_list
            ]
        
        var_categ = [vardf[i] for i in cuts]
        weights_categ = [mc_df.loc[cut, ('slc','wgt','','','','')]
            for cut in cuts
        ]
        
        # MC stat err
        each_mc_hist_data = []
        for v, w in zip(var_categ, weights_categ):
            hist_vals, _ = np.histogram(v, weights=w, bins=var_config.bins)
            each_mc_hist_data.append(hist_vals)
        total_mc = np.sum(each_mc_hist_data, axis=0)
        total_mc_bkgd = sum(each_mc_hist_data[1:])

    else:
        vardf = None
        var_categ = None
        total_mc = None
        print("No MC data provided")
        
    # Data
    if data_df is not None:
        vardf_data, _   = get_clipped_evts(data_df, var_config.var_evt_reco_col, var_config.bins)
        total_data, _ = np.histogram(vardf_data, bins=var_config.bins, weights=data_df.slc.wgt)

    return {"total_mc": total_mc, 
            "total_mc_bkgd": total_mc_bkgd,
            "total_data": total_data}

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import os

unisim_keys = []
paired_syst = {} 
file_dir = "/exp/sbnd/data/users/lpelegri/syst/CCBC_rates"
os.makedirs(file_dir, exist_ok=True)

if 'syst_dict' not in locals():
    syst_dict = {}

var_configs = [
    VariableConfig.all_evts(), 
    VariableConfig.muon_momentum(),
    VariableConfig.muon_direction(),
    VariableConfig.pion_momentum(),
    VariableConfig.pion_direction(),
    VariableConfig.angle_between_candidates(),
    VariableConfig.num_protons(),
    VariableConfig.delta_pt(),
    VariableConfig.delta_alpha_T(),
    VariableConfig.delta_phi_T()
]

univ_hist_GiBUU = {"Ps": {}, "Bs": {}, "nc": {}}
# --- 3. Main Variable Loop ---
for var_config in var_configs:
    var_name = var_config.var_save_name

    ret_GiBUU = overlay_hists(mc_df=mc_GiBUU_evt_df,
                            data_df=mc_GiBUU_evt_df_sideband,
                            var_config=var_config)
    print(ret_GiBUU)
    univ_hist_GiBUU["Ps"][var_name] = np.array(ret_GiBUU["total_mc"] - ret_GiBUU["total_mc_bkgd"])
    univ_hist_GiBUU["Bs"][var_name] = np.array(ret_GiBUU["total_mc_bkgd"])
    univ_hist_GiBUU["nc"][var_name] = np.array(ret_GiBUU["total_data"])

# --- CRITICAL PART FOR SAVING ---
# np.savez does not like deep nesting. To preserve your dict structure:
save_path = os.path.join(file_dir, "GiBUU_univ_hists.npz")
np.savez(save_path, **{k: np.array(v, dtype=object) for k, v in univ_hist_GiBUU.items()})
# Out:
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 52        13     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 12        9      0               0                          0.336805
#                                                               ...
# 11725     6      1               4                          0.336805
#                                  5                          0.336805
#           21     2               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 14873, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 31        8      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 207       17     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10849     16     0               3                          0.336805
# 10981     17     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 177, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 41        6      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 63        9      0               0                          0.336805
#                                                               ...
# 11659     1      0               2                          0.336805
#                                  3                          0.336805
# 11717     18     0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 1159, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 51        18     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 212       6      0               0                          0.336805
#                                                               ...
# 11481     0      0               6                          0.336805
# 11547     9      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 619, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 30        6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11352     9      2               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# Name: (slc, wgt, , , , ), Length: 608, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 89        4      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# 24        8      0               0                          0.336805
#                                                               ...
# 11717     13     0               1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  6                          0.336805
#                                  8                          0.336805
# Name: (slc, wgt, , , , ), Length: 1108, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 73        10     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11521     11     0               4                          0.336805
# 11663     19     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 405, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 39        0      0               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  7                          0.336805
#                                  8                          0.336805
#                                                               ...
# 11382     6      0               3                          0.336805
#                                  4                          0.336805
# 11537     12     0               0                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 198, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 42        11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 2643      11     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10616     6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 65, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 1548      15     0               1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
# 3542      6      1               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# 4824      11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
# Name: (slc, wgt, , , , ), dtype: float64
# {'total_mc': array([6475.07700175]), 'total_mc_bkgd': array([1465.77555847]), 'total_data': array([1504.17133367])}
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 52        13     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 12        9      0               0                          0.336805
#                                                               ...
# 11725     6      1               4                          0.336805
#                                  5                          0.336805
#           21     2               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 14873, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 31        8      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 207       17     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10849     16     0               3                          0.336805
# 10981     17     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 177, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 41        6      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 63        9      0               0                          0.336805
#                                                               ...
# 11659     1      0               2                          0.336805
#                                  3                          0.336805
# 11717     18     0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 1159, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 51        18     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 212       6      0               0                          0.336805
#                                                               ...
# 11481     0      0               6                          0.336805
# 11547     9      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 619, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 30        6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11352     9      2               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# Name: (slc, wgt, , , , ), Length: 608, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 89        4      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# 24        8      0               0                          0.336805
#                                                               ...
# 11717     13     0               1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  6                          0.336805
#                                  8                          0.336805
# Name: (slc, wgt, , , , ), Length: 1108, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 73        10     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11521     11     0               4                          0.336805
# 11663     19     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 405, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 39        0      0               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  7                          0.336805
#                                  8                          0.336805
#                                                               ...
# 11382     6      0               3                          0.336805
#                                  4                          0.336805
# 11537     12     0               0                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 198, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 42        11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 2643      11     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10616     6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 65, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 1548      15     0               1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
# 3542      6      1               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# 4824      11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
# Name: (slc, wgt, , , , ), dtype: float64
# {'total_mc': array([1056.22062302, 1571.19553775, 1486.32066625, 1087.20668721,
#        1274.13348752]), 'total_mc_bkgd': array([258.32946998, 319.29118323, 279.8849929 , 243.84685302,
#        364.42305934]), 'total_data': array([215.55522919, 337.14185065, 346.57239193, 282.91623831,
#        321.9856236 ])}
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 52        13     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 12        9      0               0                          0.336805
#                                                               ...
# 11725     6      1               4                          0.336805
#                                  5                          0.336805
#           21     2               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 14873, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 31        8      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 207       17     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10849     16     0               3                          0.336805
# 10981     17     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 177, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 41        6      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 63        9      0               0                          0.336805
#                                                               ...
# 11659     1      0               2                          0.336805
#                                  3                          0.336805
# 11717     18     0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 1159, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 51        18     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 212       6      0               0                          0.336805
#                                                               ...
# 11481     0      0               6                          0.336805
# 11547     9      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 619, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 30        6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11352     9      2               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# Name: (slc, wgt, , , , ), Length: 608, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 89        4      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# 24        8      0               0                          0.336805
#                                                               ...
# 11717     13     0               1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  6                          0.336805
#                                  8                          0.336805
# Name: (slc, wgt, , , , ), Length: 1108, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 73        10     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11521     11     0               4                          0.336805
# 11663     19     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 405, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 39        0      0               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  7                          0.336805
#                                  8                          0.336805
#                                                               ...
# 11382     6      0               3                          0.336805
#                                  4                          0.336805
# 11537     12     0               0                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 198, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 42        11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 2643      11     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10616     6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 65, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 1548      15     0               1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
# 3542      6      1               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# 4824      11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
# Name: (slc, wgt, , , , ), dtype: float64
# {'total_mc': array([1217.88704491, 1052.51576751, 1159.61977202, 1441.52559519,
#        1603.52882212]), 'total_mc_bkgd': array([356.6765433 , 254.96141952, 240.81560761, 234.41631174,
#        378.90567631]), 'total_data': array([359.70778871, 273.48569703, 297.73566031, 296.38844013,
#        276.85374749])}
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 52        13     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 12        9      0               0                          0.336805
#                                                               ...
# 11725     6      1               4                          0.336805
#                                  5                          0.336805
#           21     2               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 14873, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 31        8      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 207       17     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10849     16     0               3                          0.336805
# 10981     17     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 177, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 41        6      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 63        9      0               0                          0.336805
#                                                               ...
# 11659     1      0               2                          0.336805
#                                  3                          0.336805
# 11717     18     0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 1159, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 51        18     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 212       6      0               0                          0.336805
#                                                               ...
# 11481     0      0               6                          0.336805
# 11547     9      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 619, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 30        6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11352     9      2               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# Name: (slc, wgt, , , , ), Length: 608, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 89        4      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# 24        8      0               0                          0.336805
#                                                               ...
# 11717     13     0               1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  6                          0.336805
#                                  8                          0.336805
# Name: (slc, wgt, , , , ), Length: 1108, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 73        10     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11521     11     0               4                          0.336805
# 11663     19     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 405, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 39        0      0               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  7                          0.336805
#                                  8                          0.336805
#                                                               ...
# 11382     6      0               3                          0.336805
#                                  4                          0.336805
# 11537     12     0               0                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 198, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 42        11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 2643      11     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10616     6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 65, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 1548      15     0               1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
# 3542      6      1               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# 4824      11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
# Name: (slc, wgt, , , , ), dtype: float64
# {'total_mc': array([1531.11573732, 1462.07070297, 1172.41836375, 1084.84905189,
#        1224.62314582]), 'total_mc_bkgd': array([322.99603873, 285.27387363, 281.90582317, 224.98577046,
#        350.61405247]), 'total_data': array([527.77350646, 469.50623357, 241.4892177 , 165.03447235,
#        100.36790359])}
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 52        13     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 12        9      0               0                          0.336805
#                                                               ...
# 11725     6      1               4                          0.336805
#                                  5                          0.336805
#           21     2               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 14873, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 31        8      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 207       17     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10849     16     0               3                          0.336805
# 10981     17     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 177, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 41        6      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 63        9      0               0                          0.336805
#                                                               ...
# 11659     1      0               2                          0.336805
#                                  3                          0.336805
# 11717     18     0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 1159, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 51        18     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 212       6      0               0                          0.336805
#                                                               ...
# 11481     0      0               6                          0.336805
# 11547     9      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 619, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 30        6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11352     9      2               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# Name: (slc, wgt, , , , ), Length: 608, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 89        4      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# 24        8      0               0                          0.336805
#                                                               ...
# 11717     13     0               1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  6                          0.336805
#                                  8                          0.336805
# Name: (slc, wgt, , , , ), Length: 1108, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 73        10     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11521     11     0               4                          0.336805
# 11663     19     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 405, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 39        0      0               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  7                          0.336805
#                                  8                          0.336805
#                                                               ...
# 11382     6      0               3                          0.336805
#                                  4                          0.336805
# 11537     12     0               0                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 198, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 42        11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 2643      11     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10616     6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 65, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 1548      15     0               1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
# 3542      6      1               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# 4824      11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
# Name: (slc, wgt, , , , ), dtype: float64
# {'total_mc': array([1481.26859057, 1082.15461153, 1292.65776503, 1190.94264126,
#        1428.05339336]), 'total_mc_bkgd': array([284.26345849, 169.74974298, 230.37465119, 282.57943326,
#        498.80827254]), 'total_data': array([269.10723144, 171.43376821, 202.08302736, 364.75986439,
#        496.78744227])}
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 52        13     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 12        9      0               0                          0.336805
#                                                               ...
# 11725     6      1               4                          0.336805
#                                  5                          0.336805
#           21     2               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 14873, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 31        8      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 207       17     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10849     16     0               3                          0.336805
# 10981     17     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 177, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 41        6      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 63        9      0               0                          0.336805
#                                                               ...
# 11659     1      0               2                          0.336805
#                                  3                          0.336805
# 11717     18     0               0                          0.336805
#                                  1                          0.336805
# ...
#                                  3                          0.336805
# 11717     18     0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 1159, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 51        18     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 212       6      0               0                          0.336805
#                                                               ...
# 11481     0      0               6                          0.336805
# 11547     9      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 619, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 30        6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11352     9      2               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# Name: (slc, wgt, , , , ), Length: 608, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 89        4      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# 24        8      0               0                          0.336805
#                                                               ...
# 11717     13     0               1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  6                          0.336805
#                                  8                          0.336805
# Name: (slc, wgt, , , , ), Length: 1108, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 73        10     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11521     11     0               4                          0.336805
# 11663     19     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 405, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 39        0      0               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  7                          0.336805
#                                  8                          0.336805
#                                                               ...
# 11382     6      0               3                          0.336805
#                                  4                          0.336805
# 11537     12     0               0                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 198, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 42        11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 2643      11     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10616     6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 65, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 1548      15     0               1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
# 3542      6      1               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# 4824      11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
# Name: (slc, wgt, , , , ), dtype: float64
# {'total_mc': array([ 686.74548799,  665.52677011,  921.16179973, 1515.62270522,
#        2686.0202387 ]), 'total_mc_bkgd': array([157.96156639, 108.11441964, 157.62476134, 294.7044149 ,
#        747.3703962 ]), 'total_data': array([137.07965356,  93.29499763, 130.68035769, 227.68021083,
#        915.43611395])}
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 52        13     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 12        9      0               0                          0.336805
#                                                               ...
# 11725     6      1               4                          0.336805
#                                  5                          0.336805
#           21     2               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 14873, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 31        8      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 207       17     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10849     16     0               3                          0.336805
# 10981     17     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 177, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 41        6      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 63        9      0               0                          0.336805
#                                                               ...
# 11659     1      0               2                          0.336805
#                                  3                          0.336805
# 11717     18     0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 1159, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 51        18     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# 212       6      0               0                          0.336805
#                                                               ...
# 11481     0      0               6                          0.336805
# 11547     9      0               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 619, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 30        6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11352     9      2               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# Name: (slc, wgt, , , , ), Length: 608, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 89        4      0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# 24        8      0               0                          0.336805
#                                                               ...
# 11717     13     0               1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  6                          0.336805
#                                  8                          0.336805
# Name: (slc, wgt, , , , ), Length: 1108, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 73        10     1               0                          0.336805
#                                  1                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                                               ...
# 11521     11     0               4                          0.336805
# 11663     19     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 405, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 39        0      0               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  7                          0.336805
#                                  8                          0.336805
#                                                               ...
# 11382     6      0               3                          0.336805
#                                  4                          0.336805
# 11537     12     0               0                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
# Name: (slc, wgt, , , , ), Length: 198, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 42        11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
# 2643      11     1               0                          0.336805
#                                  1                          0.336805
#                                                               ...
# 10616     6      1               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  3                          0.336805
#                                  4                          0.336805
# Name: (slc, wgt, , , , ), Length: 65, dtype: float64
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 1548      15     0               1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
# 3542      6      1               0                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
#                                  6                          0.336805
# 4824      11     0               0                          0.336805
#                                  1                          0.336805
#                                  2                          0.336805
#                                  4                          0.336805
#                                  5                          0.336805
# Name: (slc, wgt, , , , ), dtype: float64
# {'total_mc': array([1218.22384995, 1299.39386594, 1467.12277865, 1234.0536871 ,
#        1256.28282011]), 'total_mc_bkgd': array([286.28428876, 294.36760986, 309.86064196, 261.36071539,
#        313.9023025 ]), 'total_data': array([415.61742628, 364.75986439, 280.22179794, 183.22194481,
#        260.35030025])}
