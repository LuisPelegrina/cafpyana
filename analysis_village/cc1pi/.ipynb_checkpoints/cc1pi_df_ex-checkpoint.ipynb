# %%
## In this example, we will study output data frame from pandora.py configuration
#### 1. Opening each data frame and check structure
#### 2. Collect POT and scale factor to the target POT
#### 3. Merge evtdf and mcnudf for further study
#### 4. Draw some plots for each slice and for each pfp
import ROOT
from ROOT import TMVA

import os
import sys
import lmfit
import numpy as np
import math
import uproot as uproot
import pickle
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.colors
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import ticker
from matplotlib.ticker import (AutoMinorLocator, MultipleLocator)
from matplotlib import gridspec

from analysis_village.unfolding.wienersvd import *
from analysis_village.unfolding.unfolding_inputs import *


print('Importing Helper Funcions...')
# Add the directory containing Constants to the system path
if ('./HelperFunctions' not in sys.path):
    sys.path.append('./HelperFunctions')  # project root
# Import the constants
import HelperFunctions

# Add the head direcoty to sys.path
workspace_root = os.getcwd()  
sys.path.insert(0, workspace_root + "/../../")

# Absolute path to cafpyana directory
print('Importing cafpyana utils...')
cafpyana_root = "/home/lpelegri/cafpyana"
# Add CAFpyana to the Python search path -- this will allow you to import cafpyana modules
sys.path.insert(0, cafpyana_root)

# import this repo's classes
import pyanalib.pandas_helpers as ph
import pyanalib.split_df_helpers as splh
import pyanalib.stat_helpers as sh

np.seterr(divide='ignore', invalid='ignore', over='ignore')

print('Importing the values of the constants...')
# Add the directory containing Constants to the system path
if ('./Constants' not in sys.path):
    sys.path.append('./Constants')  # project root
# Import the constants
import CTE

print('Importing function to load the DataFrames...')
# Add the directory containing LoadDataFrames to the system path
if ('./DataFrameUtils' not in sys.path):
    sys.path.append('./DataFrameUtils')  # project root
from Files import filename_to_dataframe
from DFCleaning import *

print('Importing Functions to make cut masks...')
# Add the directory containing Constants to the system path
if ('./CutMasks' not in sys.path):
    sys.path.append('./CutMasks')  # project root
# Import the constants
import CutMasks

print('Importing Helper Funcions...')
# Add the directory containing Constants to the system path
if ('./HelperFunctions' not in sys.path):
    sys.path.append('./HelperFunctions')  # project root
# Import the constants
import HelperFunctions

print('Importing make_df...')
# Add the directory containing Constants to the system path
if ('./makedf' not in sys.path):
    sys.path.append('./makedf')  # project root
# Import the constants
import make_cc1pidf
# Out:
# Welcome to JupyROOT 6.28/12
# Importing Helper Funcions...
# Importing cafpyana utils...
# Importing the values of the constants...
# Importing function to load the DataFrames...
# Importing Functions to make cut masks...
# Importing cafpyana utils...
# Importing Helper Funcions...
# Importing make_df...
# Importing cafpyana utils...
# Info in <TUnixSystem::ACLiC>: creating shared library /home/lpelegri/cafpyana/analysis_village/cc1pi/TLExtensionMethod/PhysdEdx_cpp.so
# 📦 Successfully compiled and linked: PhysdEdx
# 📦 Successfully compiled and linked: Hypfit
# 🚀 Success! Hypfit object initialized and linked.
# Done creating splines for particle with pdgcode 13
# Done creating splines for particle with pdgcode 211
# Done creating splines for particle with pdgcode 321
# Done creating splines for particle with pdgcode 2212
# Hypfit: Pre-calculating convolution maps...
# Info in <TUnixSystem::ACLiC>: creating shared library /home/lpelegri/cafpyana/analysis_village/cc1pi/TLExtensionMethod/Hypfit_cpp.so

# %% [markdown]
# # Load DataFrames

# %%
## Check keys in each file
test_file = "/scratch/7DayLifetime/lpelegrina/cc1pi_wiremod_YZ_test.df"
print("keys in test_file")
splh.print_keys(test_file)

## Check split multiplicity
print("mc_bnb_cosmic_file n_split: %d" %splh.get_n_split(test_file))
# Out:
# keys in test_file
# Keys: ['/cc1pi_0', '/hdr_0', '/histpotdf_0', '/nudf_0', '/pot_0', '/split']
# mc_bnb_cosmic_file n_split: 1

# %%
## Define keys to load
print('MC dataframes')
n_max_concat = 2 ## for big files, each key could have more than one split
keys2load = ["cc1pi", "hdr", "histpotdf", "nudf"] ## keys from the configuration file
test_df = splh.load_dfs(test_file, keys2load, n_max_concat)
print('test data loaded!')
# Out:
# MC dataframes
# test data loaded!

# %% [markdown]
# # Filter DataFrame

# %%
#Perform duplication validation
print("duplication for Spring Production BNB + Cosmic sample")
find_duplicate_run_evt_combinations(test_df['hdr'])
# Out:
# duplication for Spring Production BNB + Cosmic sample
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []

# %%
plot_duplicate_run_subrun_evt_distribution(test_df["hdr"], "test_df")

# %%
### Filter the hdr DataFrame first, then filter other DataFrames by matching with the hdr DataFrame
test_df["hdr"] = filter_unique_events(test_df["hdr"])
find_duplicate_run_evt_combinations(test_df["hdr"])
#filter the rest of dataframe keys
for key in keys2load:
    if key == "hdr":
        continue
    test_df[key] = filter_using_hdr(test_df[key], test_df["hdr"])
# Out:
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []

# %% [markdown]
# # Check normalization

# %%
def get_n_evt(df):
    unique_count = df.index.droplevel(
        list(df.index.names[2:])  # drop everything except first two levels
    ).nunique()
    return unique_count

# %%
## Collect the offbeam data fudge factor and scale for offbeam data
#n_record_spill_data = get_n_evt(data_bnb_light_dfs['hdr'])
#n_gates_data = len(data_bnb_light_dfs["pot"])

#n_record_spill_offbeam_data = get_n_evt(data_offbeam_light_dfs['hdr'])
#n_gates_offbeam_data = data_offbeam_light_dfs["hdr"][data_offbeam_light_dfs["hdr"]['first_in_subrun'] == 1]['noffbeambnb'].sum()

#p_trig_data = n_record_spill_data / n_gates_data
#p_trig_offbeam_data = n_record_spill_offbeam_data / n_gates_offbeam_data

#f_factor = (p_trig_data - p_trig_offbeam_data) / (1 - p_trig_offbeam_data)
#print("f_factor: %f" %f_factor)

#intime_gate_scale = (1. - f_factor) * (n_gates_data + 0.) / (n_gates_offbeam_data + 0.)
#print("intime_gate_scale: %f" %intime_gate_scale)

# %%
## Collect pot scale for MC
mc_tot_pot = test_df["hdr"]['pot'].sum()
#mc_low_th_tot_pot = mc_rockbox_th1to100_dfs["hdr"]['pot'].sum()

data_tot_pot = 3.63462e+18
#data_tot_pot = data_bnb_light_dfs["hdr"]['pot'].sum()
#data_tot_TOR860 = data_bnb_light_dfs["pot"]['TOR860'].sum()
#data_tot_TOR875 = data_bnb_light_dfs["pot"]['TOR875'].sum()

print("mc_tot_pot: %e" %(mc_tot_pot))
#print("mc_low_thtot_pot: %e" %(mc_low_th_tot_pot))

#print("data_tot_pot: %e" %(data_tot_pot))
#print("data_tot_TOR860: %e" %(data_tot_TOR860))
#print("data_tot_TOR875: %e" %(data_tot_TOR875))

target_pot = data_tot_pot
mc_pot_scale = target_pot / mc_tot_pot
#mc_low_th_scale = target_pot / mc_low_th_tot_pot
print("MC POT scale: %.3f" %(mc_pot_scale))
#print("MC Low Th. POT scale: %.3f" %(mc_low_th_scale))
# Out:
# mc_tot_pot: 1.531431e+17
# MC POT scale: 23.733

# %%
## Comparison between observed and expected total number of recorded spills
n_evt_mc = get_n_evt(test_df["hdr"])
#n_evt_mc_low_th = get_n_evt(mc_rockbox_th1to100_dfs["hdr"])

#print("n_evt_data_onbeam: %d" %n_record_spill_data)
#print("n_evt_exp.: %f" %(n_evt_mc * mc_pot_scale + n_evt_mc_low_th * mc_low_th_scale +n_record_spill_offbeam_data * intime_gate_scale))
print("- n_evt_mc: %f" %(n_evt_mc * mc_pot_scale))
#print("- n_evt_mc_low_th: %f" %(n_evt_mc_low_th * mc_low_th_scale))
#print("- n_evt_data_offbeam: %f" %(n_record_spill_offbeam_data * intime_gate_scale))
# Out:
# - n_evt_mc: 40228.261335

# %% [markdown]
# # Do truth matching

# %%
evt_df = test_df['cc1pi']
hdr_df = test_df['hdr']
nu_df = test_df['nudf']

# %%
new_columns = []
for c in nu_df.columns:
    new_columns.append(('truth',) + c + ('',) + ('',))  # prepend 'truth'
nu_df.columns = pd.MultiIndex.from_tuples(new_columns)

# %%
pd.set_option('display.max_rows', None)
print(nu_df.loc[:,[('truth', 'genie_categ', '', '','',''),('truth', 'pdg', '', '','',''), ('truth', 'genie_mode', '', '','',''), ('truth', 'iscc', '', '','','')]])
# Out:
#                                         truth
#                                   genie_categ pdg genie_mode iscc
#
#
#
#
# __ntuple entry rec.mc.nu..index
# 12       0     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          1    0
#                2                    out_AV_nu  14          1    0
#          1     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          1    1
#          2     0                 nu_mu_CC_Res  14          1    1
#          3     0                     nu_mu_NC  14          1    0
#          4     0                  nu_mu_CC_QE  14          0    1
#          5     0                 nu_mu_CC_Res  14          1    1
#          6     0                    out_AV_nu  14          0    1
#          7     0                    out_AV_nu  14          2    1
#                1                     nu_mu_NC  14          1    0
#                2                    out_AV_nu  14          1    1
#          8     0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          1    1
#          9     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    1
#          10    0                    out_AV_nu  14          1    1
#                1                     nu_mu_NC  14          0    0
#                2                    out_AV_nu  14          1    0
#          11    0                    out_AV_nu  14         10    1
#                1                    out_AV_nu  14          0    1
#          12    0                  nu_mu_CC_QE  14          0    1
# 81       0     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    1
#          1     0                    out_AV_nu  14          0    1
#          2     0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14          2    1
#          3     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          2    1
#                2                    out_AV_nu  14          1    1
#          4     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14         10    1
#          5     0                    out_AV_nu  14          0    1
#          6     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          1    1
#          7     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    1
#          8     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14         10    1
#          9     0                    out_AV_nu  14         10    1
#          10    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14         10    1
#          11    0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14          0    1
#          12    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          1    1
#          13    0                    out_AV_nu  14          0    1
#                1                  nu_mu_CC_QE  14          0    1
#                2                    out_AV_nu  14          0    1
#                3                    out_AV_nu  14          1    1
#                4                     nu_mu_NC  14          0    0
# 64       0     0                    out_AV_nu  14          1    0
#                1                 nu_mu_CC_Res  14          1    1
#                2                    out_AV_nu  14          1    1
#          1     0                    out_AV_nu  14          1    0
#                1                     nu_mu_NC  14          1    0
#          2     0                    out_AV_nu  14          2    1
#                1                     nu_mu_NC  14          0    0
#          3     0                    out_AV_nu  14          0    0
#                1                 nu_mu_CC_MEC  14         10    1
#          4     0                    out_AV_nu  14          2    1
#          5     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    0
#                2                    out_AV_nu  14          1    1
#          6     0                 nu_mu_CC_Res  14          1    1
#          7     0                    out_AV_nu  14          0    1
#          8     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          0    1
#          9     0                    out_AV_nu  14          1    1
#                1                 nu_mu_CC_MEC  14         10    1
#          10    0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          0    1
#          11    0                     nu_mu_NC  14          0    0
# 98       0     0                 nu_mu_CC_Dis  14          2    1
#                1                    out_AV_nu  14         10    1
#          1     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          0    1
#          2     0                     nu_mu_NC  14          0    0
#          3     0                    out_AV_nu  14          2    0
#                1                 nu_mu_CC_Res  14          1    1
#          4     0                    out_AV_nu  14          1    1
#          5     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#          6     0                    out_AV_nu  14         10    1
#                1                    out_AV_nu  14          0    1
#          7     0                    out_AV_nu  14          2    1
#          8     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          0    0
#                2                    out_AV_nu  14          0    1
#                3                    out_AV_nu  14          1    0
#          9     0                    out_AV_nu  14          0    1
#          10    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#          11    0                  nu_mu_CC_QE  14          0    1
#          12    0                    out_AV_nu  14          2    1
#          13    0                    out_AV_nu  14          1    1
#                1                     nu_mu_NC  14         10    0
#          14    0                    out_AV_nu  14          2    0
#                1                 nu_mu_CC_Res  14          1    1
#                2                    out_AV_nu  14          2    1
#          15    0                     nu_mu_NC  14          0    0
#                1                     nu_mu_NC  14          0    0
#          16    0                    out_AV_nu  14          0    1
# 94       0     0                    out_AV_nu  14          1    1
#                1                 nu_mu_CC_Res  14          1    1
#          1     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu -14          0    0
#                2                     nu_mu_NC  14          2    0
#                3                     nu_mu_NC  14          1    0
#          2     0                 nu_mu_CC_MEC  14         10    1
#          3     0                    out_AV_nu  14          2    1
#          4     0                  nu_mu_CC_QE  14          0    1
#                1                 nu_mu_CC_MEC  14         10    1
#          5     0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          0    1
#          6     0                     nu_mu_NC  14          1    0
#                1                    out_AV_nu  14         10    1
#          7     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    0
#                2                    out_AV_nu  14          0    1
#          8     0                 nu_mu_CC_Res  14          1    1
#          9     0                    out_AV_nu  14          0    1
#          10    0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          0    1
#                2                     nu_mu_NC  14          1    0
#          11    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          1    1
#          12    0                     nu_mu_NC -14          1    0
#                1                    out_AV_nu  14          1    0
#                2                    out_AV_nu  14          0    1
# 47       0     0                 nu_mu_CC_MEC  14         10    1
#          1     0                     nu_mu_NC  14          2    0
#          2     0                    out_AV_nu  14          0    1
#          3     0                    out_AV_nu  14          0    1
#                1                 nu_mu_CC_Res  14          1    1
#          4     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          2    1
#          5     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    0
#          6     0                  nu_mu_CC_QE  14          0    1
#          7     0                    out_AV_nu  14         10    1
#          8     0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          0    1
#          9     0                 nu_mu_CC_Dis  14          2    1
#                1                    out_AV_nu  14          0    1
#          10    0                    out_AV_nu  14          0    1
#                1                  nu_mu_CC_QE  14          0    1
#          11    0                 nu_mu_CC_Res  14          1    1
#          12    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          1    1
#                2                    out_AV_nu  14          0    1
#          13    0                 nu_mu_CC_Res  14          1    1
#          14    0                    out_AV_nu  14          2    0
#                1                    out_AV_nu  14          1    1
#          15    0                  nu_mu_CC_QE  14          0    1
#          16    0                 nu_mu_CC_Res  14          1    1
#          17    0                    out_AV_nu  14          1    0
#                1                     nu_mu_NC  14          0    0
# 49       0     0                     nu_mu_NC  14          0    0
#          1     0                    out_AV_nu  14          0    0
#                1                  nu_mu_CC_QE  14          0    1
#          2     0                     nu_mu_NC  14          0    0
#          3     0                    out_AV_nu  14          0    0
#                1                 nu_mu_CC_MEC  14         10    1
#          4     0                    out_AV_nu  14          2    0
#          5     0                        other  12          1    1
#          6     0                  nu_mu_CC_QE  14          0    1
#          7     0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          2    1
#          8     0                  nu_mu_CC_QE  14          0    1
#          9     0                     nu_mu_NC  14          0    0
#          10    0                    out_AV_nu  14          0    0
#                1                  nu_mu_CC_QE  14          0    1
# 62       0     0                  nu_mu_CC_QE  14          0    1
#          1     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14         10    1
#          2     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14         10    1
#          3     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    0
#                2                    out_AV_nu  14          1    1
#          4     0                    out_AV_nu -14         10    1
#                1                    out_AV_nu  14          0    0
#          5     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    0
#          6     0                     nu_mu_NC  14          0    0
#          7     0                        other  12          1    1
#                1                    out_AV_nu  14          0    1
#          8     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          1    1
#          9     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    0
#          10    0                     nu_mu_NC -14          1    0
#          11    0                    out_AV_nu  14         10    1
#                1                    out_AV_nu  14          0    1
#          12    0                 nu_mu_CC_Res  14          1    1
#                1                    out_AV_nu  14          2    1
#                2                    out_AV_nu  14          0    0
#          13    0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14         10    1
#                2                    out_AV_nu  14          1    0
#          14    0                    out_AV_nu  14          0    1
# 23       0     0                     nu_mu_NC  14          0    0
#          1     0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14          0    0
#          2     0                    out_AV_nu  14         10    1
#                1                    out_AV_nu  14          0    0
#                2                    out_AV_nu  14          0    1
#          3     0                    out_AV_nu  14          0    0
#                1                     nu_mu_NC  14          0    0
#                2                    out_AV_nu  14          0    1
#          4     0                  nu_mu_CC_QE  14          0    1
#          5     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          1    0
#          6     0                    out_AV_nu  14          0    1
#          7     0                 nu_mu_CC_MEC  14         10    1
#          8     0                 nu_mu_CC_MEC  14         10    1
# 54       0     0                 nu_mu_CC_Res  14          1    1
#          1     0                    out_AV_nu  14          2    1
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          1    0
#          2     0                    out_AV_nu  14          2    1
#          3     0                    out_AV_nu  14          2    1
#                1                    out_AV_nu  14          0    1
#          4     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          2    0
#                2                    out_AV_nu  14          1    0
#          5     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    0
#          6     0                 nu_mu_CC_MEC  14         10    1
#                1                    out_AV_nu  14         10    1
#          7     0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14          1    0
#          8     0                    out_AV_nu  14          0    1
#          9     0                    out_AV_nu  14          1    1
#                1                  nu_mu_CC_QE  14          0    1
#          10    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          2    1
#                2                  nu_mu_CC_QE  14          0    1
#          11    0                 nu_mu_CC_Res  14          1    1
#                1                    out_AV_nu  14          0    1
#          12    0                    out_AV_nu  14          0    1
#          13    0                    out_AV_nu  14          1    0
#                1                    out_AV_nu  14          0    1
#          14    0                  nu_mu_CC_QE  14          0    1
#          15    0                    out_AV_nu  14          0    1
#          16    0                    out_AV_nu  14          2    0
#                1                    out_AV_nu  14          0    1
# 8        0     0                 nu_mu_CC_Res  14          1    1
#          1     0                 nu_mu_CC_Res  14          1    1
#          2     0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14          0    1
#          3     0                    out_AV_nu  14          0    1
#          4     0                     nu_mu_NC  14          0    0
#          5     0                    out_AV_nu  14          1    0
#                1                    out_AV_nu  14          0    1
#          6     0                    out_AV_nu  14         10    1
#                1                    out_AV_nu  14          0    1
#          7     0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14         10    1
#          8     0                 nu_mu_CC_Res  14          1    1
#          9     0                  nu_mu_CC_QE  14          0    1
# 76       0     0                     nu_mu_NC  14          2    0
#                1                    out_AV_nu  14          0    1
#          1     0                    out_AV_nu  14          0    1
#          2     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          1    1
#                2                    out_AV_nu  14          0    1
#                3                    out_AV_nu  14          2    0
#          3     0                 nu_mu_CC_MEC  14         10    1
#                1                    out_AV_nu  14         10    1
#          4     0                    out_AV_nu  14          0    1
#          5     0                    out_AV_nu  14          0    1
#                1                     nu_mu_NC  14          0    0
#          6     0                    out_AV_nu  14         10    1
#                1                     nu_mu_NC  14          2    0
#          7     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    0
#          8     0                 nu_mu_CC_Dis  14          2    1
#          9     0                    out_AV_nu  14          0    1
#                1                     nu_mu_NC  14          0    0
#                2                    out_AV_nu  14          0    0
# 33       0     0                    out_AV_nu  14         10    1
#          1     0                 nu_mu_CC_MEC  14         10    1
#          2     0                 nu_mu_CC_MEC  14         10    1
#          3     0                     nu_mu_NC  14          2    0
#                1                    out_AV_nu  14         10    0
#                2                    out_AV_nu  14          0    1
#          4     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14         10    1
#          5     0                    out_AV_nu  14          1    0
#          6     0                    out_AV_nu  14         10    1
#                1                    out_AV_nu  14          0    1
#                2                  nu_mu_CC_QE  14          0    1
#          7     0                    out_AV_nu  14          1    1
#          8     0                     nu_mu_NC  14          0    0
#          9     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          2    1
#          10    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          0    1
#                3                     nu_mu_NC  14          0    0
#          11    0                  nu_mu_CC_QE  14          0    1
#          12    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14         10    1
#          13    0                    out_AV_nu  14          0    1
#          14    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    1
#          15    0                 nu_mu_CC_Res  14          1    1
#                1                    out_AV_nu  14          1    1
#                2                    out_AV_nu  14          2    0
#                3                 nu_mu_CC_Dis  14          2    1
# 28       0     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14         10    1
#          1     0                 nu_mu_CC_Res  14          1    1
#          2     0                     nu_mu_NC  14          1    0
#                1                    out_AV_nu  14          0    1
#          3     0                  nu_mu_CC_QE  14          0    1
#          4     0                    out_AV_nu  14          1    0
#                1                    out_AV_nu  14          0    1
#          5     0                     nu_mu_NC  14          1    0
#          6     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          1    1
#          7     0                    out_AV_nu  14          0    1
#                1                  nu_mu_CC_QE  14          0    1
#          8     0                    out_AV_nu  14          1    1
#                1                     nu_mu_NC  14         10    0
#          9     0                 nu_mu_CC_MEC  14         10    1
#                1                    out_AV_nu -14          1    1
#          10    0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          1    1
# 63       0     0                 nu_mu_CC_Dis  14          2    1
#                1                    out_AV_nu  14          2    1
#          1     0                     nu_mu_NC  14          0    0
#          2     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          2    1
#          3     0                    out_AV_nu  14          0    1
#          4     0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  12          0    0
#          5     0                 nu_mu_CC_Res  14          1    1
#                1                    out_AV_nu  14          0    1
#          6     0                    out_AV_nu  14          0    0
#                1                  nu_mu_CC_QE  14          0    1
#          7     0                    out_AV_nu  14          1    1
#          8     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14         10    1
#                2                    out_AV_nu  14         10    1
#          9     0                    out_AV_nu  14          0    1
#          10    0                    out_AV_nu  14          0    1
#          11    0                     nu_mu_NC  14          0    0
#          12    0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          0    1
#          13    0                    out_AV_nu  14          1    1
#                1                     nu_mu_NC  14          0    0
#          14    0                 nu_mu_CC_Res  14          1    1
#          15    0                 nu_mu_CC_MEC  14         10    1
#          16    0                     nu_mu_NC  14          2    0
#          17    0                     nu_mu_NC  14          1    0
# 52       0     0                 nu_mu_CC_MEC  14         10    1
#                1                    out_AV_nu  14          1    1
#          1     0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          0    1
#          2     0                 nu_mu_CC_Res  14          1    1
#                1                    out_AV_nu  14          2    1
#          3     0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14          0    1
#          4     0                 nu_mu_CC_Res  14          1    1
#          5     0                    out_AV_nu  14          1    0
#                1                    out_AV_nu  14          0    1
#          6     0                     nu_mu_NC  14          1    0
#          7     0                    out_AV_nu  14          0    1
#                1                     nu_mu_NC  14         10    0
#          8     0                     nu_mu_NC  14          0    0
#          9     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          0    1
#          10    0                     nu_mu_NC  14          1    0
#                1                    out_AV_nu  14          0    0
#          11    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#          12    0                  nu_mu_CC_QE  14          0    1
#          13    0                    out_AV_nu  14          1    0
#          14    0                    out_AV_nu  14          0    0
#                1                  nu_mu_CC_QE  14          0    1
#          15    0                    out_AV_nu  14          0    1
#          16    0                    out_AV_nu  14          2    0
#                1                     nu_mu_NC  14          0    0
#                2                    out_AV_nu  14          0    1
#          17    0                     nu_mu_NC  14          1    0
#          18    0                    out_AV_nu  14          1    0
#                1                  nu_mu_CC_QE  14          0    1
#          19    0                  nu_mu_CC_QE  14          0    1
#          20    0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          0    1
#          21    0                    out_AV_nu  14          0    1
# 37       0     0                     nu_mu_NC  14          0    0
#          1     0                    out_AV_nu  14          0    0
#                1                 nu_mu_CC_Res  14          1    1
#                2                    out_AV_nu  14          0    1
#          2     0                    out_AV_nu  14          1    0
#                1                     nu_mu_NC  14          0    0
#          3     0                    out_AV_nu  14         10    1
#          4     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          1    0
#                2                    out_AV_nu  14          2    0
#          5     0                    out_AV_nu  14          0    1
#          6     0                    out_AV_nu  14          1    1
#          7     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          1    1
#          8     0                 nu_mu_CC_Res  14          1    1
#          9     0                    out_AV_nu  14          1    0
#          10    0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          2    1
#                2                    out_AV_nu  14          0    1
#                3                 nu_mu_CC_MEC  14         10    1
#                4                    out_AV_nu  14          0    1
#          11    0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          1    1
#          12    0                    out_AV_nu  14         10    1
#                1                    out_AV_nu  14          0    0
#                2                    out_AV_nu  14          1    1
#          13    0                  nu_mu_CC_QE  14          0    1
#          14    0                    out_AV_nu  14          0    0
#                1                     nu_mu_NC  14          0    0
#                2                    out_AV_nu  14          0    0
#          15    0                    out_AV_nu  14          1    1
# 22       0     0                 nu_mu_CC_Res  14          1    1
#          1     0                    out_AV_nu  14          1    1
#                1                  nu_mu_CC_QE  14          0    1
#          2     0                    out_AV_nu  14          0    1
#                1                  nu_mu_CC_QE  14          0    1
#                2                    out_AV_nu  14          0    0
#          3     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14         10    1
#          4     0                    out_AV_nu  14          2    1
#                1                 nu_mu_CC_Res  14          1    1
#          5     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    0
#          6     0                    out_AV_nu  14          2    1
#                1                  nu_mu_CC_QE  14          0    1
#                2                    out_AV_nu  14          1    1
#          7     0                 nu_mu_CC_Dis  14          2    1
#                1                    out_AV_nu  14          1    1
#          8     0                    out_AV_nu  14          1    0
#          9     0                    out_AV_nu  14          1    1
#                1                  nu_mu_CC_QE  14          0    1
#          10    0                 nu_mu_CC_Res  14          1    1
#          11    0                    out_AV_nu  14         10    0
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          1    0
#                3                    out_AV_nu  14          0    1
#          12    0                    out_AV_nu  14          0    0
# 43       0     0                        other  14          3    1
#          1     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          1    0
#          2     0                    out_AV_nu  14          0    1
#                1                  nu_mu_CC_QE  14          0    1
#                2                    out_AV_nu  14         10    0
#          3     0                 nu_mu_CC_Res  14          1    1
#                1                    out_AV_nu  14          0    1
#          4     0                    out_AV_nu  14          1    0
#                1                  nu_mu_CC_QE  14          0    1
#          5     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          1    1
#          6     0                        other  12          0    1
#          7     0                     nu_mu_NC  14          0    0
#          8     0                    out_AV_nu  14          2    0
#                1                 nu_mu_CC_Res  14          1    1
#                2                    out_AV_nu  14          1    1
#          9     0                    out_AV_nu  14          0    1
#                1                 nu_mu_CC_Res  14          1    1
#          10    0                     nu_mu_NC  14          2    0
# 58       0     0                 nu_mu_CC_MEC  14         10    1
#                1                    out_AV_nu  14         10    1
#          1     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          1    1
#          2     0                    out_AV_nu  14          1    1
#          3     0                    out_AV_nu  14          2    1
#                1                 nu_mu_CC_MEC  14         10    1
#          4     0                 nu_mu_CC_MEC  14         10    1
#          5     0                  nu_mu_CC_QE  14          0    1
#          6     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          1    1
#          7     0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          0    1
#          8     0                 nu_mu_CC_MEC  14         10    1
#          9     0                    out_AV_nu  14          2    0
#                1                     nu_mu_NC  14          1    0
#          10    0                    out_AV_nu  14          0    0
#                1                 nu_mu_CC_Res  14          1    1
#                2                    out_AV_nu  14         10    1
#          11    0                  nu_mu_CC_QE  14          0    1
#          12    0                    out_AV_nu  14          0    1
#          13    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14         10    1
#                2                  nu_mu_CC_QE  14          0    1
#          14    0                  nu_mu_CC_QE  14          0    1
#          15    0                  nu_mu_CC_QE  14          0    1
# 70       0     0                    out_AV_nu  14         10    0
#                1                     nu_mu_NC  14          0    0
#          1     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    1
#          2     0                    out_AV_nu  14         10    0
#                1                    out_AV_nu  14         10    1
#          3     0                    out_AV_nu  14          2    0
#                1                  nu_mu_CC_QE  14          0    1
#          4     0                    out_AV_nu -14          1    1
#                1                    out_AV_nu  14          0    1
#          5     0                     nu_mu_NC  14          0    0
#          6     0                    out_AV_nu  14         10    1
#                1                    out_AV_nu  14          0    0
#          7     0                  nu_mu_CC_QE  14          0    1
#          8     0                    out_AV_nu  14         10    1
#                1                 nu_mu_CC_Res  14          1    1
#          9     0                 nu_mu_CC_Dis  14          2    1
#          10    0                 nu_mu_CC_Res  14          1    1
#          11    0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          1    1
#          12    0                    out_AV_nu  14          1    0
#                1                 nu_mu_CC_MEC  14         10    1
#                2                    out_AV_nu  14          1    1
#          13    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#          14    0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          1    0
#                2                     nu_mu_NC  14          2    0
# 38       0     0                    out_AV_nu  14          1    1
#          1     0                 nu_mu_CC_MEC  14         10    1
#          2     0                 nu_mu_CC_Res  14          1    1
#          3     0                  nu_mu_CC_QE  14          0    1
#          4     0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          0    1
#          5     0                    out_AV_nu -14          0    1
#                1                  nu_mu_CC_QE  14          0    1
#          6     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          1    0
#                2                    out_AV_nu  14          2    0
#          7     0                    out_AV_nu  14          1    1
#                1                     nu_mu_NC  14          0    0
#          8     0                     nu_mu_NC  14          0    0
#          9     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          0    1
#          10    0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14         10    1
#                2                    out_AV_nu  14          1    1
#          11    0                    out_AV_nu  14          1    1
#          12    0                    out_AV_nu  14          2    0
#          13    0                    out_AV_nu -14          0    1
#                1                 nu_mu_CC_MEC  14         10    1
#          14    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          1    1
#          15    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          1    1
#          16    0                    out_AV_nu  14          0    1
#                1                 nu_mu_CC_Res  14          1    1
#          17    0                    out_AV_nu  14          0    1
#                1                     nu_mu_NC  14          1    0
#          18    0                    out_AV_nu  14          0    1
#          19    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          1    1
# 89       0     0                 nu_mu_CC_Res  14          1    1
#          1     0                  nu_mu_CC_QE  14          0    1
#          2     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          0    1
#          3     0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14          2    0
#          4     0                 nu_mu_CC_Res  14          1    1
#          5     0                    out_AV_nu  14          0    0
#                1                     nu_mu_NC  14         10    0
#          6     0                  nu_mu_CC_QE  14          0    1
#          7     0                    out_AV_nu  14          2    1
#                1                    out_AV_nu  14          0    1
#                2                  nu_mu_CC_QE  14          0    1
#          8     0                    out_AV_nu -14          2    1
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          2    0
#          9     0                 nu_mu_CC_Res  14          1    1
#          10    0                    out_AV_nu  14          0    1
#                1                     nu_mu_NC  14          0    0
#          11    0                    out_AV_nu  14          0    0
#                1                     nu_mu_NC  14          0    0
#          12    0                 nu_mu_CC_MEC  14         10    1
#          13    0                  nu_mu_CC_QE  14          0    1
#          14    0                  nu_mu_CC_QE  14          0    1
#          15    0                    out_AV_nu  14          1    0
#                1                    out_AV_nu  14          1    1
#          16    0                    out_AV_nu  14          0    0
#                1                 nu_mu_CC_Res  14          1    1
#          17    0                    out_AV_nu  14         10    1
#                1                    out_AV_nu  14          2    1
#          18    0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14         10    1
# 68       0     0                  nu_mu_CC_QE  14          0    1
#          1     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          1    1
#          2     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          1    1
#          3     0                  nu_mu_CC_QE  14          0    1
#          4     0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          1    0
#                2                  nu_mu_CC_QE  14          0    1
#                3                    out_AV_nu  14          0    0
#          5     0                    out_AV_nu  14          1    0
#                1                    out_AV_nu  14          1    1
#          6     0                  nu_mu_CC_QE  14          0    1
#          7     0                 nu_mu_CC_Res  14          1    1
#                1                    out_AV_nu  14         10    1
#          8     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    1
#          9     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14         10    1
#          10    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    0
# 13       0     0                 nu_mu_CC_Dis  14          2    1
#          1     0                        other  12          0    1
#                1                    out_AV_nu -14         10    1
#          2     0                     nu_mu_NC  14          0    0
#          3     0                     nu_mu_NC  14          1    0
#          4     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14         10    1
#                2                    out_AV_nu  14          0    1
#          5     0                    out_AV_nu -14         10    0
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          1    1
#          6     0                    out_AV_nu  14          0    1
#          7     0                 nu_mu_CC_Res  14          1    1
#          8     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    1
#          9     0                    out_AV_nu  14          0    1
#                1                 nu_mu_CC_Res  14          1    1
#                2                    out_AV_nu  14         10    1
#          10    0                  nu_mu_CC_QE  14          0    1
#          11    0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14         10    1
#          12    0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          2    1
#          13    0                    out_AV_nu  14          0    1
#                1                     nu_mu_NC  14          0    0
# 20       0     0                 nu_mu_CC_MEC  14         10    1
#          1     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#          2     0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14          0    1
#          3     0                    out_AV_nu  14          0    1
#                1                  nu_mu_CC_QE  14          0    1
#          4     0                     nu_mu_NC  14          2    0
#          5     0                    out_AV_nu  14          0    0
#                1                     nu_mu_NC  14          0    0
#          6     0                     nu_mu_NC  14          0    0
#          7     0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          1    1
#                2                    out_AV_nu  14          2    0
#                3                    out_AV_nu  14         10    1
#          8     0                  nu_mu_CC_QE  14          0    1
#          9     0                    out_AV_nu  14         10    0
#                1                 nu_mu_CC_MEC  14         10    1
#          10    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    1
#          11    0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          0    1
#          12    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    0
#          13    0                    out_AV_nu  14         10    1
#          14    0                 nu_mu_CC_Res  14          1    1
#          15    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    1
#          16    0                    out_AV_nu  14          3    1
#          17    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          2    1
# 82       0     0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          0    1
#                3                    out_AV_nu  14          2    1
#          1     0                  nu_mu_CC_QE  14          0    1
#          2     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14         10    1
#          3     0                 nu_mu_CC_Dis  14          2    1
#          4     0                    out_AV_nu  14          0    1
#                1                     nu_mu_NC  14         10    0
#          5     0                    out_AV_nu  14          0    1
#          6     0                  nu_mu_CC_QE  14          0    1
#          7     0                 nu_mu_CC_Res  14          1    1
#          8     0                    out_AV_nu  14         10    1
#          9     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          2    1
#                3                    out_AV_nu  14          1    1
#          10    0                    out_AV_nu  14          0    1
# 7        0     0                    out_AV_nu  14          0    1
#          1     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          1    1
#          2     0                     nu_mu_NC  14          0    0
#          3     0                    out_AV_nu  14         10    1
#                1                     nu_mu_NC  14          0    0
#                2                    out_AV_nu  14          0    1
#          4     0                     nu_mu_NC  14          1    0
#          5     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    0
#          6     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          1    1
#                2                    out_AV_nu  14          0    1
#                3                    out_AV_nu  14          0    1
#          7     0                    out_AV_nu  14          0    1
#                1                 nu_mu_CC_MEC  14         10    1
#          8     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          1    0
#                2                    out_AV_nu  14          2    0
#                3                    out_AV_nu  14          0    0
#          9     0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          1    1
#                3                    out_AV_nu  14          1    1
#          10    0                  nu_mu_CC_QE  14          0    1
# ...
#                2                    out_AV_nu  14          0    1
#          15    0                    out_AV_nu  14          0    1
#                1                     nu_mu_NC  14          1    0
# 0        0     0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          1    0
#          1     0                 nu_mu_CC_MEC  14         10    1
#                1                    out_AV_nu  14         10    1
#                2                    out_AV_nu  14          0    1
#          2     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          1    1
#                2                    out_AV_nu  14          0    1
#          3     0                    out_AV_nu  14          0    1
#          4     0                    out_AV_nu  14          2    1
#                1                    out_AV_nu  14          1    1
#                2                    out_AV_nu  14          0    1
#          5     0                 nu_mu_CC_MEC  14         10    1
#                1                    out_AV_nu  14          0    0
#          6     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          0    1
#                3                    out_AV_nu  14         10    1
#          7     0                     nu_mu_NC  14          1    0
#          8     0                    out_AV_nu  14          2    1
#                1                    out_AV_nu  14          1    0
#          9     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14         10    1
#                2                    out_AV_nu  14          0    1
#                3                  nu_mu_CC_QE  14          0    1
#          10    0                 nu_mu_CC_Res  14          1    1
#          11    0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          1    1
#          12    0                    out_AV_nu  14         10    1
#          13    0                  nu_mu_CC_QE  14          0    1
#          14    0                    out_AV_nu  14          1    1
#          15    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  12          0    0
#          16    0                    out_AV_nu  14          0    0
#                1                     nu_mu_NC  14          1    0
#          17    0                    out_AV_nu  14          2    1
#                1                     nu_mu_NC  14          1    0
#          18    0                     nu_mu_NC  14         10    0
# 72       0     0                    out_AV_nu  14         10    1
#                1                    out_AV_nu  14         10    0
#                2                    out_AV_nu  14         10    1
#                3                  nu_mu_CC_QE  14          0    1
#          1     0                    out_AV_nu  14          2    1
#          2     0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          0    1
#                2                  nu_mu_CC_QE  14          0    1
#          3     0                  nu_mu_CC_QE  14          0    1
#          4     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          1    1
#                2                    out_AV_nu  14          0    1
#                3                    out_AV_nu  14          0    0
#          5     0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          0    0
#          6     0                     nu_mu_NC  14          0    0
#          7     0                    out_AV_nu  14          0    0
#          8     0                 nu_mu_CC_MEC  14         10    1
#                1                    out_AV_nu  14          1    1
#          9     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#          10    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    0
#          11    0                    out_AV_nu  14          0    0
#                1                  nu_mu_CC_QE  14          0    1
#          12    0                    out_AV_nu  14          1    0
#                1                    out_AV_nu  14          0    1
#          13    0                  nu_mu_CC_QE  14          0    1
#          14    0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          0    0
#          15    0                    out_AV_nu  14          1    1
#          16    0                    out_AV_nu  14          2    0
#          17    0                 nu_mu_CC_MEC  14         10    1
#          18    0                 nu_mu_CC_Res  14          1    1
#                1                    out_AV_nu  14          1    1
# 51       0     0                 nu_mu_CC_Res  14          1    1
#          1     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          1    1
#                2                     nu_mu_NC  14          2    0
#          2     0                    out_AV_nu  14          2    1
#                1                    out_AV_nu  14          1    1
#                2                    out_AV_nu  14         10    1
#          3     0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14         10    1
#                2                    out_AV_nu  14          1    1
#          4     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#          5     0                    out_AV_nu  14          0    0
#                1                  nu_mu_CC_QE  14          0    1
#          6     0                    out_AV_nu  14         10    0
#                1                 nu_mu_CC_Res  14          1    1
#                2                    out_AV_nu  14          1    1
#          7     0                    out_AV_nu  14          0    1
#                1                     nu_mu_NC  14          1    0
#          8     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          0    0
#                2                    out_AV_nu  14          0    1
#                3                    out_AV_nu  14          0    0
#                4                    out_AV_nu  14          0    1
#          9     0                 nu_mu_CC_Res  14          1    1
#                1                    out_AV_nu  14          0    1
#          10    0                     nu_mu_NC  14          2    0
#          11    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    0
#          12    0                    out_AV_nu  14          1    0
#                1                    out_AV_nu  14          1    0
#                2                    out_AV_nu  12          1    1
#          13    0                    out_AV_nu  14          0    1
#                1                 nu_mu_CC_MEC  14         10    1
#          14    0                 nu_mu_CC_MEC  14         10    1
#                1                    out_AV_nu  14          0    1
#          15    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    0
#          16    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          1    1
#                2                    out_AV_nu  14         10    1
#          17    0                  nu_mu_CC_QE  14          0    1
#          18    0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14          0    1
#          19    0                  nu_mu_CC_QE  14          0    1
#          20    0                    out_AV_nu  14         10    1
#                1                  nu_mu_CC_QE  14          0    1
#                2                    out_AV_nu  14          1    1
#          21    0                    out_AV_nu  14         10    0
#          22    0                 nu_mu_CC_MEC  14         10    1
#                1                    out_AV_nu  14          0    0
#          23    0                     nu_mu_NC  14         10    0
# 50       0     0                    out_AV_nu  14          1    1
#          1     0                    out_AV_nu  14          2    1
#                1                    out_AV_nu  14          0    0
#                2                     nu_mu_NC  14          1    0
#          2     0                     nu_mu_NC  14          1    0
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14         10    0
#          3     0                    out_AV_nu  14          0    1
#                1                     nu_mu_NC  14          0    0
#                2                    out_AV_nu  14          1    0
#          4     0                    out_AV_nu  14          0    1
#                1                     nu_mu_NC  14          0    0
#          5     0                    out_AV_nu  14          1    0
#                1                    out_AV_nu  14          2    1
#          6     0                 nu_mu_CC_Res  14          1    1
#          7     0                 nu_mu_CC_Res  14          1    1
#          8     0                    out_AV_nu  14          1    1
#          9     0                  nu_mu_CC_QE  14          0    1
#          10    0                    out_AV_nu  14          0    0
#          11    0                    out_AV_nu  14         10    1
#                1                    out_AV_nu  14          1    1
#          12    0                 nu_mu_CC_Res  14          1    1
#          13    0                    out_AV_nu  14          0    1
#          14    0                    out_AV_nu  14          0    1
#                1                  nu_mu_CC_QE  14          0    1
#          15    0                    out_AV_nu  14          0    1
#          16    0                    out_AV_nu  14          0    0
#                1                    out_AV_nu  14          0    0
# 4        0     0                    out_AV_nu  14          0    0
#                1                  nu_mu_CC_QE  14          0    1
#          1     0                 nu_mu_CC_Res  14          1    1
#                1                 nu_mu_CC_Res  14          1    1
#                2                    out_AV_nu  14         10    0
#          2     0                    out_AV_nu  14         10    0
#                1                 nu_mu_CC_MEC  14         10    1
#          3     0                    out_AV_nu  14          1    0
#          4     0                    out_AV_nu  14          2    1
#                1                    out_AV_nu  14          0    1
#          5     0                        other  12          1    1
#          6     0                    out_AV_nu  14          0    0
#                1                 nu_mu_CC_MEC  14         10    1
#          7     0                    out_AV_nu  12          1    1
#                1                    out_AV_nu  14          0    1
#          8     0                    out_AV_nu  14          0    1
#          9     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#          10    0                    out_AV_nu  14         10    1
#          11    0                    out_AV_nu  14          1    1
#                1                 nu_mu_CC_Res  14          1    1
#          12    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    0
#                2                    out_AV_nu  14          0    1
#                3                    out_AV_nu  14          1    1
#                4                    out_AV_nu  14          1    1
#                5                    out_AV_nu  14         10    0
#          13    0                    out_AV_nu  14          1    1
#                1                     nu_mu_NC  14          1    0
#          14    0                 nu_mu_CC_Res  14          1    1
#                1                    out_AV_nu  14          0    0
#          15    0                  nu_mu_CC_QE  14          0    1
#          16    0                    out_AV_nu  14          1    1
#          17    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    0
#          18    0                    out_AV_nu  14         10    1
#                1                  nu_mu_CC_QE  14          0    1
#          19    0                 nu_mu_CC_Dis  14          2    1
#          20    0                    out_AV_nu  14          0    1
#          21    0                     nu_mu_NC  14          0    0
#          22    0                  nu_mu_CC_QE  14          0    1
#          23    0                  nu_mu_CC_QE  14          0    1
#          24    0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          1    1
#          25    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          1    1
#                3                    out_AV_nu  14          0    0
# 59       0     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          2    0
#                2                 nu_mu_CC_Dis  14          2    1
#          1     0                    out_AV_nu  14         10    1
#                1                    out_AV_nu  14          0    1
#                2                  nu_mu_CC_QE  14          0    1
#          2     0                     nu_mu_NC  14          0    0
#          3     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14          1    1
#          4     0                  nu_mu_CC_QE  14          0    1
#          5     0                    out_AV_nu  14          0    1
#                1                    out_AV_nu  14          0    1
#                2                  nu_mu_CC_QE  14          0    1
#                3                    out_AV_nu  14          0    1
#                4                    out_AV_nu  14          0    1
#          6     0                    out_AV_nu  14          1    1
#                1                    out_AV_nu  14         10    1
#          7     0                  nu_mu_CC_QE  14          0    1
#          8     0                     nu_mu_NC  14          0    0
#                1                    out_AV_nu  14          0    1
#          9     0                  nu_mu_CC_QE  14          0    1
#          10    0                  nu_mu_CC_QE  14          0    1
#                1                    out_AV_nu  14          0    1
#                2                    out_AV_nu  14          0    0
#          11    0                     nu_mu_NC  14          1    0
#          12    0                    out_AV_nu  14          1    0
#                1                    out_AV_nu  14          0    0
#                2                    out_AV_nu  14          0    1
#          13    0                    out_AV_nu  14         10    1
#                1                    out_AV_nu  14          1    1
#                2                    out_AV_nu  14          1    1
#          14    0                  nu_mu_CC_QE  14          0    1
#          15    0                    out_AV_nu  14          1    1
#          16    0                     nu_mu_NC  14          0    0
#          17    0                 nu_mu_CC_MEC  14         10    1
#          18    0                    out_AV_nu  14          1    1
#                1                  nu_mu_CC_QE  14          0    1

# %%
matchdf = ph.multicol_merge(evt_df.reset_index(), nu_df.reset_index(),
                            left_on=[("__ntuple", "","","","",""),("entry", "","","","",""), ("slc", "tmatch","idx","","","")],
                            right_on=[("__ntuple", "","","","",""),("entry", "","","","",""), ("rec.mc.nu..index", "","","","","")], 
                            how="left") ## -- save all sllices
#Reindex so it is again "__ntuple","entry", "slice_id"
matchdf = matchdf.set_index(evt_df.index.names, verify_integrity=True)
#Remove "rec.mc.nu..index"
matchdf = matchdf.drop(columns=[('rec.mc.nu..index','','','','','')])
matchdf.loc[:, ('truth', 'nu_categ','','','','')] = (
    matchdf.loc[:, ('truth', 'nu_categ','','','','')].fillna('cosmic')
)

# %%
evt_df = matchdf

# %%
for column in matchdf.truth.columns:
    print(column)
# Out:
# ('E', '', '', '', '')
# ('baseline', '', '', '', '')
# ('time', '', '', '', '')
# ('bjorkenX', '', '', '', '')
# ('inelasticityY', '', '', '', '')
# ('Q2', '', '', '', '')
# ('w', '', '', '', '')
# ('momentum', 'x', '', '', '')
# ('momentum', 'y', '', '', '')
# ('momentum', 'z', '', '', '')
# ('position', 'x', '', '', '')
# ('position', 'y', '', '', '')
# ('position', 'z', '', '', '')
# ('pdg', '', '', '', '')
# ('iscc', '', '', '', '')
# ('genie_mode', '', '', '', '')
# ('parent_pdg', '', '', '', '')
# ('parent_dcy_E', '', '', '', '')
# ('genie_evtrec_idx', '', '', '', '')
# ('max_proton_ke', '', '', '', '')
# ('nprim', '', '', '', '')
# ('nn', '', '', '', '')
# ('np', '', '', '', '')
# ('nmu', '', '', '', '')
# ('npi', '', '', '', '')
# CC_mu_2pi: 0.0936479680078293 %, n_evts: 222
# NC: 0.7639480633431481 %, n_evts: 1811
# other_CC1pi: 0.17295345442887394 %, n_evts: 410
# CC_e: 0.033747015498316865 %, n_evts: 80

# %%
obvious_cosmic_mask = slc_df.slc.cut.obvious_cosmic == True
HelperFunctions.print_purity(slc_df[obvious_cosmic_mask])
# Out:
# Total evts:55185
# Purity
# out_AV_nu: 11.979704629881308 %, n_evts: 6611
# cosmic: 70.3125849415602 %, n_evts: 38802
# CC1pi: 1.5239648455196158 %, n_evts: 841
# CC_mu_0pi_1p: 6.780828123584308 %, n_evts: 3742
# CC_mu_0pi_2p: 2.3520884298269458 %, n_evts: 1298
# CC_mu_0pi_0p: 2.54054543807194 %, n_evts: 1402
# CC_mu_2pi: 0.39141070943191086 %, n_evts: 216
# NC: 3.243635045755187 %, n_evts: 1790
# other_CC1pi: 0.7338950801848328 %, n_evts: 405
# CC_e: 0.1413427561837456 %, n_evts: 78

# %%
t0_mask = slc_df.slc.cut.t0
HelperFunctions.print_purity(slc_df[obvious_cosmic_mask & t0_mask])
# Out:
# Total evts:14316
# Purity
# out_AV_nu: 32.64179938530316 %, n_evts: 4673
# cosmic: 7.914221849678682 %, n_evts: 1133
# CC1pi: 5.273819502654373 %, n_evts: 755
# CC_mu_0pi_1p: 23.407376362112323 %, n_evts: 3351
# CC_mu_0pi_2p: 8.284436993573625 %, n_evts: 1186
# CC_mu_0pi_0p: 8.340318524727577 %, n_evts: 1194
# CC_mu_2pi: 1.3202011735121542 %, n_evts: 189
# NC: 9.828164291701592 %, n_evts: 1407
# other_CC1pi: 2.5146689019279127 %, n_evts: 360
# CC_e: 0.47499301480860573 %, n_evts: 68

# %%
is_inside_FV_mask = slc_df.slc.cut.inside_FV == True
HelperFunctions.print_purity(slc_df[obvious_cosmic_mask & t0_mask & is_inside_FV_mask])
# Out:
# Total evts:9685
# Purity
# out_AV_nu: 8.002065049044916 %, n_evts: 775
# cosmic: 5.833763551884357 %, n_evts: 565
# CC1pi: 7.71295818275684 %, n_evts: 747
# CC_mu_0pi_1p: 34.1455859576665 %, n_evts: 3307
# CC_mu_0pi_2p: 12.028910686628807 %, n_evts: 1165
# CC_mu_0pi_0p: 11.935983479607641 %, n_evts: 1156
# CC_mu_2pi: 1.9204956117707797 %, n_evts: 186
# NC: 14.062983995869901 %, n_evts: 1362
# other_CC1pi: 3.6654620547237995 %, n_evts: 355
# CC_e: 0.6917914300464636 %, n_evts: 67

# %%
nu_score_mask = slc_df.slc.cut.nu_score == True
HelperFunctions.print_purity(slc_df[obvious_cosmic_mask & t0_mask & is_inside_FV_mask & nu_score_mask])
# Out:
# Total evts:5526
# Purity
# out_AV_nu: 4.83170466883822 %, n_evts: 267
# cosmic: 0.760043431053203 %, n_evts: 42
# CC1pi: 11.038726022439377 %, n_evts: 610
# CC_mu_0pi_1p: 39.974665218964894 %, n_evts: 2209
# CC_mu_0pi_2p: 15.182772348896128 %, n_evts: 839
# CC_mu_0pi_0p: 9.77198697068404 %, n_evts: 540
# CC_mu_2pi: 3.0582699963807456 %, n_evts: 169
# NC: 9.13861744480637 %, n_evts: 505
# other_CC1pi: 5.15743756786102 %, n_evts: 285
# CC_e: 1.0857763300760044 %, n_evts: 60

# %%
track_mask = slc_df.slc.cut.track == True
HelperFunctions.print_purity(slc_df[obvious_cosmic_mask & t0_mask & is_inside_FV_mask & nu_score_mask & track_mask])
# Out:
# Total evts:4041
# Purity
# out_AV_nu: 3.093293739173472 %, n_evts: 125
# cosmic: 0.3959415986142044 %, n_evts: 16
# CC1pi: 13.412521653056174 %, n_evts: 542
# CC_mu_0pi_1p: 47.414006434050975 %, n_evts: 1916
# CC_mu_0pi_2p: 19.203167532788914 %, n_evts: 776
# CC_mu_0pi_0p: 1.435288294976491 %, n_evts: 58
# CC_mu_2pi: 3.885176936401881 %, n_evts: 157
# NC: 5.023509032417718 %, n_evts: 203
# other_CC1pi: 5.691660480079189 %, n_evts: 230
# CC_e: 0.44543429844098 %, n_evts: 18

# %%
shower_mask = slc_df.slc.cut.shower == True
HelperFunctions.print_purity(slc_df[obvious_cosmic_mask & t0_mask & is_inside_FV_mask & nu_score_mask & track_mask & shower_mask])
# Out:
# Total evts:3237
# Purity
# out_AV_nu: 3.583565029348162 %, n_evts: 116
# cosmic: 0.3089280197713933 %, n_evts: 10
# CC1pi: 13.623725671918443 %, n_evts: 441
# CC_mu_0pi_1p: 51.99258572752549 %, n_evts: 1683
# CC_mu_0pi_2p: 19.30800123571208 %, n_evts: 625
# CC_mu_0pi_0p: 1.2357120790855731 %, n_evts: 40
# CC_mu_2pi: 2.0080321285140563 %, n_evts: 65
# NC: 4.324992276799506 %, n_evts: 140
# other_CC1pi: 3.5526722273710227 %, n_evts: 115
# CC_e: 0.06178560395427865 %, n_evts: 2

# %%
chi2_mask = slc_df.slc.cut.MIP_candidates == True
HelperFunctions.print_purity(slc_df[obvious_cosmic_mask & t0_mask & is_inside_FV_mask & nu_score_mask & track_mask & shower_mask & chi2_mask])
# Out:
# Total evts:666
# Purity
# out_AV_nu: 9.00900900900901 %, n_evts: 60
# cosmic: 0.6006006006006006 %, n_evts: 4
# CC1pi: 48.048048048048045 %, n_evts: 320
# CC_mu_0pi_1p: 20.42042042042042 %, n_evts: 136
# CC_mu_0pi_2p: 6.606606606606607 %, n_evts: 44
# CC_mu_0pi_0p: 1.6516516516516517 %, n_evts: 11
# CC_mu_2pi: 4.354354354354355 %, n_evts: 29
# NC: 3.1531531531531534 %, n_evts: 21
# other_CC1pi: 6.156156156156156 %, n_evts: 41
# CC_e: 0%, n_evts: 0

# %%
angle_mask = slc_df.slc.cut.angle == True
HelperFunctions.print_purity(slc_df[obvious_cosmic_mask & t0_mask & is_inside_FV_mask & nu_score_mask & track_mask & shower_mask & chi2_mask & angle_mask])
# Out:
# Total evts:601
# Purity
# out_AV_nu: 3.327787021630616 %, n_evts: 20
# cosmic: 0.33277870216306155 %, n_evts: 2
# CC1pi: 52.91181364392679 %, n_evts: 318
# CC_mu_0pi_1p: 21.46422628951747 %, n_evts: 129
# CC_mu_0pi_2p: 7.1547420965058235 %, n_evts: 43
# CC_mu_0pi_0p: 0.6655574043261231 %, n_evts: 4
# CC_mu_2pi: 4.658901830282862 %, n_evts: 28
# NC: 3.327787021630616 %, n_evts: 20
# other_CC1pi: 6.156405990016639 %, n_evts: 37
# CC_e: 0%, n_evts: 0

# %%
proton_BDT_mask = slc_df.slc.cut.proton_BDT == True
HelperFunctions.print_purity(slc_df[obvious_cosmic_mask & t0_mask & is_inside_FV_mask & nu_score_mask & track_mask & shower_mask & chi2_mask & angle_mask & proton_BDT_mask])
# Out:
# Total evts:421
# Purity
# out_AV_nu: 4.275534441805226 %, n_evts: 18
# cosmic: 0.2375296912114014 %, n_evts: 1
# CC1pi: 67.2209026128266 %, n_evts: 283
# CC_mu_0pi_1p: 8.551068883610451 %, n_evts: 36
# CC_mu_0pi_2p: 2.137767220902613 %, n_evts: 9
# CC_mu_0pi_0p: 0.7125890736342043 %, n_evts: 3
# CC_mu_2pi: 4.98812351543943 %, n_evts: 21
# NC: 3.8004750593824226 %, n_evts: 16
# other_CC1pi: 8.076009501187649 %, n_evts: 34
# CC_e: 0%, n_evts: 0

# %%
containment_mask = slc_df.slc.cut.containment == True
HelperFunctions.print_purity(slc_df[obvious_cosmic_mask & t0_mask & is_inside_FV_mask & nu_score_mask & track_mask & shower_mask & chi2_mask & angle_mask & containment_mask])
# Out:
# Total evts:496
# Purity
# out_AV_nu: 0.8064516129032258 %, n_evts: 4
# cosmic: 0.20161290322580644 %, n_evts: 1
# CC1pi: 56.653225806451616 %, n_evts: 281
# CC_mu_0pi_1p: 21.572580645161292 %, n_evts: 107
# CC_mu_0pi_2p: 6.048387096774194 %, n_evts: 30
# CC_mu_0pi_0p: 0.8064516129032258 %, n_evts: 4
# CC_mu_2pi: 4.435483870967742 %, n_evts: 22
# NC: 3.8306451612903225 %, n_evts: 19
# other_CC1pi: 5.645161290322581 %, n_evts: 28
# CC_e: 0%, n_evts: 0

# %%
filtered_df = slc_df[obvious_cosmic_mask & t0_mask & is_inside_FV_mask & nu_score_mask & track_mask & shower_mask & chi2_mask & angle_mask & containment_mask]

# %%
michel_mask = slc_df.slc.cut.michel == True
HelperFunctions.print_purity(filtered_df[michel_mask])
# Out:
# Total evts:487
# Purity
# out_AV_nu: 0.4106776180698152 %, n_evts: 2
# cosmic: 0%, n_evts: 0
# CC1pi: 57.28952772073922 %, n_evts: 279
# CC_mu_0pi_1p: 21.765913757700204 %, n_evts: 106
# CC_mu_0pi_2p: 6.160164271047228 %, n_evts: 30
# CC_mu_0pi_0p: 0.6160164271047228 %, n_evts: 3
# CC_mu_2pi: 4.517453798767967 %, n_evts: 22
# NC: 3.9014373716632442 %, n_evts: 19
# other_CC1pi: 5.338809034907597 %, n_evts: 26
# CC_e: 0%, n_evts: 0
# /tmp/ipykernel_1079094/600202323.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   HelperFunctions.print_purity(filtered_df[michel_mask])

# %%
extra_pion_mask = slc_df.slc.cut.extra_pion == True
HelperFunctions.print_purity(filtered_df[michel_mask & extra_pion_mask])
# Out:
# Total evts:472
# Purity
# out_AV_nu: 0.423728813559322 %, n_evts: 2
# cosmic: 0%, n_evts: 0
# CC1pi: 57.83898305084746 %, n_evts: 273
# CC_mu_0pi_1p: 22.45762711864407 %, n_evts: 106
# CC_mu_0pi_2p: 6.3559322033898304 %, n_evts: 30
# CC_mu_0pi_0p: 0.635593220338983 %, n_evts: 3
# CC_mu_2pi: 3.6016949152542375 %, n_evts: 17
# NC: 3.8135593220338984 %, n_evts: 18
# other_CC1pi: 4.872881355932203 %, n_evts: 23
# CC_e: 0%, n_evts: 0
# /tmp/ipykernel_1079094/2347761176.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   HelperFunctions.print_purity(filtered_df[michel_mask & extra_pion_mask])

# %%
proton_BDT_mask = slc_df.slc.cut.proton_BDT == True
#HelperFunctions.print_purity(filtered_df[michel_mask & extra_pion_mask &  proton_BDT_mask])
HelperFunctions.print_purity(filtered_df[proton_BDT_mask])
# Out:
# Total evts:354
# Purity
# out_AV_nu: 1.1299435028248588 %, n_evts: 4
# cosmic: 0.2824858757062147 %, n_evts: 1
# CC1pi: 70.33898305084746 %, n_evts: 249
# CC_mu_0pi_1p: 8.757062146892656 %, n_evts: 31
# CC_mu_0pi_2p: 2.2598870056497176 %, n_evts: 8
# CC_mu_0pi_0p: 0.847457627118644 %, n_evts: 3
# CC_mu_2pi: 5.084745762711864 %, n_evts: 18
# NC: 4.237288135593221 %, n_evts: 15
# other_CC1pi: 7.062146892655368 %, n_evts: 25
# CC_e: 0%, n_evts: 0
# /tmp/ipykernel_1079094/3404136063.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   HelperFunctions.print_purity(filtered_df[proton_BDT_mask])

# %%
def set_hep_style():
    mpl.rcParams.update({

        # -------------------------------------------------
        # Figure
        # -------------------------------------------------
        'figure.figsize': (8, 6),
        'figure.dpi': 100,
        'savefig.dpi': 300,
        'savefig.bbox': 'tight',

        # -------------------------------------------------
        # Fonts
        # -------------------------------------------------
        'font.family': 'sans-serif',
        'font.size': 14,
        'axes.labelsize': 16,
        'axes.titlesize': 16,
        'legend.fontsize': 12,

        # -------------------------------------------------
        # Axes
        # -------------------------------------------------
        'axes.linewidth': 2.0,
        'axes.edgecolor': 'black',
        'axes.grid': False,

        # -------------------------------------------------
        # Ticks (ROOT-like)
        # -------------------------------------------------
        'xtick.direction': 'in',
        'ytick.direction': 'in',
        'xtick.major.size': 8,
        'ytick.major.size': 8,
        'xtick.major.width': 2,
        'ytick.major.width': 2,
        'xtick.minor.size': 4,
        'ytick.minor.size': 4,
        'xtick.minor.width': 1.5,
        'ytick.minor.width': 1.5,
        'xtick.top': True,
        'ytick.right': True,

        # -------------------------------------------------
        # Histograms
        # -------------------------------------------------
        'hist.bins': 50,

        # -------------------------------------------------
        # Lines
        # -------------------------------------------------
        'lines.linewidth': 2.5,
        'lines.markersize': 6,

        # -------------------------------------------------
        # Legend
        # -------------------------------------------------
        'legend.frameon': True,
        'legend.framealpha': 1.0,
        'legend.edgecolor': 'black',
        'legend.fancybox': False,

    })

# %%
# Color map
MC_COLORS = [
    "#1f77b4",  # blue
    "#ff7f0e",  # orange
    "#2ca02c",  # green
    "#d62728",  # red
    "#9467bd",  # purple
    "#8c564b",  # brown
    "#e377c2",  # pink
    "#7f7f7f",  # gray
    "#bcbd22",  # olive
    "#17becf",  # cyan

    "#393b79",  # dark blue
    "#637939",  # dark green
    "#8c6d31",  # dark olive
    "#843c39",  # dark red
    "#7b4173",  # dark purple
    "#3182bd",  # steel blue
    "#31a354",  # teal green
    "#756bb1",  # muted violet
    "#636363",  # dark gray
    "#e6550d",  # burnt orange
]

# %%
from dataclasses import dataclass, field
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.colors import to_rgba

# --------------------------------------------------
# Config class (columns, bins, colors, labels)
# --------------------------------------------------
@dataclass
class HistogramConfig:
    data_column: tuple               # Column with the data to plot
    bins: np.ndarray = np.linspace(-0.5, 0.5, 51)
    color_map: dict = field(default_factory=dict)
    xlabel: str = 'Score'
    ylabel: str = 'Entries'
    title: str = None

# --------------------------------------------------
# Plotting function
# --------------------------------------------------
def plot_stacked_histogram(
    df,
    config: HistogramConfig,
    type_column: tuple,
    first_per_slice: bool = False,
):
    """
    Plot a stacked histogram using a HistogramConfig and an external type column.

    Parameters
    ----------
    df : pandas DataFrame
        The dataframe containing the data.
    config : HistogramConfig
        Configuration object with data_column, bins, colors, labels, and title.
    type_column : tuple
        Column used for stacking.
    first_per_slice : bool, optional
        If True, plot only the first PFP per slice
        (grouped by ['__ntuple', 'entry', 'rec.slc..index']).
        Default is False (use all rows).
    """

    slice_levels = ['__ntuple', 'entry', 'rec.slc..index']

    # Optionally reduce to first PFP per slice
    if first_per_slice:
        df = (
            df
            .groupby(level=slice_levels, sort=False)
            .first()
        )

    # Extract series
    data = df[config.data_column]
    types = df[type_column]

    # Unique type values (preserve order of appearance)
    type_values = list(types.dropna().unique())

    # Build stack data
    stack_data = {
        t: data[types == t].dropna()
        for t in type_values
    }

    # Colors (list-based, stable)
    colors = [MC_COLORS[i % len(MC_COLORS)] for i in range(len(type_values))]

    # Create figure
    fig, ax = plt.subplots()

    # Filled stack
    ax.hist(
        [stack_data[t] for t in type_values],
        bins=config.bins,
        stacked=True,
        histtype='stepfilled',
        color=colors,
        alpha=0.1,
        linewidth=0,
    )

    # Outline stack
    ax.hist(
        [stack_data[t] for t in type_values],
        bins=config.bins,
        stacked=True,
        histtype='step',
        color=colors,
        linewidth=2.0,
    )

    # Legend
    legend_handles = [
        Patch(
            facecolor=to_rgba(c, 0.1),
            edgecolor=to_rgba(c, 1.0),
            linewidth=2.0,
            label=t
        )
        for c, t in zip(colors, type_values)
    ]

    ax.set_xlabel(config.xlabel)
    ax.set_ylabel(config.ylabel)
    if config.title:
        ax.set_title(config.title)

    ax.legend(handles=legend_handles, loc='upper right')

    plt.show()

# %%
MIP_df = filtered_df[michel_mask & extra_pion_mask & ~CutMasks.exiting_pfp_mask(filtered_df) & CutMasks.is_MIP_candidate_mask(filtered_df)]
# Define config
config_bdt_proton = HistogramConfig(
    data_column=('pfp','trk','bdt_proton_score','','',''),
    bins=np.linspace(-0.5, 0.5, 51),
    xlabel='BDT proton score',
    ylabel='Entries',
    title='BDTProtonScore'
)

config_bdt_muon_pion = HistogramConfig(
    data_column=('pfp','trk','bdt_muon_pion_score','','',''),
    bins=np.linspace(-0.5, 0.5, 51),
    xlabel='BDT muon/pion score',
    ylabel='Entries',
    title='BDTMuonPionScore'
)

config_chi2mu = HistogramConfig(
    data_column=('pfp','trk','chi2pid','best','chi2_muon',''),
    bins=np.linspace(0, 60, 41),
    xlabel=r'$\text{primary tracks } \chi^{2}_{\mu}$',
    ylabel='Entries',
    title='Chi2mu'
)
config_chi2p = HistogramConfig(
    data_column=('pfp','trk','chi2pid','best','chi2_proton',''),
    bins=np.linspace(0, 300, 41),
    xlabel=r'$\text{primary tracks } \chi^{2}_{p}$',
    ylabel='Entries',
    title='Chi2p'
)

config_chi2exppol0 = HistogramConfig(
    data_column=('pfp','trk','chi2_exp_pol_3var','','',''),
    bins=np.linspace(0, 1.025, 42),
    xlabel=r'$\frac{\chi^{2}/ndf_{\mathrm{pol0}}}{\chi^{2}/ndf_{\mathrm{exp}}}$',
    ylabel='Entries',
    title='Chi2expol'
)

config_frac50 = HistogramConfig(
    data_column=('pfp','trk','frac50','','',''),
    bins=np.linspace(0, 1, 41),
    xlabel='residual range frac 50%',
    ylabel='Entries',
    title='Frac50'
)

config_max_daughter_hits = HistogramConfig(
    data_column=('pfp','max_daughter_hits','','','',''),
    bins=np.linspace(1, 200, 51),
    xlabel='max daughter hits',
    ylabel='Entries',
    title='max daughter hits'
)

config_scatter_angle = HistogramConfig(
    data_column=('pfp','scatter_angle_ratio','','','',''),
    bins=np.linspace(0, 1, 51),
    xlabel='scatter angle ratio',
    ylabel='Entries',
    title='scatter angle ratio'
)

configs = [ config_bdt_proton, config_bdt_muon_pion, 
            config_chi2mu, config_chi2p, config_chi2exppol0,
            config_frac50, config_max_daughter_hits, config_scatter_angle]

# Now we pass type_column explicitly
plot_stacked_histogram(
    MIP_df,
    config=config_frac50,
    type_column=('pfp','trk','truth','p','p_type',''),
    first_per_slice = False
)
# Out:
# /tmp/ipykernel_1079094/2167907629.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   MIP_df = filtered_df[michel_mask & extra_pion_mask & ~CutMasks.exiting_pfp_mask(filtered_df) & CutMasks.is_MIP_candidate_mask(filtered_df)]

# %%
filtered_df[('pfp','trk','bdt_proton_score','','','')]
# Out:
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
# 37        2      0               0                          0.122091
#                                  1                         -1.000000
#                                  2                          0.008726
#                                  3                         -1.000000
#                                  4                         -1.000000
#                                                               ...
# 1928      9      2               2                          0.089687
#                                  3                          0.038719
#                                  4                          0.028009
#                                  5                          0.011377
#                                  6                         -1.000000
# Name: (pfp, trk, bdt_proton_score, , , ), Length: 2384, dtype: float32

# %%
candidate_df = filtered_df[michel_mask & extra_pion_mask & CutMasks.is_MIP_candidate_mask(filtered_df)]
# Out:
# /tmp/ipykernel_1079094/1849082676.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   candidate_df = filtered_df[michel_mask & extra_pion_mask & CutMasks.is_MIP_candidate_mask(filtered_df)]

# %%
'''
def get_mu_pi_vars(group):
    # group has 2 rows (2 PFPs)

    exiting = CutMasks.exiting_pfp_mask(group)

    # Case 1️⃣: exactly one exiting PFP
    if exiting.sum() == 1:
        p_mu = group.loc[exiting].pfp.trk.mcsP.fwdP_muon.iloc[0]
        p_pi = group.loc[~exiting].pfp.trk.rangeP.p_pion.iloc[0]
        cos_theta_mu =  group.loc[exiting].pfp.trk.dir.z.iloc[0]
        cos_theta_pi =  group.loc[~exiting].pfp.trk.dir.z.iloc[0]
        muon_contained = False

    # Case 2️⃣: no exiting PFP
    else:
        group_sorted = group.sort_values(
            ('pfp','trk','bdt_muon_pion_score','','','')
        )

        p_mu = group_sorted.pfp.trk.rangeP.p_muon.iloc[1]
        p_pi = group_sorted.pfp.trk.rangeP.p_pion.iloc[0]
        cos_theta_mu =  group_sorted.pfp.trk.dir.z.iloc[1]
        cos_theta_pi =  group_sorted.pfp.trk.dir.z.iloc[0]
        muon_contained = True

    return pd.Series({
        'reco_p_mu': p_mu,
        'reco_p_pi': p_pi,
        'cos_theta_mu': cos_theta_mu,
        'cos_theta_pi': cos_theta_pi,
        'muon_contained': muon_contained,
    })
'''
# Out:
# "\ndef get_mu_pi_vars(group):\n    # group has 2 rows (2 PFPs)\n\n    exiting = CutMasks.exiting_pfp_mask(group)\n\n    # Case 1️⃣: exactly one exiting PFP\n    if exiting.sum() == 1:\n        p_mu = group.loc[exiting].pfp.trk.mcsP.fwdP_muon.iloc[0]\n        p_pi = group.loc[~exiting].pfp.trk.rangeP.p_pion.iloc[0]\n        cos_theta_mu =  group.loc[exiting].pfp.trk.dir.z.iloc[0]\n        cos_theta_pi =  group.loc[~exiting].pfp.trk.dir.z.iloc[0]\n        muon_contained = False\n\n    # Case 2️⃣: no exiting PFP\n    else:\n        group_sorted = group.sort_values(\n            ('pfp','trk','bdt_muon_pion_score','','','')\n        )\n\n        p_mu = group_sorted.pfp.trk.rangeP.p_muon.iloc[1]\n        p_pi = group_sorted.pfp.trk.rangeP.p_pion.iloc[0]\n        cos_theta_mu =  group_sorted.pfp.trk.dir.z.iloc[1]\n        cos_theta_pi =  group_sorted.pfp.trk.dir.z.iloc[0]\n        muon_contained = True\n\n    return pd.Series({\n        'reco_p_mu': p_mu,\n        'reco_p_pi': p_pi,\n        'cos_theta_mu': cos_theta_mu,\n        'cos_theta_pi': cos_theta_pi,\n        'muon_contained': muon_contained,\n    })\n"

# %%
group_levels = ['__ntuple','entry', 'rec.slc..index']

# %%
'''
resolved = (
    candidate_df
    .groupby(level=group_levels)
    .apply(get_mu_pi_vars)
)
'''
# Out:
# '\nresolved = (\n    candidate_df\n    .groupby(level=group_levels)\n    .apply(get_mu_pi_vars)\n)\n'

# %%
'''
p_mu_series = resolved['reco_p_mu']
p_pi_series = resolved['reco_p_pi']
cos_theta_mu_series = resolved['cos_theta_mu']
cos_theta_pi_series = resolved['cos_theta_pi']
muon_contained_series = resolved['muon_contained']
'''
# Out:
# "\np_mu_series = resolved['reco_p_mu']\np_pi_series = resolved['reco_p_pi']\ncos_theta_mu_series = resolved['cos_theta_mu']\ncos_theta_pi_series = resolved['cos_theta_pi']\nmuon_contained_series = resolved['muon_contained']\n"

# %%
'''
slcdf = pd.DataFrame({
    'muon_contained': muon_contained_series,
    'reco_p_mu': p_mu_series,
    'reco_p_pi': p_pi_series,
    'reco_cos_theta_mu_1': cos_theta_mu_series,
    'reco_cos_theta_pi_1': cos_theta_pi_series
})
    # Add column to df
slcdf.columns = pd.MultiIndex.from_tuples([('slc','measure_var',col,'','','') for col in slcdf.columns])        
candidate_df = candidate_df.join(slcdf)
'''
# Out:
# "\nslcdf = pd.DataFrame({\n    'muon_contained': muon_contained_series,\n    'reco_p_mu': p_mu_series,\n    'reco_p_pi': p_pi_series,\n    'reco_cos_theta_mu_1': cos_theta_mu_series,\n    'reco_cos_theta_pi_1': cos_theta_pi_series\n})\n    # Add column to df\nslcdf.columns = pd.MultiIndex.from_tuples([('slc','measure_var',col,'','','') for col in slcdf.columns])        \ncandidate_df = candidate_df.join(slcdf)\n"

# %%
# Define config
config_p_mu = HistogramConfig(
    data_column=('slc','measure_var','reco_p_mu','','',''),
    bins=np.linspace(0, 3, 41),
    xlabel='Pmu',
    ylabel='Entries',
    title='Pmu'
)

config_TLE_p_pi = HistogramConfig(
    data_column=('slc','measure_var','TLE_p_pi','','',''),
    bins=np.linspace(0.1,0.83, 41),
    xlabel='Ppi_TLE',
    ylabel='Entries',
    title='Ppi'
)

config_range_p_pi = HistogramConfig(
    data_column=('slc','measure_var','range_p_pi','','',''),
    bins=np.linspace(0.1, 0.8, 41),
    xlabel='range_p_pi',
    ylabel='Entries',
    title='Ppi'
)

config_costheta_mu = HistogramConfig(
    data_column=('slc','measure_var','reco_cos_theta_mu','','',''),
    bins=np.linspace(0, 1, 41),
    xlabel='costhetamu',
    ylabel='Entries',
    title='costhetamu'
)

config_costheta_pi = HistogramConfig(
    data_column=('slc','measure_var','reco_cos_theta_pi','','',''),
    bins=np.linspace(0, 1, 41),
    xlabel='costhetapi',
    ylabel='Entries',
    title='costhetapi'
)

# Now we pass type_column explicitly
plot_stacked_histogram(
    #candidate_df[candidate_df.slc.measure_var.muon_contained],
    candidate_df,
    config=config_range_p_pi,
    type_column=('truth','nu_categ','','','',''),
    first_per_slice = True
)

# %%
'''
import os
import ROOT
import subprocess
from ROOT import std

# 1. Setup Paths
base_path = "/home/lpelegri/cafpyana/analysis_village/cc1pi/TLExtensionMethod"
# Let's get the ROOT lib directory dynamically to ensure it's correct
try:
    root_lib_dir = subprocess.check_output(['root-config', '--libdir'], text=True).strip()
except:
    root_lib_dir = "/cvmfs/larsoft.opensciencegrid.org/products/root/v6_28_12/Linux64bit+3.10-2.17-e26-p3915-prof/lib"

# 2. Update Environment
os.environ['LD_LIBRARY_PATH'] = f"{root_lib_dir}:{os.environ.get('LD_LIBRARY_PATH', '')}"
ROOT.gSystem.AddDynamicPath(root_lib_dir)

# 3. Load the "Big" ROOT dependency blocks
# Loading these covers almost all physics class requirements (Hist, Geom, Graf, etc.)
root_libs = ["libRint","libROOTGpadv7","libMathMore","libCore", "libRIO", "libNet", "libHist", "libGraf", "libGraf3d", "libGpad", "libTree", "libMathCore", "libThread", "libMatrix", "libGeom","libROOTHist"]
for lib in root_libs:
    ROOT.gSystem.Load(lib)

def load_custom_class(class_name, extension="cpp"):
    source_file = os.path.join(base_path, f"{class_name}.{extension}")
    so_file = os.path.join(base_path, f"{class_name}_{extension}.so")
    
    # Try to load existing
    if os.path.exists(so_file):
        # We check return status: 0 = loaded, 1 = already loaded, -1 = failure
        if ROOT.gSystem.Load(so_file) >= 0:
            print(f"📦 Loaded: {class_name}")
            return True
    
    # If load failed or file missing, compile
    print(f"🛠️  Compiling: {class_name}...")
    return ROOT.gSystem.CompileMacro(source_file, "kO") >= 0

# 4. Run the sequence
if load_custom_class("PhysdEdx"):
    if load_custom_class("Hypfit"):
        from ROOT import Hypfit
        h_fit = Hypfit()
        print("🚀 Success! All libraries and dependencies are active.")
'''
# Out:
# '\nimport os\nimport ROOT\nimport subprocess\nfrom ROOT import std\n\n# 1. Setup Paths\nbase_path = "/home/lpelegri/cafpyana/analysis_village/cc1pi/TLExtensionMethod"\n# Let\'s get the ROOT lib directory dynamically to ensure it\'s correct\ntry:\n    root_lib_dir = subprocess.check_output([\'root-config\', \'--libdir\'], text=True).strip()\nexcept:\n    root_lib_dir = "/cvmfs/larsoft.opensciencegrid.org/products/root/v6_28_12/Linux64bit+3.10-2.17-e26-p3915-prof/lib"\n\n# 2. Update Environment\nos.environ[\'LD_LIBRARY_PATH\'] = f"{root_lib_dir}:{os.environ.get(\'LD_LIBRARY_PATH\', \'\')}"\nROOT.gSystem.AddDynamicPath(root_lib_dir)\n\n# 3. Load the "Big" ROOT dependency blocks\n# Loading these covers almost all physics class requirements (Hist, Geom, Graf, etc.)\nroot_libs = ["libRint","libROOTGpadv7","libMathMore","libCore", "libRIO", "libNet", "libHist", "libGraf", "libGraf3d", "libGpad", "libTree", "libMathCore", "libThread", "libMatrix", "libGeom","libROOTHist"]\nfor lib in root_libs:\n    ROOT.gSystem.Load(lib)\n\ndef load_custom_class(class_name, extension="cpp"):\n    source_file = os.path.join(base_path, f"{class_name}.{extension}")\n    so_file = os.path.join(base_path, f"{class_name}_{extension}.so")\n    \n    # Try to load existing\n    if os.path.exists(so_file):\n        # We check return status: 0 = loaded, 1 = already loaded, -1 = failure\n        if ROOT.gSystem.Load(so_file) >= 0:\n            print(f"📦 Loaded: {class_name}")\n            return True\n    \n    # If load failed or file missing, compile\n    print(f"🛠️  Compiling: {class_name}...")\n    return ROOT.gSystem.CompileMacro(source_file, "kO") >= 0\n\n# 4. Run the sequence\nif load_custom_class("PhysdEdx"):\n    if load_custom_class("Hypfit"):\n        from ROOT import Hypfit\n        h_fit = Hypfit()\n        print("🚀 Success! All libraries and dependencies are active.")\n'

# %%
candidate_df.pfp.trk.truth.p.columns
# Out:
# MultiIndex([( 'start_process',  ''),
#             (   'end_process',  ''),
#             (           'pdg',  ''),
#             (        'startE',  ''),
#             (          'endE',  ''),
#             (         'start', 'x'),
#             (         'start', 'y'),
#             (         'start', 'z'),
#             (           'end', 'x'),
#             (           'end', 'y'),
#             (           'end', 'z'),
#             (          'genp', 'x'),
#             (          'genp', 'y'),
#             (          'genp', 'z'),
#             (        'length',  ''),
#             (          'G4ID',  ''),
#             (        'parent',  ''),
#             (      'cont_tpc',  ''),
#             (          'genE',  ''),
#             ('interaction_id',  ''),
#             (   'crosses_tpc',  ''),
#             (        'p_type',  '')],
#            )

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Define the columns and categories
# Let's compare Hypfit to the standard Range momentum
col_a = ('slc','measure_var','TLE_p_pi','','','') # Hypfit result
col_b = ('truth', 'true_var', 'true_p_pi', '','','') # Reference/Standard result
type_column=('truth','nu_categ','','','','')

data = (candidate_df[col_a] - candidate_df[col_b])/candidate_df[col_a]
types = candidate_df[type_column]

# Unique type values (preserve order of appearance)
type_values = list(types.dropna().unique())

# Build stack data
stack_data = {
    t: data[types == t].dropna()
    for t in type_values
}

# Colors (list-based, stable)
colors = [MC_COLORS[i % len(MC_COLORS)] for i in range(len(type_values))]

# Create figure
fig, ax = plt.subplots()

# Filled stack
ax.hist(
    [stack_data[t] for t in type_values],
    bins=np.linspace(-1.5, 1.5, 41),
    stacked=True,
    histtype='stepfilled',
    color=colors,
    alpha=0.1,
    linewidth=0,
)

# Outline stack
ax.hist(
    [stack_data[t] for t in type_values],
    bins=np.linspace(-1.5, 1.5, 41),
    stacked=True,
    histtype='step',
    color=colors,
    linewidth=2.0,
)

# Legend
legend_handles = [
    Patch(
        facecolor=to_rgba(c, 0.1),
        edgecolor=to_rgba(c, 1.0),
        linewidth=2.0,
        label=t
    )
    for c, t in zip(colors, type_values)
]

ax.set_xlabel("res")
ax.set_ylabel("evts")

ax.legend(handles=legend_handles, loc='upper right')

plt.show()

# %%
#best_hit_df = best_hit_df.sort_values('rr', ascending=True)

# %%
hit0_df.index
# Out:
# MultiIndex([(  77,  0, 0, 0,  0),
#             (  77,  0, 0, 0,  1),
#             (  77,  0, 0, 0,  2),
#             (  77,  0, 0, 0,  3),
#             (  77,  0, 0, 0,  4),
#             (  77,  0, 0, 0,  5),
#             (  77,  0, 0, 0,  6),
#             (  77,  0, 0, 0,  7),
#             (  77,  0, 0, 0,  8),
#             (  77,  0, 0, 0,  9),
#             ...
#             (1928, 15, 0, 0,  1),
#             (1928, 15, 0, 0,  2),
#             (1928, 15, 0, 0,  3),
#             (1928, 15, 0, 0,  4),
#             (1928, 15, 0, 0,  5),
#             (1928, 15, 0, 0,  6),
#             (1928, 15, 0, 0,  7),
#             (1928, 15, 0, 0,  8),
#             (1928, 15, 0, 0,  9),
#             (1928, 15, 0, 0, 10)],
#            names=['__ntuple', 'entry', 'rec.slc..index', 'rec.slc.reco.pfp..index', 'rec.slc.reco.pfp.trk.calo.points..index'], length=15174995)

# %%
filtered_df[filtered_df.pfp.trk.truth.p.parent != 10000000].pfp.trk.truth.p.parent
# Out:
# __ntuple  entry  rec.slc..index  rec.slc.reco.pfp..index
#
# ('slc', 'truth', 'e', 'pdg', '', '')
# ('slc', 'truth', 'e', 'genp', 'x', '')
# ('slc', 'truth', 'e', 'genp', 'y', '')
# ('slc', 'truth', 'e', 'genp', 'z', '')
# ('slc', 'truth', 'e', 'start', 'x', '')
# ('slc', 'truth', 'e', 'start', 'y', '')
# ('slc', 'truth', 'e', 'start', 'z', '')
# ('slc', 'truth', 'e', 'end', 'x', '')
# ('slc', 'truth', 'e', 'end', 'y', '')
# ('slc', 'truth', 'e', 'end', 'z', '')
# ('slc', 'truth', 'e', 'interaction_id', '', '')
# ('slc', 'truth', 'e', 'crosses_tpc', '', '')
# ('slc', 'truth', 'e', 'contained', '', '')
# ('slc', 'truth', 'mu', 'totp', '', '')
# ('slc', 'truth', 'p', 'totp', '', '')
# ('slc', 'truth', 'mu', 'dir', 'x', '')
# ('slc', 'truth', 'mu', 'dir', 'y', '')
# ('slc', 'truth', 'mu', 'dir', 'z', '')
# ('slc', 'truth', 'p', 'dir', 'x', '')
# ('slc', 'truth', 'p', 'dir', 'y', '')
# ('slc', 'truth', 'p', 'dir', 'z', '')
# ('pfp', 'trk', 'producer', '', '', '')
# ('pfp', 'trk', 'start', 'x', '', '')
# ('pfp', 'trk', 'start', 'y', '', '')
# ('pfp', 'trk', 'start', 'z', '', '')
# ('pfp', 'trk', 'end', 'x', '', '')
# ('pfp', 'trk', 'end', 'y', '', '')
# ('pfp', 'trk', 'end', 'z', '', '')
# ('pfp', 'trk', 'dir', 'x', '', '')
# ('pfp', 'trk', 'dir', 'y', '', '')
# ('pfp', 'trk', 'dir', 'z', '', '')
# ('pfp', 'trk', 'len', '', '', '')
# ('pfp', 'trk', 'rangeP', 'p_muon', '', '')
# ('pfp', 'trk', 'mcsP', 'fwdP_muon', '', '')
# ('pfp', 'trk', 'rangeP', 'p_pion', '', '')
# ('pfp', 'trk', 'mcsP', 'fwdP_pion', '', '')
# ('pfp', 'trk', 'rangeP', 'p_proton', '', '')
# ('pfp', 'trk', 'mcsP', 'fwdP_proton', '', '')
# ('pfp', 'trk', 'bestplane', '', '', '')
# ('pfp', 'trk', 'crthit', 'distance', '', '')
# ('pfp', 'trk', 'crthit', 'hit', 'time', '')
# ('pfp', 'trk', 'crthit', 'hit', 'pe', '')
# ('pfp', 'trk', 'chi2pid', 'I0', 'pid_ndof', '')
# ('pfp', 'trk', 'chi2pid', 'I0', 'chi2_muon', '')
# ('pfp', 'trk', 'chi2pid', 'I0', 'chi2_proton', '')
# ('pfp', 'trk', 'chi2pid', 'I0', 'pida', '')
# ('pfp', 'trk', 'chi2pid', 'I1', 'pid_ndof', '')
# ('pfp', 'trk', 'chi2pid', 'I1', 'chi2_muon', '')
# ('pfp', 'trk', 'chi2pid', 'I1', 'chi2_proton', '')
# ('pfp', 'trk', 'chi2pid', 'I1', 'pida', '')
# ('pfp', 'trk', 'chi2pid', 'I2', 'pid_ndof', '')
# ('pfp', 'trk', 'chi2pid', 'I2', 'chi2_muon', '')
# ('pfp', 'trk', 'chi2pid', 'I2', 'chi2_proton', '')
# ('pfp', 'trk', 'chi2pid', 'I2', 'pida', '')
# ('pfp', 'trk', 'calo', 'I0', 'ke', '')
# ('pfp', 'trk', 'calo', 'I1', 'ke', '')
# ('pfp', 'trk', 'calo', 'I2', 'ke', '')
# ('pfp', 'parent_is_primary', '', '', '', '')
# ('pfp', 'slcID', '', '', '', '')
# ('pfp', 'trackScore', '', '', '', '')
# ('pfp', 'parent', '', '', '', '')
# ('pfp', 'id', '', '', '', '')
# ('pfp', 't0', '', '', '', '')
# ('pfp', 'pfochar', 'chgendfrac', '', '', '')
# ('pfp', 'pfochar', 'chgfracspread', '', '', '')
# ('pfp', 'pfochar', 'linfitdiff', '', '', '')
# ('pfp', 'pfochar', 'linfitlen', '', '', '')
# ('pfp', 'pfochar', 'linfitgaplen', '', '', '')
# ('pfp', 'pfochar', 'linfitrms', '', '', '')
# ('pfp', 'pfochar', 'openanglediff', '', '', '')
# ('pfp', 'pfochar', 'pca2ratio', '', '', '')
# ('pfp', 'pfochar', 'pca3ratio', '', '', '')
# ('pfp', 'pfochar', 'vtxdist', '', '', '')
# ('pfp', 'trk', 'truth', 'p', 'start_process', '')
# ('pfp', 'trk', 'truth', 'p', 'end_process', '')
# ('pfp', 'trk', 'truth', 'p', 'pdg', '')
# ('pfp', 'trk', 'truth', 'p', 'startE', '')
# ('pfp', 'trk', 'truth', 'p', 'endE', '')
# ('pfp', 'trk', 'truth', 'p', 'start', 'x')
# ('pfp', 'trk', 'truth', 'p', 'start', 'y')
# ('pfp', 'trk', 'truth', 'p', 'start', 'z')
# ('pfp', 'trk', 'truth', 'p', 'end', 'x')
# ('pfp', 'trk', 'truth', 'p', 'end', 'y')
# ('pfp', 'trk', 'truth', 'p', 'end', 'z')
# ('pfp', 'trk', 'truth', 'p', 'genp', 'x')
# ('pfp', 'trk', 'truth', 'p', 'genp', 'y')
# ('pfp', 'trk', 'truth', 'p', 'genp', 'z')
# ('pfp', 'trk', 'truth', 'p', 'length', '')
# ('pfp', 'trk', 'truth', 'p', 'G4ID', '')
# ('pfp', 'trk', 'truth', 'p', 'parent', '')
# ('pfp', 'trk', 'truth', 'p', 'cont_tpc', '')
# ('pfp', 'trk', 'truth', 'p', 'genE', '')
# ('pfp', 'trk', 'truth', 'p', 'interaction_id', '')
# ('pfp', 'trk', 'truth', 'p', 'crosses_tpc', '')
# ('pfp', 'tindex', '', '', '', '')
# ('pfp', 'dist_to_vertex', '', '', '', '')
# ('pfp', 'shw', 'bestplane_energy', '', '', '')
# ('pfp', 'nhit0', '', '', '', '')
# ('pfp', 'nhit1', '', '', '', '')
# ('pfp', 'nhit2', '', '', '', '')
# ('pfp', 'nhit', '', '', '', '')
# ('pfp', 'trk', 'chi2pid', 'best', 'chi2_muon', '')
# ('pfp', 'trk', 'chi2pid', 'best', 'chi2_proton', '')
# ('slc', 'measure_var', 'angle_between_candidates', '', '', '')
# ('pfp', 'max_daughter_hits', '', '', '', '')
# ('pfp', 'trk', 'calo', 'best', 'ke', '')
# ('pfp', 'trk', 'mean_dEdx', '', '', '')
# ('pfp', 'trk', 'chi2_exp_pol', '', '', '')
# ('pfp', 'trk', 'chi2_exp_pol_3var', '', '', '')
# ('pfp', 'trk', 'frac50', '', '', '')
# ('pfp', 'trk', 'bdt_proton_score', '', '', '')
# ('pfp', 'scatter_angle_ratio', '', '', '', '')
# ('pfp', 'trk', 'truth', 'p', 'p_type', '')
# ('truth', 'p', 'dir', 'z', '', '')
# ('truth', 'ind', '', '', '', '')
# ('truth', 'syst', 'Flux', 'univ_0', '', '')
# ('truth', 'syst', 'Flux', 'univ_1', '', '')
# ('truth', 'syst', 'Flux', 'univ_10', '', '')
# ('truth', 'syst', 'Flux', 'univ_11', '', '')
# ('truth', 'syst', 'Flux', 'univ_12', '', '')
# ('truth', 'syst', 'Flux', 'univ_13', '', '')
# ('truth', 'syst', 'Flux', 'univ_14', '', '')
# ('truth', 'syst', 'Flux', 'univ_15', '', '')
# ('truth', 'syst', 'Flux', 'univ_16', '', '')
# ('truth', 'syst', 'Flux', 'univ_17', '', '')
# ('truth', 'syst', 'Flux', 'univ_18', '', '')
# ('truth', 'syst', 'Flux', 'univ_19', '', '')
# ('truth', 'syst', 'Flux', 'univ_2', '', '')
# ('truth', 'syst', 'Flux', 'univ_20', '', '')
# ('truth', 'syst', 'Flux', 'univ_21', '', '')
# ('truth', 'syst', 'Flux', 'univ_22', '', '')
# ('truth', 'syst', 'Flux', 'univ_23', '', '')
# ('truth', 'syst', 'Flux', 'univ_24', '', '')
# ('truth', 'syst', 'Flux', 'univ_25', '', '')
# ('truth', 'syst', 'Flux', 'univ_26', '', '')
# ('truth', 'syst', 'Flux', 'univ_27', '', '')
# ('truth', 'syst', 'Flux', 'univ_28', '', '')
# ('truth', 'syst', 'Flux', 'univ_29', '', '')
# ('truth', 'syst', 'Flux', 'univ_3', '', '')
# ('truth', 'syst', 'Flux', 'univ_30', '', '')
# ('truth', 'syst', 'Flux', 'univ_31', '', '')
# ('truth', 'syst', 'Flux', 'univ_32', '', '')
# ('truth', 'syst', 'Flux', 'univ_33', '', '')
# ('truth', 'syst', 'Flux', 'univ_34', '', '')
# ('truth', 'syst', 'Flux', 'univ_35', '', '')
# ('truth', 'syst', 'Flux', 'univ_36', '', '')
# ('truth', 'syst', 'Flux', 'univ_37', '', '')
# ('truth', 'syst', 'Flux', 'univ_38', '', '')
# ('truth', 'syst', 'Flux', 'univ_39', '', '')
# ('truth', 'syst', 'Flux', 'univ_4', '', '')
# ('truth', 'syst', 'Flux', 'univ_40', '', '')
# ('truth', 'syst', 'Flux', 'univ_41', '', '')
# ('truth', 'syst', 'Flux', 'univ_42', '', '')
# ('truth', 'syst', 'Flux', 'univ_43', '', '')
# ('truth', 'syst', 'Flux', 'univ_44', '', '')
# ('truth', 'syst', 'Flux', 'univ_45', '', '')
# ('truth', 'syst', 'Flux', 'univ_46', '', '')
# ('truth', 'syst', 'Flux', 'univ_47', '', '')
# ('truth', 'syst', 'Flux', 'univ_48', '', '')
# ('truth', 'syst', 'Flux', 'univ_49', '', '')
# ('truth', 'syst', 'Flux', 'univ_5', '', '')
# ('truth', 'syst', 'Flux', 'univ_50', '', '')
# ('truth', 'syst', 'Flux', 'univ_51', '', '')
# ('truth', 'syst', 'Flux', 'univ_52', '', '')
# ('truth', 'syst', 'Flux', 'univ_53', '', '')
# ('truth', 'syst', 'Flux', 'univ_54', '', '')
# ('truth', 'syst', 'Flux', 'univ_55', '', '')
# ('truth', 'syst', 'Flux', 'univ_56', '', '')
# ('truth', 'syst', 'Flux', 'univ_57', '', '')
# ('truth', 'syst', 'Flux', 'univ_58', '', '')
# ('truth', 'syst', 'Flux', 'univ_59', '', '')
# ('truth', 'syst', 'Flux', 'univ_6', '', '')
# ('truth', 'syst', 'Flux', 'univ_60', '', '')
# ('truth', 'syst', 'Flux', 'univ_61', '', '')
# ('truth', 'syst', 'Flux', 'univ_62', '', '')
# ('truth', 'syst', 'Flux', 'univ_63', '', '')
# ('truth', 'syst', 'Flux', 'univ_64', '', '')
# ('truth', 'syst', 'Flux', 'univ_65', '', '')
# ('truth', 'syst', 'Flux', 'univ_66', '', '')
# ('truth', 'syst', 'Flux', 'univ_67', '', '')
# ('truth', 'syst', 'Flux', 'univ_68', '', '')
# ('truth', 'syst', 'Flux', 'univ_69', '', '')
# ('truth', 'syst', 'Flux', 'univ_7', '', '')
# ('truth', 'syst', 'Flux', 'univ_70', '', '')
# ('truth', 'syst', 'Flux', 'univ_71', '', '')
# ('truth', 'syst', 'Flux', 'univ_72', '', '')
# ('truth', 'syst', 'Flux', 'univ_73', '', '')
# ('truth', 'syst', 'Flux', 'univ_74', '', '')
# ('truth', 'syst', 'Flux', 'univ_75', '', '')
# ('truth', 'syst', 'Flux', 'univ_76', '', '')
# ('truth', 'syst', 'Flux', 'univ_77', '', '')
# ('truth', 'syst', 'Flux', 'univ_78', '', '')
# ('truth', 'syst', 'Flux', 'univ_79', '', '')
# ('truth', 'syst', 'Flux', 'univ_8', '', '')
# ('truth', 'syst', 'Flux', 'univ_80', '', '')
# ('truth', 'syst', 'Flux', 'univ_81', '', '')
# ('truth', 'syst', 'Flux', 'univ_82', '', '')
# ('truth', 'syst', 'Flux', 'univ_83', '', '')
# ('truth', 'syst', 'Flux', 'univ_84', '', '')
# ('truth', 'syst', 'Flux', 'univ_85', '', '')
# ('truth', 'syst', 'Flux', 'univ_86', '', '')
# ('truth', 'syst', 'Flux', 'univ_87', '', '')
# ('truth', 'syst', 'Flux', 'univ_88', '', '')
# ('truth', 'syst', 'Flux', 'univ_89', '', '')
# ('truth', 'syst', 'Flux', 'univ_9', '', '')
# ('truth', 'syst', 'Flux', 'univ_90', '', '')
# ('truth', 'syst', 'Flux', 'univ_91', '', '')
# ('truth', 'syst', 'Flux', 'univ_92', '', '')
# ('truth', 'syst', 'Flux', 'univ_93', '', '')
# ('truth', 'syst', 'Flux', 'univ_94', '', '')
# ('truth', 'syst', 'Flux', 'univ_95', '', '')
# ('truth', 'syst', 'Flux', 'univ_96', '', '')
# ('truth', 'syst', 'Flux', 'univ_97', '', '')
# ('truth', 'syst', 'Flux', 'univ_98', '', '')
# ('truth', 'syst', 'Flux', 'univ_99', '', '')
# ('truth', 'syst', 'GENIE', 'univ_0', '', '')
# ('truth', 'syst', 'GENIE', 'univ_1', '', '')
# ('truth', 'syst', 'GENIE', 'univ_10', '', '')
# ('truth', 'syst', 'GENIE', 'univ_11', '', '')
