# %%
import pandas as pd
import pathlib
import glob
import os
import numpy as np
import warnings
import pyanalib.split_df_helpers as splh

# 1. Suppress the annoying warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from tables import NaturalNameWarning
warnings.filterwarnings('ignore', category=NaturalNameWarning)
import os, sys, pathlib, glob
import pandas as pd
import numpy as np
import pyanalib.split_df_helpers as splh

def consolidate_buffered(folder_path, output_name, split_margin_gb=1.0):
    """
    Consolidates files by buffering them in memory and saving to a new split 
    whenever the buffer exceeds split_margin_gb.
    Removes initial files upon successful completion.
    """
    out_dir = pathlib.Path("/exp/sbnd/data/users/lpelegri/cafpyana_data")
    out_dir.mkdir(parents=True, exist_ok=True)
    output_file = out_dir / f"{output_name}.df"

    input_folder = pathlib.Path(folder_path)
    files = sorted(glob.glob(str(input_folder / f"*{output_name}*.df")))
    
    if not files:
        print(f"No files found for {output_name}")
        return

    # 1. Discover keys
    with pd.HDFStore(files[0], mode='r') as store:
        keys2load = [k.lstrip('/').rsplit('_', 1)[0] for k in store.keys() if 'split' not in k]
        keys2load = sorted(list(set(keys2load)))

    df_buffers = {k: [] for k in keys2load}
    size_counters = {k: 0 for k in keys2load}
    k_idx = 0 
    total_ntuples_seen = 0 

    print(f"Starting buffered consolidation for {len(files)} files...")

    # Use context manager to ensure the output file is closed properly before deletion starts
    with pd.HDFStore(output_file, mode='w') as hdf_out:
        for file_path in files:
            print(f"Reading {os.path.basename(file_path)}...")
            file_data = splh.load_dfs(file_path, keys2load)
            
            current_file_ntuples = 0
            for df in file_data.values():
                if df is not None:
                    current_file_ntuples = len(df.index.get_level_values("__ntuple").unique())
                    break

            for k in keys2load:
                df = file_data[k]
                if df is not None:
                    # Update __ntuple levels with global offset
                    old_ntuple_level = df.index.get_level_values("__ntuple")
                    new_ntuple_level = old_ntuple_level + total_ntuples_seen
                    df.index = df.index.set_levels(new_ntuple_level.unique(), level="__ntuple")

                    size_gb = df.memory_usage(deep=True).sum() / (1024**3)
                    size_counters[k] += size_gb
                    df_buffers[k].append(df)
            
            total_ntuples_seen += current_file_ntuples
            
            if any(val >= split_margin_gb for val in size_counters.values()):
                print(f"--- Buffer limit reached. Flushing to split_{k_idx} ---")
                for k in keys2load:
                    if df_buffers[k]:
                        concat_df = pd.concat(df_buffers[k], ignore_index=False)
                        hdf_out.put(key=f"{k}_{k_idx}", value=concat_df, format="fixed")
                        df_buffers[k] = []
                        size_counters[k] = 0
                k_idx += 1
            
            del file_data

        if any(len(b) > 0 for b in df_buffers.values()):
            print(f"--- Final Flush: split_{k_idx} ---")
            for k in keys2load:
                if df_buffers[k]:
                    concat_df = pd.concat(df_buffers[k], ignore_index=False)
                    hdf_out.put(key=f"{k}_{k_idx}", value=concat_df, format="fixed")
            k_idx += 1

        hdf_out.put(key="split", value=pd.DataFrame({"n_split": [k_idx]}), format="fixed")

    print(f"\nConsolidation finished. Total splits created: {k_idx}")

    # --- CLEANUP: Remove initial files ---
    print(f"Cleaning up {len(files)} initial files...")
    for file_path in files:
        try:
            os.remove(file_path)
        except OSError as e:
            print(f"Error deleting {file_path}: {e}")

    print("Cleanup Complete!")
    return output_file

file_list = ["cc1pi_5e18_CV"]

# --- Usage ---
SOURCE = "/exp/sbnd/data/users/lpelegri/cafpyana_data_transfer_folder"
NAME = file_list[0]

consolidate_buffered(SOURCE, NAME)
# Out:
# Starting buffered consolidation for 100 files...
# Reading cc1pi_5e18_CV_0.df...
# Reading cc1pi_5e18_CV_1.df...
# Reading cc1pi_5e18_CV_10.df...
# Reading cc1pi_5e18_CV_11.df...
# Reading cc1pi_5e18_CV_12.df...
# Reading cc1pi_5e18_CV_13.df...
# Reading cc1pi_5e18_CV_14.df...
# Reading cc1pi_5e18_CV_15.df...
# Reading cc1pi_5e18_CV_16.df...
# Reading cc1pi_5e18_CV_17.df...
# Reading cc1pi_5e18_CV_18.df...
# Reading cc1pi_5e18_CV_19.df...
# Reading cc1pi_5e18_CV_2.df...
# Reading cc1pi_5e18_CV_20.df...
# Reading cc1pi_5e18_CV_21.df...
# Reading cc1pi_5e18_CV_22.df...
# Reading cc1pi_5e18_CV_23.df...
# Reading cc1pi_5e18_CV_24.df...
# Reading cc1pi_5e18_CV_25.df...
# Reading cc1pi_5e18_CV_26.df...
# Reading cc1pi_5e18_CV_27.df...
# Reading cc1pi_5e18_CV_28.df...
# Reading cc1pi_5e18_CV_29.df...
# Reading cc1pi_5e18_CV_3.df...
# Reading cc1pi_5e18_CV_30.df...
# Reading cc1pi_5e18_CV_31.df...
# Reading cc1pi_5e18_CV_32.df...
# Reading cc1pi_5e18_CV_33.df...
# Reading cc1pi_5e18_CV_34.df...
# Reading cc1pi_5e18_CV_35.df...
# Reading cc1pi_5e18_CV_36.df...
# Reading cc1pi_5e18_CV_37.df...
# Reading cc1pi_5e18_CV_38.df...
# Reading cc1pi_5e18_CV_39.df...
# Reading cc1pi_5e18_CV_4.df...
# Reading cc1pi_5e18_CV_40.df...
# Reading cc1pi_5e18_CV_41.df...
# Reading cc1pi_5e18_CV_42.df...
# Reading cc1pi_5e18_CV_43.df...
# Reading cc1pi_5e18_CV_44.df...
# Reading cc1pi_5e18_CV_45.df...
# Reading cc1pi_5e18_CV_46.df...
# Reading cc1pi_5e18_CV_47.df...
# Reading cc1pi_5e18_CV_48.df...
# Reading cc1pi_5e18_CV_49.df...
# Reading cc1pi_5e18_CV_5.df...
# Reading cc1pi_5e18_CV_50.df...
# Reading cc1pi_5e18_CV_51.df...
# Reading cc1pi_5e18_CV_52.df...
# Reading cc1pi_5e18_CV_53.df...
# Reading cc1pi_5e18_CV_54.df...
# Reading cc1pi_5e18_CV_55.df...
# Reading cc1pi_5e18_CV_56.df...
# Reading cc1pi_5e18_CV_57.df...
# Reading cc1pi_5e18_CV_58.df...
# Reading cc1pi_5e18_CV_59.df...
# Reading cc1pi_5e18_CV_6.df...
# Reading cc1pi_5e18_CV_60.df...
# Reading cc1pi_5e18_CV_61.df...
# Reading cc1pi_5e18_CV_62.df...
# Reading cc1pi_5e18_CV_63.df...
# Reading cc1pi_5e18_CV_64.df...
# Reading cc1pi_5e18_CV_65.df...
# Reading cc1pi_5e18_CV_66.df...
# Reading cc1pi_5e18_CV_67.df...
# Reading cc1pi_5e18_CV_68.df...
# Reading cc1pi_5e18_CV_69.df...
# Reading cc1pi_5e18_CV_7.df...
# Reading cc1pi_5e18_CV_70.df...
# Reading cc1pi_5e18_CV_71.df...
# Reading cc1pi_5e18_CV_72.df...
# Reading cc1pi_5e18_CV_73.df...
# Reading cc1pi_5e18_CV_74.df...
# Reading cc1pi_5e18_CV_75.df...
# Reading cc1pi_5e18_CV_76.df...
# Reading cc1pi_5e18_CV_77.df...
# Reading cc1pi_5e18_CV_78.df...
# Reading cc1pi_5e18_CV_79.df...
# Reading cc1pi_5e18_CV_8.df...
# Reading cc1pi_5e18_CV_80.df...
# Reading cc1pi_5e18_CV_81.df...
# Reading cc1pi_5e18_CV_82.df...
# Reading cc1pi_5e18_CV_83.df...
# Reading cc1pi_5e18_CV_84.df...
# Reading cc1pi_5e18_CV_85.df...
# Reading cc1pi_5e18_CV_86.df...
# Reading cc1pi_5e18_CV_87.df...
# Reading cc1pi_5e18_CV_88.df...
# Reading cc1pi_5e18_CV_89.df...
# Reading cc1pi_5e18_CV_9.df...
# Reading cc1pi_5e18_CV_90.df...
# Reading cc1pi_5e18_CV_91.df...
# Reading cc1pi_5e18_CV_92.df...
# Reading cc1pi_5e18_CV_93.df...
# Reading cc1pi_5e18_CV_94.df...
# Reading cc1pi_5e18_CV_95.df...
# Reading cc1pi_5e18_CV_96.df...
# Reading cc1pi_5e18_CV_97.df...
# Reading cc1pi_5e18_CV_98.df...
# Reading cc1pi_5e18_CV_99.df...
# --- Final Flush: split_0 ---
#
# Consolidation finished. Total splits created: 1
# Cleaning up 100 initial files...
# Cleanup Complete!
# PosixPath('/exp/sbnd/data/users/lpelegri/cafpyana_data/consolidated_cc1pi_5e18_CV.df')
