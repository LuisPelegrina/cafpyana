# %%
# %load_ext autoreload
# %autoreload

# %%
import pandas as pd
import numpy as np
from os import path, makedirs
from datetime import datetime
from functools import partial
import gc

import sys
print('Importing cafpyana utils...')
cafpyana_root = "/home/lpelegri/cafpyana"
# Add CAFpyana to the Python search path -- this will allow you to import cafpyana modules
sys.path.insert(0, cafpyana_root)

from pyanalib.split_df_helpers import *
from analysis_village.cc1pi.systematics.final_variable_configs import VariableConfig
from analysis_village.cc1pi.systematics.utils import *
from analysis_village.cc1pi.systematics.constants import *
from pyanalib.covariance import *
from analysis_village.cc1pi.DataFrameUtils.DFLoading import *
from analysis_village.cc1pi.Constants import CTE as CTE
from analysis_village.cc1pi.CutMasks.MaskUtils import *
from analysis_village.cc1pi.CutMasks.CutMasks import *
from analysis_village.cc1pi.HelperFunctions import HelperFunctions

from makedf.mcstat import get_MCstat_unc

from analysis_village.cc1pi.var_configs import *

# turn off PerformanceWarning 
# triggered by mismatched column levels
import warnings
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning)
# Out:
# Importing cafpyana utils...
# mc_tot_pot: 4.516e+18
# Integrated flux: 7.293e+10
# Integrated flux: 1.615e+02
# # of targets:  1.4154995096228214e+30
# 72932100000.0
# xsec unit:  9.686604534848245e-42
# Importing cafpyana utils...

# %% [markdown]
# # Load df

# %%
pot_weight_col = ('slc', 'wgt', '', '', '', '')
# BNB data
'''
data_tot_pot = data_hdr_df['pot'].sum()
data_gates = data_hdr_df.nbnbinfo.sum()
'''
print("data_tot_pot: %.3e" %(data_tot_pot))
print("data tot gates : %.3e" %(data_gates))
#data_evt_df[pot_weight_col] = np.ones(len(data_evt_df))
# Out:
# data_tot_pot: 4.516e+18
# data tot gates : 9.481e+05

# %%
#Load systematics df
#syst_names = ["2xSCE", "PMTGainFluct","PMTHighNoise", "PMTLowEff", "CCalVar", "$C_{cal}$ Variation"]

syst_keys = ["SystVarsCV","wiremod_YZ","wiremod_XZ_thetaXW", "0xSCE","2xSCE","PMTGainFluct", "PMTHighNoise", "PMTLowEff", "ccalm", "ccalp", "alpham", "alphap", "rm", "rp", "betam", "betap"]
colors = ["black", "C0","C1","C2","C3","C4","C5","C6","C7","C8","C9","C10","C11","C12","C13","C14","C15","C16"]
labels    = ["CV", r"Wiremod Y-Z",r"Wiremod X$\theta_{xw}$", "0xSCE", "2xSCE","PMTGainFluct", "PMTHighNoise", "PMTLowEff", "ccalm", "ccalp", "alpham", "alphap", "rm", "rp", "betam", "betap"]

detvar_plotter = partial(
    variation_hists,
    var_colors=colors,
    var_labels=labels,
    approval="internal"
)

detvar_plotter_final_vars = partial(
    variation_hists_final_vars,
    var_colors=colors,
    var_labels=labels,
    approval="internal"
)

keys2load = ["cc1pi", "hdr", "histpotdf", "nudf"] ## keys from the configuration file
syst_evt_dfs = {}

for key in syst_keys:
    syst_df = load_df(f"/exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_{key}.df",keys2load,100, filter_df = False)
    syst_tot_pot = syst_df['hdr']['pot'].sum()
    print("syst_pot: %.3e" %(syst_tot_pot))
    syst_pot_scale = data_tot_pot / syst_tot_pot
    print(syst_pot_scale)
    cols_to_keep_mc = [
        ('nu_categ', '', '', ''),
        ('nu_categ_proton_reduced', '', '', ''),
        ('genie_categ', '', '', ''),
        ('genie_mode', '', '', ''),
    ]

    cols_to_keep_reco = [
        ('slc', 'self', '', '', '', ''),
        ('slc', 'tmatch', 'idx', '', '', ''),
        ('slc', 'nu_score', '', '', '', ''),
        ('slc', 'cut', 'obvious_cosmic', '', '', ''),
        ('slc', 'cut', 't0', '', '', ''),
        ('slc', 'cut', 'inside_FV', '', '', ''),
        ('slc', 'cut', 'nu_score', '', '', ''),
        ('slc', 'cut', 'track', '', '', ''),
        ('slc', 'cut', 'shower', '', '', ''),
        ('slc', 'cut', 'MIP_candidates', '', '', ''),
        ('slc', 'cut', 'angle', '', '', ''),
        ('slc', 'cut', 'proton_BDT', '', '', ''),
        ('slc', 'cut', 'proton_BDT_sideband', '', '', ''),
        ('slc', 'cut', 'containment', '', '', ''),
        ('slc', 'cut', 'michel', '', '', ''),
        ('slc', 'cut', 'extra_pion', '', '', ''),
        ('slc','cut','energy','','',''),
        ('slc','cut_var','n_MIP_candidates','','',''),
        ('slc', 'measure_var', 'angle_between_candidates', '', '', ''),
        ('slc', 'measure_var', 'num_protons', '', '', ''),
        ('slc','measure_var','reco_p_mu','','',''),
        ('slc','measure_var','reco_cos_theta_mu','','',''),
        ('slc','measure_var','TLE_p_pi','','',''),
        ('slc','measure_var','range_p_pi','','',''),
        ('slc','measure_var','reco_cos_theta_pi','','',''), 
        ('slc','measure_var','delta_pT','','',''),
        ('slc','measure_var','delta_alpha_T','','',''),
        ('slc','measure_var','delta_phi_T','','',''),
        ('slc','measure_var','mu_true_p_type','','',''),
        ('slc','measure_var','pi_true_p_type','','',''),
        ('slc','measure_var','mu_true_pdg','','',''),
        ('slc','measure_var','pi_true_pdg','','',''),
        ('slc','measure_var','pi_true_p','','',''),
        ('slc','measure_var','mu_true_p','','',''),
        ('slc','measure_var','pi_true_costheta','','',''),
        ('slc','measure_var','mu_true_costheta','','',''),
        ('slc','measure_var','muon_contained','','',''),
    ]
    
       
    syst_evt_dfs[key] = syst_df['cc1pi']
    mask = build_event_cumulative_masks(syst_evt_dfs[key] , sideband = "")["energy"]
    syst_evt_dfs[key] = syst_evt_dfs[key][mask]
    syst_evt_dfs[key] = syst_evt_dfs[key][cols_to_keep_reco]
    syst_evt_dfs[key][pot_weight_col] = syst_pot_scale * np.ones(len(syst_evt_dfs[key])) 

    syst_evt_dfs[key] = (
        syst_evt_dfs[key]
        .groupby(['__ntuple', 'entry', 'rec.slc..index'])
        .first()
    )   
    
    syst_evt_dfs[key] = perform_truth_matching(syst_evt_dfs[key], syst_df['nudf'][cols_to_keep_mc])
     
    HelperFunctions.print_purity(syst_evt_dfs[key], ('truth','nu_categ','','','',''))
# Out:
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_SystVarsCV.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/cc1pi_6', '/cc1pi_7', '/cc1pi_8', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/hdr_6', '/hdr_7', '/hdr_8', '/histgenevtdf_0', '/histgenevtdf_1', '/histgenevtdf_2', '/histgenevtdf_3', '/histgenevtdf_4', '/histgenevtdf_5', '/histgenevtdf_6', '/histgenevtdf_7', '/histgenevtdf_8', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/histpotdf_6', '/histpotdf_7', '/histpotdf_8', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/nudf_6', '/nudf_7', '/nudf_8', '/split']
# n_split: 9
# dataframes
# loaded!
# 1.4578133e+20
# Changing CC1pi
# Adding proton BDT sidebans
# Adding TPC containment
# Adding FV
# Adding high y z
# Finish
# Change energy
# Reprocessing truth
# CHANGING nudf
# syst_pot: 1.458e+20
# 0.03097988
# Total weighted slices: 370.302
# Purity (weighted / total weighted)
#
# $\nu_{\mu}$CC1$\pi^{\pm}$: purity: 74.6173%  counts: 276.310
# $\nu_{e}$CC: purity: 0.0837%  counts: 0.310
# $\nu_{\mu}$CC0$\pi^{\pm}$0p: purity: 1.2633%  counts: 4.678
# $\nu_{\mu}$CC0$\pi^{\pm}$1p: purity: 7.0192%  counts: 25.992
# $\nu_{\mu}$CC0$\pi^{\pm}2^{+}p$: purity: 3.4636%  counts: 12.826
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 3.7564%  counts: 13.910
# NC: purity: 6.6594%  counts: 24.660
# cosmic: purity: 0.1171%  counts: 0.434
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 2.4931%  counts: 9.232
# out-AV $\nu$: purity: 0.5271%  counts: 1.952
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_wiremod_YZ.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/cc1pi_6', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/hdr_6', '/histgenevtdf_0', '/histgenevtdf_1', '/histgenevtdf_2', '/histgenevtdf_3', '/histgenevtdf_4', '/histgenevtdf_5', '/histgenevtdf_6', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/histpotdf_6', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/nudf_6', '/split']
# n_split: 7
# dataframes
# loaded!
# 1.1201559e+20
# Changing CC1pi
# Adding proton BDT sidebans
# Adding TPC containment
# Adding FV
# Adding high y z
# Finish
# Change energy
# Reprocessing truth
# CHANGING nudf
# syst_pot: 1.120e+20
# 0.04031839
# Total weighted slices: 363.269
# Purity (weighted / total weighted)
#
# $\nu_{\mu}$CC1$\pi^{\pm}$: purity: 74.6171%  counts: 271.061
# $\nu_{e}$CC: purity: 0.0888%  counts: 0.323
# $\nu_{\mu}$CC0$\pi^{\pm}$0p: purity: 1.2986%  counts: 4.717
# $\nu_{\mu}$CC0$\pi^{\pm}$1p: purity: 6.8257%  counts: 24.796
# $\nu_{\mu}$CC0$\pi^{\pm}2^{+}p$: purity: 3.6737%  counts: 13.345
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 4.0954%  counts: 14.877
# NC: purity: 6.4262%  counts: 23.344
# cosmic: purity: 0.1998%  counts: 0.726
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 2.2531%  counts: 8.185
# out-AV $\nu$: purity: 0.5216%  counts: 1.895
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_wiremod_XZ_thetaXW.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/cc1pi_6', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/hdr_6', '/histgenevtdf_0', '/histgenevtdf_1', '/histgenevtdf_2', '/histgenevtdf_3', '/histgenevtdf_4', '/histgenevtdf_5', '/histgenevtdf_6', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/histpotdf_6', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/nudf_6', '/split']
# n_split: 7
# dataframes
# loaded!
# 1.1204851e+20
# Changing CC1pi
# Adding proton BDT sidebans
# Adding TPC containment
# Adding FV
# Adding high y z
# Finish
# Change energy
# Reprocessing truth
# CHANGING nudf
# syst_pot: 1.120e+20
# 0.040306542
# Total weighted slices: 373.642
# Purity (weighted / total weighted)
#
# $\nu_{\mu}$CC1$\pi^{\pm}$: purity: 75.0378%  counts: 280.372
# $\nu_{e}$CC: purity: 0.0971%  counts: 0.363
# $\nu_{\mu}$CC0$\pi^{\pm}$0p: purity: 1.2729%  counts: 4.756
# $\nu_{\mu}$CC0$\pi^{\pm}$1p: purity: 6.7961%  counts: 25.393
# $\nu_{\mu}$CC0$\pi^{\pm}2^{+}p$: purity: 3.5599%  counts: 13.301
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 3.6677%  counts: 13.704
# NC: purity: 6.3215%  counts: 23.620
# cosmic: purity: 0.1618%  counts: 0.605
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 2.4703%  counts: 9.230
# out-AV $\nu$: purity: 0.6149%  counts: 2.297
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_0xSCE.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/cc1pi_6', '/cc1pi_7', '/cc1pi_8', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/hdr_6', '/hdr_7', '/hdr_8', '/histgenevtdf_0', '/histgenevtdf_1', '/histgenevtdf_2', '/histgenevtdf_3', '/histgenevtdf_4', '/histgenevtdf_5', '/histgenevtdf_6', '/histgenevtdf_7', '/histgenevtdf_8', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/histpotdf_6', '/histpotdf_7', '/histpotdf_8', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/nudf_6', '/nudf_7', '/nudf_8', '/split']
# n_split: 9
# dataframes
# loaded!
# 1.39097325e+20
# Changing CC1pi
# Adding proton BDT sidebans
# Adding TPC containment
# Adding FV
# Adding high y z
# Finish
# Change energy
# Reprocessing truth
# CHANGING nudf
# syst_pot: 1.391e+20
# 0.032468546
# Total weighted slices: 373.908
# Purity (weighted / total weighted)
#
# $\nu_{\mu}$CC1$\pi^{\pm}$: purity: 74.5050%  counts: 278.580
# $\nu_{e}$CC: purity: 0.0521%  counts: 0.195
# $\nu_{\mu}$CC0$\pi^{\pm}$0p: purity: 1.3286%  counts: 4.968
# $\nu_{\mu}$CC0$\pi^{\pm}$1p: purity: 6.9642%  counts: 26.040
# $\nu_{\mu}$CC0$\pi^{\pm}2^{+}p$: purity: 3.4734%  counts: 12.987
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 3.8729%  counts: 14.481
# NC: purity: 6.5561%  counts: 24.514
# cosmic: purity: 0.1129%  counts: 0.422
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 2
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 3.7430%  counts: 13.787
# NC: purity: 6.7121%  counts: 24.724
# cosmic: purity: 0.1178%  counts: 0.434
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 2.5486%  counts: 9.388
# out-AV $\nu$: purity: 0.5131%  counts: 1.890
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_alphap.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/cc1pi_6', '/cc1pi_7', '/cc1pi_8', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/hdr_6', '/hdr_7', '/hdr_8', '/histgenevtdf_0', '/histgenevtdf_1', '/histgenevtdf_2', '/histgenevtdf_3', '/histgenevtdf_4', '/histgenevtdf_5', '/histgenevtdf_6', '/histgenevtdf_7', '/histgenevtdf_8', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/histpotdf_6', '/histpotdf_7', '/histpotdf_8', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/nudf_6', '/nudf_7', '/nudf_8', '/split']
# n_split: 9
# dataframes
# loaded!
# 1.4576628e+20
# Changing CC1pi
# Adding proton BDT sidebans
# Adding TPC containment
# Adding FV
# Adding high y z
# Finish
# Change energy
# Reprocessing truth
# CHANGING nudf
# syst_pot: 1.458e+20
# 0.03098308
# Total weighted slices: 378.768
# Purity (weighted / total weighted)
#
# $\nu_{\mu}$CC1$\pi^{\pm}$: purity: 73.9223%  counts: 279.994
# $\nu_{e}$CC: purity: 0.0818%  counts: 0.310
# $\nu_{\mu}$CC0$\pi^{\pm}$0p: purity: 1.2434%  counts: 4.709
# $\nu_{\mu}$CC0$\pi^{\pm}$1p: purity: 7.5174%  counts: 28.473
# $\nu_{\mu}$CC0$\pi^{\pm}2^{+}p$: purity: 3.6646%  counts: 13.880
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 3.6564%  counts: 13.849
# NC: purity: 6.7648%  counts: 25.623
# cosmic: purity: 0.1145%  counts: 0.434
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 2.5358%  counts: 9.605
# out-AV $\nu$: purity: 0.4990%  counts: 1.890
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_rm.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/cc1pi_6', '/cc1pi_7', '/cc1pi_8', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/hdr_6', '/hdr_7', '/hdr_8', '/histgenevtdf_0', '/histgenevtdf_1', '/histgenevtdf_2', '/histgenevtdf_3', '/histgenevtdf_4', '/histgenevtdf_5', '/histgenevtdf_6', '/histgenevtdf_7', '/histgenevtdf_8', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/histpotdf_6', '/histpotdf_7', '/histpotdf_8', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/nudf_6', '/nudf_7', '/nudf_8', '/split']
# n_split: 9
# dataframes
# loaded!
# 1.45758905e+20
# Changing CC1pi
# Adding proton BDT sidebans
# Adding TPC containment
# Adding FV
# Adding high y z
# Finish
# Change energy
# Reprocessing truth
# CHANGING nudf
# syst_pot: 1.458e+20
# 0.030984646
# Total weighted slices: 374.326
# Purity (weighted / total weighted)
#
# $\nu_{\mu}$CC1$\pi^{\pm}$: purity: 74.2819%  counts: 278.056
# $\nu_{e}$CC: purity: 0.0745%  counts: 0.279
# $\nu_{\mu}$CC0$\pi^{\pm}$0p: purity: 1.2499%  counts: 4.679
# $\nu_{\mu}$CC0$\pi^{\pm}$1p: purity: 7.2511%  counts: 27.143
# $\nu_{\mu}$CC0$\pi^{\pm}2^{+}p$: purity: 3.6007%  counts: 13.478
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 3.6504%  counts: 13.664
# NC: purity: 6.7379%  counts: 25.222
# cosmic: purity: 0.1159%  counts: 0.434
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 2.5329%  counts: 9.481
# out-AV $\nu$: purity: 0.5049%  counts: 1.890
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_rp.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/cc1pi_6', '/cc1pi_7', '/cc1pi_8', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/hdr_6', '/hdr_7', '/hdr_8', '/histgenevtdf_0', '/histgenevtdf_1', '/histgenevtdf_2', '/histgenevtdf_3', '/histgenevtdf_4', '/histgenevtdf_5', '/histgenevtdf_6', '/histgenevtdf_7', '/histgenevtdf_8', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/histpotdf_6', '/histpotdf_7', '/histpotdf_8', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/nudf_6', '/nudf_7', '/nudf_8', '/split']
# n_split: 9
# dataframes
# loaded!
# 1.45766355e+20
# Changing CC1pi
# Adding proton BDT sidebans
# Adding TPC containment
# Adding FV
# Adding high y z
# Finish
# Change energy
# Reprocessing truth
# CHANGING nudf
# syst_pot: 1.458e+20
# 0.030983062
# Total weighted slices: 373.129
# Purity (weighted / total weighted)
#
# $\nu_{\mu}$CC1$\pi^{\pm}$: purity: 74.3253%  counts: 277.329
# $\nu_{e}$CC: purity: 0.0747%  counts: 0.279
# $\nu_{\mu}$CC0$\pi^{\pm}$0p: purity: 1.2538%  counts: 4.678
# $\nu_{\mu}$CC0$\pi^{\pm}$1p: purity: 7.2573%  counts: 27.079
# $\nu_{\mu}$CC0$\pi^{\pm}2^{+}p$: purity: 3.5539%  counts: 13.261
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 3.6785%  counts: 13.725
# NC: purity: 6.6927%  counts: 24.972
# cosmic: purity: 0.1163%  counts: 0.434
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 2.5409%  counts: 9.481
# out-AV $\nu$: purity: 0.5065%  counts: 1.890
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_betam.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/cc1pi_6', '/cc1pi_7', '/cc1pi_8', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/hdr_6', '/hdr_7', '/hdr_8', '/histgenevtdf_0', '/histgenevtdf_1', '/histgenevtdf_2', '/histgenevtdf_3', '/histgenevtdf_4', '/histgenevtdf_5', '/histgenevtdf_6', '/histgenevtdf_7', '/histgenevtdf_8', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/histpotdf_6', '/histpotdf_7', '/histpotdf_8', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/nudf_6', '/nudf_7', '/nudf_8', '/split']
# n_split: 9
# dataframes
# loaded!
# 1.4578133e+20
# Changing CC1pi
# Adding proton BDT sidebans
# Adding TPC containment
# Adding FV
# Adding high y z
# Finish
# Change energy
# Reprocessing truth
# CHANGING nudf
# syst_pot: 1.458e+20
# 0.03097988
# Total weighted slices: 377.955
# Purity (weighted / total weighted)
#
# $\nu_{\mu}$CC1$\pi^{\pm}$: purity: 74.2213%  counts: 280.523
# $\nu_{e}$CC: purity: 0.0820%  counts: 0.310
# $\nu_{\mu}$CC0$\pi^{\pm}$0p: purity: 1.2377%  counts: 4.678
# $\nu_{\mu}$CC0$\pi^{\pm}$1p: purity: 7.2705%  counts: 27.479
# $\nu_{\mu}$CC0$\pi^{\pm}2^{+}p$: purity: 3.6475%  counts: 13.786
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 3.6230%  counts: 13.693
# NC: purity: 6.7705%  counts: 25.589
# cosmic: purity: 0.1148%  counts: 0.434
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 2.5328%  counts: 9.573
# out-AV $\nu$: purity: 0.5000%  counts: 1.890
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_betap.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/cc1pi_6', '/cc1pi_7', '/cc1pi_8', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/hdr_6', '/hdr_7', '/hdr_8', '/histgenevtdf_0', '/histgenevtdf_1', '/histgenevtdf_2', '/histgenevtdf_3', '/histgenevtdf_4', '/histgenevtdf_5', '/histgenevtdf_6', '/histgenevtdf_7', '/histgenevtdf_8', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/histpotdf_6', '/histpotdf_7', '/histpotdf_8', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/nudf_6', '/nudf_7', '/nudf_8', '/split']
# n_split: 9
# dataframes
# loaded!
# 1.4575809e+20
# Changing CC1pi
# Adding proton BDT sidebans
# Adding TPC containment
# Adding FV
# Adding high y z
# Finish
# Change energy
# Reprocessing truth
# CHANGING nudf
# syst_pot: 1.458e+20
# 0.030984819
# Total weighted slices: 368.533
# Purity (weighted / total weighted)
#
# $\nu_{\mu}$CC1$\pi^{\pm}$: purity: 74.3568%  counts: 274.030
# $\nu_{e}$CC: purity: 0.0757%  counts: 0.279
# $\nu_{\mu}$CC0$\pi^{\pm}$0p: purity: 1.2780%  counts: 4.710
# $\nu_{\mu}$CC0$\pi^{\pm}$1p: purity: 7.1128%  counts: 26.213
# $\nu_{\mu}$CC0$\pi^{\pm}2^{+}p$: purity: 3.4892%  counts: 12.859
# $\nu_{\mu}$CC2$^{+}\pi^{\pm}$: purity: 3.7666%  counts: 13.881
# NC: purity: 6.7261%  counts: 24.788
# cosmic: purity: 0.1177%  counts: 0.434
# Excluded 1$\mu$1$\pi^{\pm}$: purity: 2.5559%  counts: 9.419
# out-AV $\nu$: purity: 0.5213%  counts: 1.921

# %% [markdown]
# # Get all the syst uncert

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import os

# --- 1. Pretty Label Mapping ---
# Maps raw systematic keys to publication-quality LaTeX labels
pretty_label_map = {
    "CV": "Nominal (CV)",
    "wiremod_YZ": r"WireMod $Y$-$Z$",
    "wiremod_XZ_thetaXW": r"WireMod $X\theta_{xw}$",
    "0xSCE": "0xSCE",
    "2xSCE": "2xSCE",
    "PMTGainFluct": "PMT Gain Fluctuation",
    "PMTHighNoise": "PMT High Noise",
    "PMTLowEff": "PMT Low Efficiency",
    "phi": r"Recomb. $\phi$ model",
    "ccal": r"Recomb. $C_{cal}$",
    "alpha": r"Recomb. $\alpha$",
    "r": r"Recomb. $R$",
    "beta": r"Recomb. $\beta_{90}$"
}# --- 2. Configuration ---


bkg_substract = True
extra_string = ""
if not bkg_substract:
    extra_string = "_rate_no_bkg_substract"

save_result = True
save_fig = save_result
save_fig_dir = "/exp/sbnd/data/users/lpelegri/Graphs/syst/detector" + extra_string

if save_fig:
    if not path.exists(save_fig_dir):
        makedirs(save_fig_dir)
    print("saving plots in ", save_fig_dir)
    

unisim_keys = []
paired_syst = {} 
file_dir = "/exp/sbnd/data/users/lpelegri/syst/frac_cov_matrices" + extra_string
os.makedirs(file_dir, exist_ok=True)

if 'syst_dict' not in locals():
    syst_dict = {}

var_configs = [
    VariableConfig.all_evts(), 
    VariableConfig.muon_momentum(),
    VariableConfig.muon_direction(),
    VariableConfig.pion_momentum(),
    VariableConfig.pion_direction(),
    VariableConfig.angle_between_candidates(),
    VariableConfig.num_protons(),
    VariableConfig.num_protons_two(),
    VariableConfig.delta_pt(),
    VariableConfig.delta_alpha_T(),
    VariableConfig.delta_phi_T()
]

# Identify Unisim (1 univ) vs Paired/Multisim (2 univ)
for key in syst_keys:
    if key == "SystVarsCV": continue
    if key.endswith('m') or key.endswith('p'):
        base = key[:-1]
        if base not in paired_syst:
            paired_syst[base] = [None, None]
        if key.endswith('m'): paired_syst[base][0] = key
        else: paired_syst[base][1] = key
    else:
        unisim_keys.append(key)

# --- 3. Main Variable Loop ---
for var_config in var_configs:
    GROUP_LEVELS = ['__ntuple', 'entry', 'rec.slc..index']
    
    evtdfs = [syst_evt_dfs[syst_key].groupby(level=['__ntuple', 'entry', 'rec.slc..index'], sort=False).first() for syst_key in syst_evt_dfs.keys()]
    
    n = detvar_plotter_final_vars(
        evtdfs,
        var_name=var_config.var_evt_reco_col,
        bins=var_config.bins,
        plot=False,
    )
    
    key_to_idx = {key: i for i, key in enumerate(syst_evt_dfs)}
    cv_events = n[0]
    
    if bkg_substract:
        signal_evtdfs = [df[df.truth.nu_categ == "CC1pi"] for df in evtdfs]
    
        n_only_signal = detvar_plotter_final_vars(
            signal_evtdfs,
            var_name=var_config.var_evt_reco_col,
            bins=var_config.bins,
            plot=False,
        )
    
        bkg_cv = n[0] - n_only_signal[0]
        cv_events = n_only_signal[0]
    
        for i in range(1, len(n)):
            n[i] -= bkg_cv
 
    ret_dict = {}

    print(cv_events)
    # Covariance Calculations
    for syst_key in unisim_keys:
        kidx = key_to_idx[syst_key]
        ret_dict[syst_key] = get_covariance_matrix(np.array([n[kidx]]), cv_events)
        print(f"{syst_key} {n[kidx]}")
        
    for base_name, keys in paired_syst.items():
        m_idx, p_idx = key_to_idx.get(keys[0]), key_to_idx.get(keys[1])
        if m_idx is not None and p_idx is not None:
            ret_dict[base_name] = get_covariance_matrix(np.array([n[m_idx], n[p_idx]]), cv_events)

    # Aggregate Total Uncertainty
    total_cov_frac = None
    total_cov = None
    uncertanties_list = []
    
    for syst_key, ret in ret_dict.items():
        frac_unc = np.sqrt(np.diag(ret["cov_frac"]))
        uncertanties_list.append((frac_unc, syst_key))
        
        if total_cov_frac is None: total_cov_frac = ret["cov_frac"].copy()
        else: total_cov_frac += ret["cov_frac"]
            
        if total_cov is None: total_cov = ret["cov"].copy()
        else: total_cov += ret["cov"]

    
    total_corr = corr_from_fraccov(total_cov)

    f_name = f"detector_{var_config.var_save_name}_frac_cov.pdf" 
    save_full_path = os.path.join(save_fig_dir, f_name)
       
    plot_heatmap(total_cov_frac, 
            var_config.bins, 
            plot_labels=[var_config.var_labels[1], var_config.var_labels[1], "Fractional Covariance"],
            save_fig=save_fig, save_name=save_full_path)

    f_name = f"detector_{var_config.var_save_name}_cov.pdf" 
    save_full_path = os.path.join(save_fig_dir, f_name)
    plot_heatmap(total_cov, 
            var_config.bins, 
            plot_labels=[var_config.var_labels[1], var_config.var_labels[1], "Covariance"],
            save_fig=save_fig, save_name=save_full_path)
        
    f_name = f"detector_{var_config.var_save_name}_corr.pdf" 
    save_full_path = os.path.join(save_fig_dir, f_name)
    plot_heatmap(total_corr, 
            var_config.bins, 
            plot_labels=[var_config.var_labels[1], var_config.var_labels[1], "Correlation"],
            save_fig=save_fig, save_name=save_full_path)

    # --- 4. Plotting ---
    fig, ax = plt.subplots(figsize=(8, 6))
    total_values = np.sqrt(np.diag(total_cov_frac)) * 100 

    # SORT BY IMPORTANCE (Integral of uncertainty)
    sorted_uncertanties = sorted(uncertanties_list, key=lambda x: np.sum(x[0]), reverse=True)
    
    for frac_unc, syst_key in sorted_uncertanties:
        display_label = pretty_label_map.get(syst_key, syst_key.replace("_", " "))
        ax.hist(
            var_config.bin_centers,
            bins=var_config.bins,
            weights=frac_unc * 1e2,
            histtype="step",
            linewidth=2,
            label=display_label,
            zorder=3
        )

    ax.hist(
        var_config.bin_centers,
        bins=var_config.bins,
        weights=total_values,
        histtype="step",
        linewidth=2,
        color="k",
        label="Total",
        zorder=15  # Ensure the total is always on top
    )
    
    # Formatting
    ax.legend(loc="upper center", ncol=3, fontsize=12, frameon=True, edgecolor='gray')
    ax.set_xlim(var_config.bins[0], var_config.bins[-1])
    ax.set_ylim(0, max(total_values) * 1.6) 
    ax.set_xlabel(var_config.var_labels[1])
    ax.set_ylabel("Uncertainty [%]")
    
    ax.grid(which='major', linestyle='-', linewidth=0.7, alpha=0.7)
    ax.grid(which='minor', linestyle=':', linewidth=0.5, alpha=0.5)
    ax.minorticks_on()
    
    plt.tight_layout()
    plt.savefig(os.path.join(save_fig_dir, f"detvar_{var_config.var_save_name}.png"), dpi=300)
    plt.show()

    # Store for NPZ
    syst_dict[var_config.var_save_name] = total_cov_frac
    for key, ret in ret_dict.items():
        syst_dict[f"{var_config.var_save_name}_{key}"] = ret["cov_frac"]

# Final Save
if save_result:
    np.savez(os.path.join(file_dir, "detvar_syst_dict.npz"), **syst_dict)
# Out:
# saving plots in  /exp/sbnd/data/users/lpelegri/Graphs/syst/detector_rate_no_bkg_substract
# [370.30249608]
# wiremod_YZ [363.26868031]
# wiremod_XZ_thetaXW [373.64164498]
# 0xSCE [373.90777783]
# 2xSCE [372.55713686]
# PMTGainFluct [363.68159339]
# PMTHighNoise [361.07237773]
# PMTLowEff [372.50495455]
# [112.4569615   98.63993537  88.478535    70.72706421]
# wiremod_YZ [111.19811546  95.91744622  87.69249497  68.46062366]
# wiremod_XZ_thetaXW [114.95425798  98.30765611  89.35960377  71.02012713]
# 0xSCE [112.92560362  99.09400295  90.42490112  71.46327015]
# 2xSCE [112.13034118  99.44911676  89.32260502  71.65507391]
# PMTGainFluct [110.88581041  96.48173511  85.95568009  70.35836779]
# PMTHighNoise [110.59196862  95.41267881  85.63243669  69.43529362]
# PMTLowEff [115.2728346   98.81092637  88.11265987  70.30853371]
# [119.55135383  90.74006618  75.03326742  84.97780865]
# wiremod_YZ [115.75409336  88.82140985  74.75029226  83.94288484]
# wiremod_XZ_thetaXW [121.92728976  89.80297573  75.9778318   85.93354769]
# 0xSCE [119.15956449  91.98339133  76.43095771  86.3338643 ]
# 2xSCE [120.13305562  91.3540633   75.50253278  85.56748517]
# PMTGainFluct [117.10768908  88.3421541   73.51192273  84.71982747]
# PMTHighNoise [115.45996244  90.32341255  72.002054    83.28694876]
# PMTLowEff [121.6286313   90.52075676  76.26956043  84.08600606]
# [ 93.094537    86.8366014  105.98216674  84.38919094]
# wiremod_YZ [ 94.06280035  86.5232617  106.64213756  76.0404807 ]
# wiremod_XZ_thetaXW [ 95.24435891  86.94121124 105.56283368  85.89324115]
# 0xSCE [ 94.93802904  87.24298359 106.91892258  84.80784263]
# 2xSCE [ 94.52436941  87.19880773 106.4976614   84.33629833]
# PMTGainFluct [ 91.62355587  84.03797776 105.00485659  83.01520318]
