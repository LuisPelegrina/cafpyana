# %%
# %load_ext autoreload
# %autoreload

# %%
import pandas as pd
import numpy as np
from os import path, makedirs
from datetime import datetime
from functools import partial
import gc

# local imports
import sys
sys.path.append('../../../')
from pyanalib.split_df_helpers import *
from analysis_village.cc1pi.systematics.final_variable_configs import VariableConfig
from analysis_village.cc1pi.systematics.utils import *
from analysis_village.cc1pi.systematics.constants import *
from pyanalib.covariance import *
from analysis_village.cc1pi.DataFrameUtils.DFLoading import *
from analysis_village.cc1pi.Constants import CTE as CTE
from analysis_village.cc1pi.CutMasks.MaskUtils import *
from analysis_village.cc1pi.CutMasks.CutMasks import *

from makedf.mcstat import get_MCstat_unc

from analysis_village.cc1pi.var_configs import *

# turn off PerformanceWarning 
# triggered by mismatched column levels
import warnings
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning)
# Out:
# mc_tot_pot: 5.947e+18
# Integrated flux: 9.604e+10
# Integrated flux: 1.615e+02
# # of targets:  1.4154995096228214e+30
# xsec unit:  7.356229423996019e-42
# Importing cafpyana utils...

# %%
save_result = True
save_fig = save_result
save_fig_dir = "/exp/sbnd/data/users/lpelegri/Graphs/syst/detector"

if save_fig:
    if not path.exists(save_fig_dir):
        makedirs(save_fig_dir)
    print("saving plots in ", save_fig_dir)
# Out:
# saving plots in  /exp/sbnd/data/users/lpelegri/Graphs/syst/detector

# %% [markdown]
# # Load df

# %%
pot_weight_col = ('slc', 'wgt', '', '', '', '')

#Load data
keys2load = ["cc1pi", "hdr", "histpotdf"] ## keys from the configuration file
data_df = load_df("/exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_data_rollingdev_bnblight.df", keys2load, 100)
data_evt_df = data_df['cc1pi']
data_hdr_df = data_df['hdr']

# BNB data
# data_tot_pot = data_hdr_df['TOR875'].sum()
data_tot_pot = data_hdr_df['pot'].sum()
print("data_tot_pot: %.3e" %(data_tot_pot))
pot_str = f"{data_tot_pot} $\\times 10^{18}$"
data_evt_df[pot_weight_col] = np.ones(len(data_evt_df))
data_gates = data_hdr_df.nbnbinfo.sum()
print("data tot gates : %.3e" %(data_gates))
# Out:
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_data_rollingdev_bnblight.df
# Keys: ['/cc1pi_0', '/hdr_0', '/histpotdf_0', '/pot_0', '/split']
# n_split: 1
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_data_rollingdev_bnblight.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# data_tot_pot: 5.948e+18
# data tot gates : 1.251e+06

# %%
#Load systematics df
#syst_names = ["2xSCE", "PMTGainFluct","PMTHighNoise", "PMTLowEff", "CCalVar", "$C_{cal}$ Variation"]
syst_keys = ["SystVarsCV","wiremod_YZ","wiremod_XZ_thetaXW", "0xSCE","2xSCE","PMTGainFluct", "PMTHighNoise", "PMTLowEff", "ccalm", "ccalp", "alpham", "alphap", "rm", "rp", "betam", "betap"]
colors = ["black", "C0","C1","C2","C3","C4","C5","C6","C7","C8","C9","C10","C11","C12","C13","C14","C15","C16"]
labels    = ["CV", r"Wiremod Y-Z",r"Wiremod X$\theta_{xw}$", "0xSCE", "2xSCE","PMTGainFluct", "PMTHighNoise", "PMTLowEff", "ccalm", "ccalp", "alpham", "alphap", "rm", "rp", "betam", "betap"]

'''
syst_keys = ["SystVarsCV","wiremod_YZ", "ccalm", "ccalp"]
colors = ["black", "C0","C1","C2","C3","C4","C5","C6","C7","C8","C9","C10","C11","C12","C13","C14","C15","C16"]
labels    = ["CV", r"Wiremod Y-Z", "ccalm", "ccalp"]
'''

detvar_plotter = partial(
    variation_hists,
    var_colors=colors,
    var_labels=labels,
    approval="internal"
)

detvar_plotter_final_vars = partial(
    variation_hists_final_vars,
    var_colors=colors,
    var_labels=labels,
    approval="internal"
)

keys2load = ["cc1pi", "hdr", "histpotdf", "nudf"] ## keys from the configuration file
syst_dfs = {}
syst_evt_dfs = {}
for key in syst_keys:
    print(f"--- Processing {key} ---")
    
    # 1. Load (Temporary)
    temp_df = load_df(f"/path/to/cc1pi_{key}.df", keys2load, 100)
    
    # 2. Scale POT
    syst_tot_pot = temp_df['hdr']['pot'].sum()
    syst_pot_scale = data_tot_pot / syst_tot_pot
    temp_df['cc1pi'][pot_weight_col] = syst_pot_scale
    
    # 3. Process & Match
    # This overwrites the slice-level DF with the matched version
    matched_evt = perform_truth_matching(temp_df['cc1pi'], temp_df['nudf'])
    
    # 4. Apply Mask
    matched_evt[('slc', 'cut', 'proton_BDT_sideband', '', '', '')] = \
        proton_BDT_sideband_mask(matched_evt, ['__ntuple', 'entry', 'rec.slc..index'])
    
    # 5. Store only the reduced result
    syst_evt_dfs[key] = matched_evt
    
    # 6. Aggressive Cleanup
    del temp_df
    gc.collect()
# Out:
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_SystVarsCV.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/pot_5', '/split']
# n_split: 6
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_SystVarsCV.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.287e+20
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_wiremod_YZ.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/split']
# n_split: 5
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_wiremod_YZ.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.013e+20
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_wiremod_XZ_thetaXW.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/split']
# n_split: 5
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_wiremod_XZ_thetaXW.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.013e+20
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_0xSCE.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/pot_5', '/split']
# n_split: 6
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_0xSCE.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.237e+20
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_2xSCE.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/pot_5', '/split']
# n_split: 6
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_2xSCE.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.295e+20
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_PMTGainFluct.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/split']
# n_split: 5
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_PMTGainFluct.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 9.671e+19
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_PMTHighNoise.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/split']
# n_split: 4
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_PMTHighNoise.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 9.313e+19
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_PMTLowEff.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/split']
# n_split: 5
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_PMTLowEff.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.037e+20
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_ccalm.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/pot_5', '/split']
# n_split: 6
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_ccalm.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.287e+20
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_ccalp.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/pot_5', '/split']
# n_split: 6
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_ccalp.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.287e+20
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_alpham.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/pot_5', '/split']
# n_split: 6
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_alpham.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.287e+20
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_alphap.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/pot_5', '/split']
# n_split: 6
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_alphap.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.287e+20
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_rm.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/pot_5', '/split']
# n_split: 6
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_rm.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.287e+20
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_rp.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/pot_5', '/split']
# n_split: 6
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_rp.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.287e+20
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_betam.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/pot_5', '/split']
# n_split: 6
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_betam.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.287e+20
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_betap.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/pot_0', '/pot_1', '/pot_2', '/pot_3', '/pot_4', '/pot_5', '/split']
# n_split: 6
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_betap.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# syst_pot: 1.287e+20

# %%
'''
def proton_BDT_sideband_mask(df, group_levels):
    BDT_proton_df = df[(is_MIP_candidate_mask(df)) & (df.pfp.trk.bdt_proton_score < -0.15)]
    
    # Count how many pfps per slice
    candidate_counts = BDT_proton_df.groupby(level=group_levels).size()
 
    # Get only slices with at least 2 pfps
    valid_slices = candidate_counts[candidate_counts == 1].index

    # Apply the mask to original DataFrame
    final_mask = pd.Series(df.index.droplevel('rec.slc.reco.pfp..index').isin(valid_slices), index=df.index)

    return final_mask
'''
# Out:
# "\ndef proton_BDT_sideband_mask(df, group_levels):\n    BDT_proton_df = df[(is_MIP_candidate_mask(df)) & (df.pfp.trk.bdt_proton_score < -0.15)]\n    \n    # Count how many pfps per slice\n    candidate_counts = BDT_proton_df.groupby(level=group_levels).size()\n \n    # Get only slices with at least 2 pfps\n    valid_slices = candidate_counts[candidate_counts == 1].index\n\n    # Apply the mask to original DataFrame\n    final_mask = pd.Series(df.index.droplevel('rec.slc.reco.pfp..index').isin(valid_slices), index=df.index)\n\n    return final_mask\n"

# %%
syst_evt_dfs = {}
for key in list(syst_dfs.keys()):
    df_group = syst_dfs[key]
    
    # 1. Perform matching and store only what we need
    df_group['cc1pi'] = perform_truth_matching(df_group['cc1pi'], df_group['nudf'])
    syst_evt_dfs[key] = df_group['cc1pi']
    
    # 2. Add your mask
    syst_evt_dfs[key][('slc', 'cut', 'proton_BDT_sideband', '', '', '')] = proton_BDT_sideband_mask(syst_evt_dfs[key], ['__ntuple', 'entry', 'rec.slc..index'])
    
    # 3. Explicitly clear the large original group from the dictionary
    del syst_dfs[key]
    gc.collect()

# Final cleanup
del syst_dfs
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 syst_evt_dfs = {}
# ----> 2 for key in list(syst_dfs.keys()):
#       3     df_group = syst_dfs[key]
#       5     # 1. Perform matching and store only what we need
#
# NameError: name 'syst_dfs' is not defined

# %% [markdown]
# # Prepare maks

# %%
def shower_cut_mask(df, group_levels):
    is_pandora_primary_mask = (df.pfp.parent_is_primary == True)
    is_shower_mask = (df.pfp.trackScore >= 0) & (df.pfp.trackScore < CTE.max_shower_track_score)
    energy_mask = (df.pfp.shw.bestplane_energy > 0.350)
    shower_df = df[is_pandora_primary_mask & is_shower_mask & energy_mask] 
        
    # Count how many pfps per slice
    shower_counts = shower_df.groupby(level=group_levels).size()
    
    # Get only slices with at least 2 pfps
    non_valid_slices = shower_counts[(shower_counts > 0)].index

    # Apply the mask to original DataFrame
    final_mask = pd.Series(~df.index.droplevel('rec.slc.reco.pfp..index').isin(non_valid_slices), index=df.index)
   
    return final_mask

# %%
'''
group_levels = ['__ntuple', 'entry', 'rec.slc..index']
def build_event_cumulative_masks(evt_df, sideband = "shower"):
    # Define which BDT mask to use
    
    cut_sequence = [
        ("cosmic",      evt_df.slc.cut.obvious_cosmic),
        ("t0",          evt_df.slc.cut.t0),
        ("FV",          evt_df.slc.cut.inside_FV),
        ("nu_score",    evt_df.slc.nu_score > CTE.min_nu_score),
        ("track",       evt_df.slc.cut.track),
        ("chi2",        evt_df.slc.cut.MIP_candidates),
        ("shower",      evt_df.slc.cut.shower),
        ("angle",       evt_df.slc.cut.angle),
        ("proton_BDT",  evt_df.slc.cut.proton_BDT),
        ("containment", evt_df.slc.cut.containment),
        ("michel",      evt_df.slc.cut.michel),
        ("extra_pion",  evt_df.slc.cut.extra_pion),
        #("bad_tracks",  evt_df.slc.cut_var.n_bad_trks == 0),
        ("energy",      evt_df.slc.cut.energy),
    ]
    
    if sideband == "shower": 
        cut_sequence = [
            ("cosmic",      evt_df.slc.cut.obvious_cosmic),
            ("t0",          evt_df.slc.cut.t0),
            ("FV",          evt_df.slc.cut.inside_FV),
            ("nu_score",    evt_df.slc.nu_score > CTE.min_nu_score),
            ("track",       evt_df.slc.cut.track),
            ("chi2",        evt_df.slc.cut.MIP_candidates),
            ("shower",      shower_cut_mask(evt_df, group_levels) == False),
            ("angle",       evt_df.slc.cut.angle),
            #("proton_BDT",  evt_df.slc.cut.proton_BDT_sideband),
            ("containment", evt_df.slc.cut.containment),
            ("michel",      evt_df.slc.cut.michel),
            #("extra_pion",  evt_df.slc.cut.extra_pion),
            #("bad_tracks",  evt_df.slc.cut_var.n_bad_trks == 0),
            #("energy",      evt_df.slc.cut.energy),
            ("energy",      evt_df.slc.cut.obvious_cosmic),
        ]

    elif sideband == "proton": 
        cut_sequence = [
            ("cosmic",      evt_df.slc.cut.obvious_cosmic),
            ("t0",          evt_df.slc.cut.t0),
            ("FV",          evt_df.slc.cut.inside_FV),
            ("nu_score",    evt_df.slc.nu_score > CTE.min_nu_score),
            ("track",       evt_df.slc.cut.track),
            ("chi2",        evt_df.slc.cut.MIP_candidates),
            ("shower",      evt_df.slc.cut.shower),
            ("angle",       evt_df.slc.cut.angle),
            ("proton_BDT",  proton_BDT_sideband_mask(evt_df,group_levels)),
            ("containment", evt_df.slc.cut.containment),
            ("michel",      evt_df.slc.cut.michel),
            #("extra_pion",  evt_df.slc.cut.extra_pion),
            #("bad_tracks",  evt_df.slc.cut_var.n_bad_trks == 0),
            #("energy",      evt_df.slc.cut.energy),
            ("energy",      evt_df.slc.cut.obvious_cosmic),
        ]

            
        

    # 2️⃣ Build cumulative masks
    cumulative_masks = {}
    current_mask = None

    for name, mask in cut_sequence:

        if current_mask is None:
            current_mask = mask.copy()
        else:
            current_mask = current_mask & mask

        cumulative_masks[name] = current_mask.copy()

    return cumulative_masks

'''

# %%
# --- CV ---

syst_masks = {}
syst_sideband_masks = {}
for key, df in syst_evt_dfs.items():
    masks = build_event_cumulative_masks(df, plot_sideband = False)
    syst_masks[key] = masks
    masks = build_event_cumulative_masks(df, plot_sideband = True)
    syst_sideband_masks[key] = masks
'''
syst_masks = {}
syst_sideband_proton_masks = {}
syst_sideband_shower_masks = {}
for key, df in syst_evt_dfs.items():
    masks = build_event_cumulative_masks(df, sideband = "")
    syst_masks[key] = masks
    masks = build_event_cumulative_masks(df, sideband = "shower")
    syst_sideband_shower_masks[key] = masks
    masks = build_event_cumulative_masks(df, sideband = "proton")
    syst_sideband_proton_masks[key] = masks
'''

# %%
syst_evt_sideband_dfs = {}
'''
for key in syst_evt_dfs:
    mc_control_proton_evt_df = syst_evt_dfs[key][syst_sideband_proton_masks[key]["energy"]]
    mc_control_evt_df = syst_evt_dfs[key][syst_sideband_shower_masks[key]["energy"]]
    syst_evt_sideband_dfs[key] = pd.concat([mc_control_evt_df, mc_control_proton_evt_df], axis=0)
    
    syst_evt_dfs[key] = syst_evt_dfs[key][syst_masks[key]["energy"]]
del syst_masks
del syst_sideband_shower_masks
del syst_sideband_proton_masks
'''
for key in syst_evt_dfs:
    syst_evt_sideband_dfs[key] = syst_evt_dfs[key][syst_sideband_masks[key]["energy"]]
    syst_evt_dfs[key] = syst_evt_dfs[key][syst_masks[key]["energy"]] 
del syst_masks
del syst_sideband_masks
gc.collect()

# %% [markdown]
# # Get all the syst uncert

# %%
from analysis_village.cc1pi.HelperFunctions import HelperFunctions
for key in syst_evt_dfs:
    HelperFunctions.print_purity(syst_evt_dfs[key], ('truth','nu_categ','','','',''))
    HelperFunctions.print_purity(syst_evt_sideband_dfs[key], ('truth','nu_categ','','','',''))

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import os

unisim_keys = []
paired_syst = {} 
file_dir = "/exp/sbnd/data/users/lpelegri/syst/CCBC_rates"
os.makedirs(file_dir, exist_ok=True)

if 'syst_dict' not in locals():
    syst_dict = {}

var_configs = [
    VariableConfig.all_evts(), 
    VariableConfig.muon_momentum(),
    VariableConfig.muon_direction(),
    VariableConfig.pion_momentum(),
    VariableConfig.pion_direction(),
    VariableConfig.angle_between_candidates(),
    VariableConfig.num_protons(),
    VariableConfig.delta_pt(),
    VariableConfig.delta_alpha_T(),
    VariableConfig.delta_phi_T()
]

syst_keys = ["SystVarsCV","wiremod_YZ", "ccalm", "ccalp"]
# Identify Unisim (1 univ) vs Paired/Multisim (2 univ)
for key in syst_keys:
    if key.endswith('m') or key.endswith('p'):
        base = key[:-1]
        if base not in paired_syst:
            paired_syst[base] = [None, None]
        if key.endswith('m'): paired_syst[base][0] = key
        else: paired_syst[base][1] = key
    else:
        unisim_keys.append(key)

print(unisim_keys)
univ_hist_detector = {}

# Initialize structure for all systematics
for syst_key in unisim_keys:
    univ_hist_detector[syst_key] = {"Ps": {}, "Bs": {}, "nc": {}}

for base_name in paired_syst:
    univ_hist_detector[base_name] = {"Ps": {}, "Bs": {}, "nc": {}}

# --- 3. Main Variable Loop ---
for var_config in var_configs:
    var_name = var_config.var_save_name
    evtdfs_signal = [syst_evt_dfs[syst_key][syst_evt_dfs[syst_key].truth.nu_categ == "CC1pi"].groupby(level=['__ntuple', 'entry', 'rec.slc..index'], sort=False).first() for syst_key in syst_evt_dfs.keys()]
    evtdfs_bkg = [syst_evt_dfs[syst_key][syst_evt_dfs[syst_key].truth.nu_categ != "CC1pi"].groupby(level=['__ntuple', 'entry', 'rec.slc..index'], sort=False).first() for syst_key in syst_evt_dfs.keys()]
    sideband_evtdfs = [syst_evt_sideband_dfs[syst_key].groupby(level=['__ntuple', 'entry', 'rec.slc..index'], sort=False).first() for syst_key in syst_evt_dfs.keys()]

    n_phis = detvar_plotter_final_vars(evtdfs_signal, var_name=var_config.var_evt_reco_col, bins=var_config.bins, plot=False)
    n_Bs = detvar_plotter_final_vars(evtdfs_bkg, var_name=var_config.var_evt_reco_col, bins=var_config.bins, plot=False)
    n_sideband = detvar_plotter_final_vars(sideband_evtdfs, var_name=var_config.var_evt_reco_col, bins=var_config.bins, plot=False)
    
    key_to_idx = {key: i for i, key in enumerate(syst_evt_dfs.keys())}
    for syst_key in unisim_keys:
        kidx = key_to_idx[syst_key]
        # This creates (1, nbins)
        univ_hist_detector[syst_key]["Ps"][var_name] = np.array(n_phis[kidx], ndmin=2)
        univ_hist_detector[syst_key]["Bs"][var_name] = np.array(n_Bs[kidx], ndmin=2)
        univ_hist_detector[syst_key]["nc"][var_name] = np.array(n_sideband[kidx], ndmin=2)
     
    for base_name, keys in paired_syst.items():
        m_idx, p_idx = key_to_idx.get(keys[0]), key_to_idx.get(keys[1])
        if m_idx is not None and p_idx is not None:
            # This creates (2, nbins) -> Exactly like univ_events
            univ_hist_detector[base_name]["Ps"][var_name] = np.stack([n_phis[m_idx], n_phis[p_idx]])
            univ_hist_detector[base_name]["Bs"][var_name] = np.stack([n_Bs[m_idx], n_Bs[p_idx]])
            univ_hist_detector[base_name]["nc"][var_name] = np.stack([n_sideband[m_idx], n_sideband[p_idx]])

# --- CRITICAL PART FOR SAVING ---
# np.savez does not like deep nesting. To preserve your dict structure:
save_path = os.path.join(file_dir, "detector_univ_hists.npz")
np.savez(save_path, **{k: np.array(v, dtype=object) for k, v in univ_hist_detector.items()})
