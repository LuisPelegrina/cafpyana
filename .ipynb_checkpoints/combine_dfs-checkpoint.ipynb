# %%
import pandas as pd
import pathlib
import glob
import os
import numpy as np
import warnings
import gc  # Added for memory management
import pyanalib.split_df_helpers as splh
from tables import NaturalNameWarning

# 1. Suppress warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=NaturalNameWarning)
from tqdm import tqdm # Standard for progress bars in SBND environments
def consolidate_buffered(folder_path, output_name, split_margin_gb=1.0, num_splits=1, shift_ntuple_index=False):
    """
    Consolidates files with optional global ntuple index shifting.
    """
    out_dir = pathlib.Path("/exp/sbnd/data/users/lpelegri/cafpyana_data")
    out_dir.mkdir(parents=True, exist_ok=True)
    output_file = out_dir / f"{output_name}.df"

    input_folder = pathlib.Path(folder_path)
    files = sorted(glob.glob(str(input_folder / f"{output_name}_*.df")))
    
    if not files:
        print(f"No files found for {output_name}")
        return

    # --- ANNOUNCE START ---
    print(f"\n{'='*60}")
    print(f"COMBINING: {output_name}")
    print(f"TARGET:    {output_file}")
    print(f"SHIFT INDEX: {shift_ntuple_index}")
    print(f"TOTAL FILES TO PROCESS: {len(files)}")
    print(f"{'='*60}\n")

    # 1. Discover keys
    with pd.HDFStore(files[0], mode='r') as store:
        keys2load = [k.lstrip('/').rsplit('_', 1)[0] for k in store.keys() if 'split' not in k]
        keys2load = sorted(list(set(keys2load)))

    df_buffers = {k: [] for k in keys2load}
    size_counters = {k: 0 for k in keys2load}
    k_idx = 0 
    total_ntuples_seen = 0 

    with pd.HDFStore(output_file, mode='w') as hdf_out:
        pbar = tqdm(files, desc="Consolidating", unit="file")
        
        for file_path in pbar:
            if k_idx >= num_splits:
                pbar.write(f"Reached limit of {num_splits} splits. Stopping.")
                break
            
            file_data = splh.load_dfs(file_path, keys2load)
            
            # --- INDEX MAPPING LOGIC ---
            if shift_ntuple_index:
                # Calculate unique IDs only if we need to shift
                unique_ids_in_file = set()
                for df in file_data.values():
                    if df is not None and not df.empty:
                        unique_ids_in_file.update(df.index.get_level_values("__ntuple").unique())
                
                sorted_old_ids = sorted(list(unique_ids_in_file))
                num_unique_ntuples = len(sorted_old_ids)

                if num_unique_ntuples > 0:
                    mapping = {old_id: i + total_ntuples_seen for i, old_id in enumerate(sorted_old_ids)}
                    
                    for k in keys2load:
                        df = file_data[k]
                        if df is not None and not df.empty:
                            # Apply the mapping to the index
                            old_indices = df.index.get_level_values("__ntuple")
                            new_indices = old_indices.map(mapping)
                            df.index = df.index.set_levels(new_indices.unique(), level="__ntuple")
                    
                    total_ntuples_seen += num_unique_ntuples

            # --- BUFFERING ---
            for k in keys2load:
                df = file_data[k]
                if df is not None and not df.empty:
                    size_gb = df.memory_usage(deep=True).sum() / (1024**3)
                    size_counters[k] += size_gb
                    df_buffers[k].append(df)
            
            # --- FLUSH LOGIC ---
            current_total_buffer_gb = sum(size_counters.values())
            if current_total_buffer_gb >= split_margin_gb:
                pbar.write(f"--- Buffer limit reached ({current_total_buffer_gb:.3f} GB). Flushing to split_{k_idx} ---")
                for k in keys2load:
                    if df_buffers[k]:
                        concat_df = pd.concat(df_buffers[k], ignore_index=False)
                        hdf_out.put(key=f"{k}_{k_idx}", value=concat_df, format="fixed")
                        df_buffers[k] = [] 
                        size_counters[k] = 0
                k_idx += 1
                gc.collect()

                if k_idx >= num_splits:
                    break
                
            del file_data
            gc.collect()

        # Final Flush for remaining data
        if k_idx < num_splits and any(len(b) > 0 for b in df_buffers.values()):
            print(f"--- Final Flush: split_{k_idx} ---")
            for k in keys2load:
                if df_buffers[k]:
                    concat_df = pd.concat(df_buffers[k], ignore_index=False)
                    hdf_out.put(key=f"{k}_{k_idx}", value=concat_df, format="fixed")
            k_idx += 1
            gc.collect()

        hdf_out.put(key="split", value=pd.DataFrame({"n_split": [k_idx]}), format="fixed")

    print(f"\nConsolidation finished. Total splits: {k_idx}")
    
    # Cleanup block
    print("Deleting temporary files...")
    for file_path in files:
        try:
            os.remove(file_path)
        except OSError:
            pass 
    print("All Clean!")
    return output_file
    
# --- Execution ---
# Dictionary mapping file names to their shift_ntuple_index status
'''
file_config = {
    "cc1pi_5e18_CV": False,
    "mc_GIBUU_gen1": False,
    "cc1pi_data_rollingdev_bnblight": False, # Usually False for data
    "cc1pi_data_offbeamlight": False,        # Usually False for data
    "cc1pi_1e20_lowE_CV": True,
    "cc1pi_5e18_in_time_cosmics": False,
    "cc1pi_5e18_CV_extra_syst": False,
    "cc1pi_extended_syst": False,
    "cc1pi_SystVarsCV": False,
    "cc1pi_ccalp": False,
    "cc1pi_alphap": False,
    "cc1pi_ccalm": False,
    "cc1pi_alpham": False,
    "cc1pi_betam": False,
    "cc1pi_rm": False,
    "cc1pi_rp": False,
    "cc1pi_betap": False,
    "cc1pi_wiremod_YZ": False,
    "cc1pi_wiremod_XZ_thetaXW": False,
    "cc1pi_0xSCE": False,
    "cc1pi_2xSCE": False,
    "cc1pi_PMTHighNoise": False,
    "cc1pi_PMTGainFluct": False,
    "cc1pi_PMTLowEff": False
}
'''
file_config = {
    "cc1pi_data_rollingdev_bnblight": False, # Usually False for data
}

SOURCE = "/exp/sbnd/data/users/lpelegri/cafpyana_data_transfer_folder"

for file_name, should_shift in file_config.items():
    print(f"\n>>> Processing {file_name} (Shift Index: {should_shift})")
    
    consolidate_buffered(
        SOURCE, 
        file_name, 
        split_margin_gb=1, 
        num_splits=1000, 
        shift_ntuple_index=True
    )
# Out:
# >>> Processing cc1pi_SystVarsCV (Shift Index: False)
#
# ============================================================
# COMBINING: cc1pi_SystVarsCV
# TARGET:    /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_SystVarsCV.df
# SHIFT INDEX: True
# TOTAL FILES TO PROCESS: 499
# ============================================================
# Consolidating:  11%|█         | 55/499 [00:38<05:22,  1.38file/s]
# --- Buffer limit reached (1.000 GB). Flushing to split_0 ---
# Consolidating:  22%|██▏       | 111/499 [01:20<04:51,  1.33file/s]
# --- Buffer limit reached (1.000 GB). Flushing to split_1 ---
# Consolidating:  33%|███▎      | 167/499 [02:06<04:21,  1.27file/s]
# --- Buffer limit reached (1.005 GB). Flushing to split_2 ---
# Consolidating:  45%|████▍     | 223/499 [02:51<03:55,  1.17file/s]
# --- Buffer limit reached (1.005 GB). Flushing to split_3 ---
# Consolidating:  56%|█████▌    | 279/499 [03:38<03:14,  1.13file/s]
# --- Buffer limit reached (1.006 GB). Flushing to split_4 ---
# Consolidating:  67%|██████▋   | 335/499 [04:25<02:14,  1.22file/s]
# --- Buffer limit reached (1.003 GB). Flushing to split_5 ---
# Consolidating:  79%|███████▊  | 392/499 [05:09<01:17,  1.37file/s]
# --- Buffer limit reached (1.011 GB). Flushing to split_6 ---
# Consolidating:  90%|█████████ | 450/499 [05:58<00:47,  1.02file/s]
# --- Buffer limit reached (1.015 GB). Flushing to split_7 ---
# Consolidating: 100%|██████████| 499/499 [06:37<00:00,  1.26file/s]
# --- Final Flush: split_8 ---
#
# Consolidation finished. Total splits: 9
# Deleting temporary files...
# All Clean!
#
# >>> Processing cc1pi_ccalp (Shift Index: False)
#
# ============================================================
# COMBINING: cc1pi_ccalp
# TARGET:    /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_ccalp.df
# SHIFT INDEX: True
# TOTAL FILES TO PROCESS: 499
# ============================================================
# Consolidating:  11%|█         | 55/499 [00:39<05:09,  1.43file/s]
# --- Buffer limit reached (1.014 GB). Flushing to split_0 ---
# Consolidating:  22%|██▏       | 111/499 [01:24<04:48,  1.34file/s]
# --- Buffer limit reached (1.014 GB). Flushing to split_1 ---
# Consolidating:  33%|███▎      | 166/499 [02:09<04:24,  1.26file/s]
# --- Buffer limit reached (1.000 GB). Flushing to split_2 ---
# Consolidating:  44%|████▍     | 221/499 [02:53<03:39,  1.27file/s]
# --- Buffer limit reached (1.001 GB). Flushing to split_3 ---
# Consolidating:  55%|█████▌    | 276/499 [03:39<02:56,  1.27file/s]
# --- Buffer limit reached (1.002 GB). Flushing to split_4 ---
# Consolidating:  67%|██████▋   | 332/499 [04:30<02:06,  1.32file/s]
# --- Buffer limit reached (1.018 GB). Flushing to split_5 ---
# Consolidating:  78%|███████▊  | 388/499 [05:13<01:19,  1.40file/s]
# --- Buffer limit reached (1.008 GB). Flushing to split_6 ---
# Consolidating:  89%|████████▉ | 445/499 [05:58<00:50,  1.08file/s]
# --- Buffer limit reached (1.011 GB). Flushing to split_7 ---
# Consolidating: 100%|██████████| 499/499 [06:42<00:00,  1.24file/s]
# --- Final Flush: split_8 ---
#
# Consolidation finished. Total splits: 9
# Deleting temporary files...
# All Clean!
#
# >>> Processing cc1pi_alphap (Shift Index: False)
#
# ============================================================
# COMBINING: cc1pi_alphap
# TARGET:    /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_alphap.df
# SHIFT INDEX: True
# TOTAL FILES TO PROCESS: 499
# ============================================================
# Consolidating:  11%|█         | 55/499 [00:42<05:30,  1.34file/s]
# --- Buffer limit reached (1.015 GB). Flushing to split_0 ---
# Consolidating:  22%|██▏       | 111/499 [01:26<04:55,  1.31file/s]
# --- Buffer limit reached (1.014 GB). Flushing to split_1 ---
# Consolidating:  33%|███▎      | 166/499 [02:10<04:24,  1.26file/s]
# --- Buffer limit reached (1.000 GB). Flushing to split_2 ---
# Consolidating:  44%|████▍     | 221/499 [02:54<03:55,  1.18file/s]
# --- Buffer limit reached (1.001 GB). Flushing to split_3 ---
# Consolidating:  55%|█████▌    | 276/499 [03:38<02:46,  1.34file/s]
# --- Buffer limit reached (1.002 GB). Flushing to split_4 ---
# Consolidating:  67%|██████▋   | 332/499 [04:24<02:20,  1.19file/s]
# --- Buffer limit reached (1.018 GB). Flushing to split_5 ---
# Consolidating:  78%|███████▊  | 388/499 [05:11<01:36,  1.15file/s]
# --- Buffer limit reached (1.008 GB). Flushing to split_6 ---
# Consolidating:  89%|████████▉ | 445/499 [05:58<00:37,  1.43file/s]
# --- Buffer limit reached (1.011 GB). Flushing to split_7 ---
# Consolidating: 100%|██████████| 499/499 [06:41<00:00,  1.24file/s]
# --- Final Flush: split_8 ---
#
# Consolidation finished. Total splits: 9
# Deleting temporary files...
# All Clean!
#
# >>> Processing cc1pi_ccalm (Shift Index: False)
#
# ============================================================
# COMBINING: cc1pi_ccalm
# TARGET:    /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_ccalm.df
# SHIFT INDEX: True
# TOTAL FILES TO PROCESS: 499
# ============================================================
# Consolidating:  11%|█         | 55/499 [00:42<05:34,  1.33file/s]
# --- Buffer limit reached (1.014 GB). Flushing to split_0 ---
# Consolidating:  22%|██▏       | 111/499 [01:30<05:49,  1.11file/s]
# --- Buffer limit reached (1.014 GB). Flushing to split_1 ---
# Consolidating:  33%|███▎      | 167/499 [02:14<04:06,  1.34file/s]
# --- Buffer limit reached (1.019 GB). Flushing to split_2 ---
# Consolidating:  44%|████▍     | 222/499 [03:00<03:37,  1.27file/s]
# --- Buffer limit reached (1.001 GB). Flushing to split_3 ---
# Consolidating:  56%|█████▌    | 277/499 [03:46<02:44,  1.35file/s]
# --- Buffer limit reached (1.002 GB). Flushing to split_4 ---
# Consolidating:  67%|██████▋   | 333/499 [04:33<02:11,  1.26file/s]
# --- Buffer limit reached (1.018 GB). Flushing to split_5 ---
# Consolidating:  78%|███████▊  | 389/499 [05:19<01:27,  1.25file/s]
# --- Buffer limit reached (1.007 GB). Flushing to split_6 ---
# Consolidating:  89%|████████▉ | 446/499 [06:07<00:41,  1.27file/s]
# --- Buffer limit reached (1.011 GB). Flushing to split_7 ---
# Consolidating: 100%|██████████| 499/499 [06:50<00:00,  1.22file/s]
# --- Final Flush: split_8 ---
#
# Consolidation finished. Total splits: 9
# Deleting temporary files...
# All Clean!
#
# >>> Processing cc1pi_alpham (Shift Index: False)
#
# ============================================================
# COMBINING: cc1pi_alpham
# TARGET:    /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_alpham.df
# SHIFT INDEX: True
# TOTAL FILES TO PROCESS: 499
# ============================================================
# Consolidating:  11%|█         | 55/499 [00:40<05:31,  1.34file/s]
# --- Buffer limit reached (1.015 GB). Flushing to split_0 ---
# Consolidating:  22%|██▏       | 111/499 [01:27<05:51,  1.10file/s]
# --- Buffer limit reached (1.014 GB). Flushing to split_1 ---
# Consolidating:  33%|███▎      | 166/499 [02:13<04:12,  1.32file/s]
# --- Buffer limit reached (1.000 GB). Flushing to split_2 ---
# Consolidating:  44%|████▍     | 221/499 [02:59<04:15,  1.09file/s]
# --- Buffer limit reached (1.001 GB). Flushing to split_3 ---
# Consolidating:  55%|█████▌    | 276/499 [03:42<02:40,  1.39file/s]
# --- Buffer limit reached (1.002 GB). Flushing to split_4 ---
# Consolidating:  64%|██████▍   | 320/499 [04:17<02:09,  1.38file/s]

# %%
def consolidate_buffered_big_files(folder_path, output_name, split_margin_gb=1.0, num_splits=1, shift_ntuple_index=True):
    """
    Consolidates files with optional global ntuple index shifting.
    """
    out_dir = pathlib.Path("/exp/sbnd/data/users/lpelegri/cafpyana_data")
    out_dir.mkdir(parents=True, exist_ok=True)
    output_file = out_dir / f"{output_name}.df"

    input_folder = pathlib.Path(folder_path)
    files = sorted(glob.glob(str(input_folder / f"{output_name}_*.df")))
    
    if not files:
        print(f"No files found for {output_name}")
        return

    # --- ANNOUNCE START ---
    print(f"\n{'='*60}")
    print(f"COMBINING: {output_name}")
    print(f"TARGET:    {output_file}")
    print(f"SHIFT INDEX: {shift_ntuple_index}")
    print(f"TOTAL FILES TO PROCESS: {len(files)}")
    print(f"{'='*60}\n")

    # 1. Discover keys
    with pd.HDFStore(files[0], mode='r') as store:
        keys2load = [k.lstrip('/').rsplit('_', 1)[0] for k in store.keys() if 'split' not in k]
        keys2load = sorted(list(set(keys2load)))

    df_buffers = {k: [] for k in keys2load}
    size_counters = {k: 0 for k in keys2load}
    k_idx = 0 
    total_ntuples_seen = 0 

    with pd.HDFStore(output_file, mode='w') as hdf_out:
        pbar = tqdm(files, desc="Consolidating", unit="file")
        
        for file_path in pbar:
            if k_idx >= num_splits:
                pbar.write(f"Reached limit of {num_splits} splits. Stopping.")
                break
            
            file_data = splh.load_dfs(file_path, keys2load)
            
            # --- INDEX MAPPING LOGIC ---
            if shift_ntuple_index:
                # Calculate unique IDs only if we need to shift
                unique_ids_in_file = set()
                for df in file_data.values():
                    if df is not None and not df.empty:
                        unique_ids_in_file.update(df.index.get_level_values("__ntuple").unique())
                
                sorted_old_ids = sorted(list(unique_ids_in_file))
                num_unique_ntuples = len(sorted_old_ids)

                if num_unique_ntuples > 0:
                    mapping = {old_id: i + total_ntuples_seen for i, old_id in enumerate(sorted_old_ids)}
                    
                    for k in keys2load:
                        df = file_data[k]
                        if df is not None and not df.empty:
                            # Apply the mapping to the index
                            old_indices = df.index.get_level_values("__ntuple")
                            new_indices = old_indices.map(mapping)
                            df.index = df.index.set_levels(new_indices.unique(), level="__ntuple")
                    
                    total_ntuples_seen += num_unique_ntuples

            # --- BUFFERING ---
            for k in keys2load:
                df = file_data[k]
                if df is not None and not df.empty:
                    size_gb = df.memory_usage(deep=True).sum() / (1024**3)
                    size_counters[k] += size_gb
                    df_buffers[k].append(df)
            
            # --- FLUSH LOGIC ---
            current_total_buffer_gb = sum(size_counters.values())
            if current_total_buffer_gb >= split_margin_gb:
                pbar.write(f"--- Buffer limit reached ({current_total_buffer_gb:.3f} GB). Flushing to split_{k_idx} ---")
                for k in keys2load:
                    if df_buffers[k]:
                        concat_df = pd.concat(df_buffers[k], ignore_index=False)
                        hdf_out.put(key=f"{k}_{k_idx}", value=concat_df, format="fixed")
                        df_buffers[k] = [] 
                        size_counters[k] = 0
                k_idx += 1
                gc.collect()

                if k_idx >= num_splits:
                    break
                
            del file_data
            gc.collect()

        # Final Flush for remaining data
        if k_idx < num_splits and any(len(b) > 0 for b in df_buffers.values()):
            print(f"--- Final Flush: split_{k_idx} ---")
            for k in keys2load:
                if df_buffers[k]:
                    concat_df = pd.concat(df_buffers[k], ignore_index=False)
                    hdf_out.put(key=f"{k}_{k_idx}", value=concat_df, format="fixed")
            k_idx += 1
            gc.collect()

        hdf_out.put(key="split", value=pd.DataFrame({"n_split": [k_idx]}), format="fixed")

    print(f"\nConsolidation finished. Total splits: {k_idx}")
    
    # Cleanup block
    print("Deleting temporary files...")
    '''
    for file_path in files:
        try:
            os.remove(file_path)
        except OSError:
            pass 
    print("All Clean!")
    '''
    return output_file

# %%
file_list = [
    "mc_ar23p_extended_syst",
]


SOURCE = "/exp/sbnd/data/users/lpelegri/cafpyana_data_transfer_folder"

for file in file_list:
    consolidate_buffered_big_files(SOURCE, file, split_margin_gb=1, num_splits=10, shift_ntuple_index = True)
# Out:
# ============================================================
# COMBINING: mc_ar23p_extended_syst
# TARGET:    /exp/sbnd/data/users/lpelegri/cafpyana_data/mc_ar23p_extended_syst.df
# SHIFT INDEX: True
# TOTAL FILES TO PROCESS: 9999
# ============================================================
# Consolidating:   0%|          | 27/9999 [00:42<4:50:57,  1.75s/file]
# --- Buffer limit reached (1.021 GB). Flushing to split_0 ---
# Consolidating:   1%|          | 55/9999 [01:27<5:00:28,  1.81s/file]
# --- Buffer limit reached (1.017 GB). Flushing to split_1 ---
# Consolidating:   1%|          | 84/9999 [02:17<5:13:41,  1.90s/file]
# --- Buffer limit reached (1.033 GB). Flushing to split_2 ---
# Consolidating:   1%|          | 112/9999 [03:05<4:43:43,  1.72s/file]
# --- Buffer limit reached (1.022 GB). Flushing to split_3 ---
# Consolidating:   1%|▏         | 140/9999 [03:53<5:23:29,  1.97s/file]
# --- Buffer limit reached (1.021 GB). Flushing to split_4 ---
# Consolidating:   2%|▏         | 169/9999 [04:44<5:38:25,  2.07s/file]
# --- Buffer limit reached (1.034 GB). Flushing to split_5 ---
# Consolidating:   2%|▏         | 197/9999 [05:32<5:08:32,  1.89s/file]
# --- Buffer limit reached (1.015 GB). Flushing to split_6 ---
# Consolidating:   2%|▏         | 225/9999 [06:22<5:01:17,  1.85s/file]
# --- Buffer limit reached (1.024 GB). Flushing to split_7 ---
# Consolidating:   3%|▎         | 253/9999 [07:13<5:31:14,  2.04s/file]
# --- Buffer limit reached (1.030 GB). Flushing to split_8 ---
# Consolidating:   3%|▎         | 281/9999 [08:04<5:39:42,  2.10s/file]
# --- Buffer limit reached (1.017 GB). Flushing to split_9 ---
# Consolidating:   3%|▎         | 281/9999 [08:07<4:41:09,  1.74s/file]
# Consolidation finished. Total splits: 10
# Deleting temporary files...
