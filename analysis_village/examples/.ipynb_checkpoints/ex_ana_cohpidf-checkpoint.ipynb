# %%
## In this example, we will study output data frame from pandora.py configuration
#### 1. Opening each data frame and check structure
#### 2. Collect POT and scale factor to the target POT
#### 3. Merge evtdf and mcnudf for further study
#### 4. Draw some plots for each slice and for each pfp

import os
import sys

import numpy as np
import math
import uproot as uproot
import pickle
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.colors
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import ticker
from matplotlib.ticker import (AutoMinorLocator, MultipleLocator)
from matplotlib import gridspec

# Add the head direcoty to sys.path
workspace_root = os.getcwd()  
sys.path.insert(0, workspace_root + "/../../")

# import this repo's classes
import pyanalib.pandas_helpers as ph

# %%
## 1. Open each df
venv_path = os.getenv("PATH")
input_df_path = "../../test_data/test.df"
 = "/exp/sbnd/data/users/sungbino/sbnd_samples/cafpyana_outputs/test_cohpi.df"
with pd.HDFStore(input_df_path) as store:
    print(store.keys())
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 4
#       2 venv_path = os.getenv("PATH")
#       3 input_df_path = "/exp/sbnd/data/users/sungbino/sbnd_samples/cafpyana_outputs/cohpi_df_mcweight_test.df"
# ----> 4 with pd.HDFStore(input_df_path) as store:
#       5     print(store.keys())
#
# File ~/cafpyana/envs/venv_py310_cafpyana/lib/python3.10/site-packages/pandas/io/pytables.py:585, in HDFStore.__init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     583 self._fletcher32 = fletcher32
#     584 self._filters = None
# --> 585 self.open(mode=mode, **kwargs)
#
# File ~/cafpyana/envs/venv_py310_cafpyana/lib/python3.10/site-packages/pandas/io/pytables.py:745, in HDFStore.open(self, mode, **kwargs)
#     739     msg = (
#     740         "Cannot open HDF5 file, which is already opened, "
#     741         "even in read-only mode."
#     742     )
#     743     raise ValueError(msg)
# --> 745 self._handle = tables.open_file(self._path, self._mode, **kwargs)
#
# File ~/cafpyana/envs/venv_py310_cafpyana/lib/python3.10/site-packages/tables/file.py:296, in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     291             raise ValueError(
#     292                 "The file '%s' is already opened.  Please "
#     293                 "close it before reopening in write mode." % filename)
#     295 # Finally, create the File instance, and return it
# --> 296 return File(filename, mode, title, root_uep, filters, **kwargs)
#
# File ~/cafpyana/envs/venv_py310_cafpyana/lib/python3.10/site-packages/tables/file.py:746, in File.__init__(self, filename, mode, title, root_uep, filters, **kwargs)
#     743 self.params = params
#     745 # Now, it is time to initialize the File extension
# --> 746 self._g_new(filename, mode, **params)
#     748 # Check filters and set PyTables format version for new files.
#     749 new = self._v_new
#
# File ~/cafpyana/envs/venv_py310_cafpyana/lib/python3.10/site-packages/tables/hdf5extension.pyx:396, in tables.hdf5extension.File._g_new()
#
# File ~/cafpyana/envs/venv_py310_cafpyana/lib/python3.10/site-packages/tables/utils.py:190, in check_file_access(filename, mode)
#     188 elif mode == 'a':
#     189     if os.access(path, os.F_OK):
# --> 190         check_file_access(path, 'r+')
#     191     else:
#     192         check_file_access(path, 'w')
#
# File ~/cafpyana/envs/venv_py310_cafpyana/lib/python3.10/site-packages/tables/utils.py:196, in check_file_access(filename, mode)
#     194     check_file_access(path, 'r')
#     195     if not os.access(path, os.W_OK):
# --> 196         raise PermissionError(f"file ``{path}`` exists but it can not be written")
#     197 else:
#     198     raise ValueError(f"invalid mode: {mode!r}")
#
# PermissionError: file ``/exp/sbnd/data/users/sungbino/sbnd_samples/cafpyana_outputs/cohpi_df_mcweight_test.df`` exists but it can not be written

# %%
cohpidf = pd.read_hdf(input_df_path, key='cohpi')
hdrdf = pd.read_hdf(input_df_path, key='hdr')
mcnuwgtdf = pd.read_hdf(input_df_path, key='mcnuwgt')

# %%
#### 1.1 Check evtdf structure
cohpidf

# %%
#### 1.2 Check hdrdf structure
hdrdf

# %%
#### 1.3 Check mcnudf structure
mcnuwgtdf

# %%
mcnuwgtdf.columns

# %%
## 2. Collect POT and scale factor to the target POT
this_pot = sum(hdrdf.pot)
print(this_pot)
target_POT = 3.0e18
POT_scale = target_POT / this_pot
print(POT_scale)

# %%
cohpidf.reset_index()

# %%
cohpidf.rec.slc.columns

# %%
## 3. Merge evtdf and mcnudf
#### 1) Merging is based on matching between slc.tmatch.idx of evtdf and rec.mc.nu..index of mcnudf.
####    For each entry (readout window), there could be multiple truth neutrino interactions and reconstructed slices
####    We want to match each truth neutrion interaction to a corresponding slice

matchdf = ph.multicol_merge(cohpidf.reset_index(), mcnuwgtdf.reset_index(),
                            left_on=[("entry", "",""), ("rec", "slc","tmatch", "idx")],
                            right_on=[("entry", "",""), ("rec.mc.nu..index", "","")], 
                            how="left") ## -- save all sllices

# %%
matchdf

# %%
matchdf.columns

# %%
## 4. Draw plots
#### 4.1) Make dataframe of nu.E for each rec.slc..index (nuE_per_slc) and for each rec.slc.reco.pfp..index (nuE_per_pfp)
nuE_col = ('E', '', '', '')
nuE_per_slc = matchdf.groupby([('entry'), ('rec.slc..index')])[[nuE_col]].first()

# %%
print(nuE_per_slc)
print("len(nuE_per_slc) = %d" %len(nuE_per_slc))

# %%
#### 4.2) Draw a plot of nu.E for each slc
plt.hist(nuE_per_slc.E, bins=np.linspace(0., 6., 71), histtype="step", label=["all"])
plt.xlabel("Neutrino Energy (GeV)")
plt.ylabel(f"Neutrinos (POT = {this_pot:.2e})")
plt.legend()
plt.show()

# %%
#### 4.4) Draw a plot of nu.E for each slc with POT scaling
plt.hist(nuE_per_slc.E, bins=np.linspace(0., 6., 71), weights=[np.ones_like(data) * POT_scale for data in nuE_per_slc.E], histtype="step", label=["all"])
plt.xlabel("Neutrino Energy (GeV)")
plt.ylabel(f"Neutrinos (POT = {target_POT:.2e})")
plt.legend()
plt.show()

# %%
#### 4.5) Draw nu score distribution per slc
nu_score_col = ('rec', 'slc', 'nu_score', '')
nu_score_per_slc = matchdf.groupby([('entry'), ('rec.slc..index')])[[nu_score_col]].first()
plt.hist(nu_score_per_slc.rec.slc.nu_score, bins=np.linspace(0., 1., 101), weights=[np.ones_like(data) * POT_scale for data in nu_score_per_slc.rec.slc.nu_score], histtype="step", label=["all"])
plt.xlabel("Neutrion Score")
plt.ylabel(f"Neutrinos (POT = {target_POT:.2e})")
plt.legend()
plt.show()
