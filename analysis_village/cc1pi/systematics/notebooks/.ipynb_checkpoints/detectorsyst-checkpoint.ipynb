# %%
# %load_ext autoreload
# %autoreload 

import pandas as pd
import numpy as np
from os import path, makedirs
from datetime import datetime
from functools import partial

# local imports
import sys
print('Importing cafpyana utils...')
cafpyana_root = "/home/lpelegri/cafpyana"
# Add CAFpyana to the Python search path -- this will allow you to import cafpyana modules
sys.path.insert(0, cafpyana_root)


from pyanalib.split_df_helpers import *
from analysis_village.cc1pi.systematics.final_variable_configs import VariableConfig
from analysis_village.cc1pi.systematics.utils import *
from analysis_village.cc1pi.systematics.constants import *
from pyanalib.covariance import *
from analysis_village.cc1pi.DataFrameUtils.DFLoading import *
from analysis_village.cc1pi.Constants import CTE as CTE

from analysis_village.cc1pi.CutMasks.MaskUtils import *
from makedf.mcstat import get_MCstat_unc

from analysis_village.cc1pi.HelperFunctions import HelperFunctions
from analysis_village.cc1pi.var_configs import *

# turn off PerformanceWarning 
# triggered by mismatched column levels
import warnings
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning)
# Out:
# Importing cafpyana utils...
# mc_tot_pot: 5.947e+18
# Integrated flux: 9.604e+10
# Integrated flux: 1.615e+02
# # of targets:  1.4154995096228214e+30
# 96036210000.0
# xsec unit:  7.356229506477044e-42
# Importing cafpyana utils...

# %%
save_result = True
save_fig = save_result

save_fig_base_dir = "/exp/sbnd/data/users/lpelegri/syst/"

today_str = datetime.now().strftime("%Y%m%d")
save_fig_dir = path.join(save_fig_base_dir, "systematics-other-{}".format(today_str))

if save_fig:
    if not path.exists(save_fig_dir):
        makedirs(save_fig_dir)
    print("saving plots in ", save_fig_dir)
# Out:
# saving plots in  /exp/sbnd/data/users/lpelegri/syst/systematics-other-20260503

# %% [markdown]
# # Load df

# %%
pot_weight_col = ('slc', 'wgt', '', '', '', '')

#Load data
keys2load = ["cc1pi", "hdr", "histpotdf"] ## keys from the configuration file
data_df = load_df("/exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_data_rollingdev_bnblight.df", keys2load, 100)
data_evt_df = data_df['cc1pi']
data_hdr_df = data_df['hdr']

# BNB data
# data_tot_pot = data_hdr_df['TOR875'].sum()
data_tot_pot = data_hdr_df['pot'].sum()
print("data_tot_pot: %.3e" %(data_tot_pot))
pot_str = f"{data_tot_pot} $\\times 10^{18}$"
data_evt_df[pot_weight_col] = np.ones(len(data_evt_df))
data_gates = data_hdr_df.nbnbinfo.sum()
print("data tot gates : %.3e" %(data_gates))




#Load CV dataframe
'''
CV_df = load_df("/scratch/7DayLifetime/lpelegrina/cc1pi_SystVarsCV.df", keys2load, 100)
CV_tot_pot =  CV_df['hdr']['pot'].sum()
CV_pot_scale = data_tot_pot / CV_tot_pot
CV_df['cc1pi'][pot_weight_col] = CV_pot_scale * np.ones(len(CV_df['cc1pi']))
'''

#Load systematics df
#syst_names = ["2xSCE", "PMTGainFluct","PMTHighNoise", "PMTLowEff"]

syst_keys = ["SystVarsCV","wiremod_YZ","wiremod_XZ_thetaXW", "0xSCE","2xSCE","PMTGainFluct", "PMTHighNoise", "PMTLowEff"]
colors = ["black", "C0","C1","C2","C3", "C4","C5","C6","C7","C8","C9"]
labels    = ["CV", r"Wiremod Y-Z",r"Wiremod X$\theta_{xw}$", "0xSCE", "2xSCE","PMTGainFluct", "PMTHighNoise", "PMTLowEff"]

#syst_keys = ["SystVarsCV", "ccalm", "ccalp", "alpham", "alphap"]
#colors = ["black", "C0","C1","C2","C3"]
#labels    = ["CV","ccalm", "ccalp","alpham","alphap"]

'''
syst_keys = ["SystVarsCV","wiremod_YZ","wiremod_XZ_thetaXW", "0xSCE","2xSCE","PMTGainFluct", "PMTHighNoise", "PMTLowEff", "ccalm", "ccalp", "alpham", "alphap", "rm", "rp", "betam", "betap"]
colors = ["black", "C0","C1","C2","C3","C4","C5","C6","C7","C8","C9","C10","C11","C12","C13","C14","C15","C16"]
labels    = ["CV", r"Wiremod Y-Z",r"Wiremod X$\theta_{xw}$", "0xSCE", "2xSCE","PMTGainFluct", "PMTHighNoise", "PMTLowEff", "ccalm", "ccalp", "alpham", "alphap", "rm", "rp", "betam", "betap"]

syst_keys = ["SystVarsCV", "ccalp", "alphap"]
colors = ["black", "C0","C1","C2","C3", "C4","C5","C6","C7","C8","C9"]
labels    = ["CV", "ccalp","alphap"]

syst_keys = ["SystVarsCV","wiremod_YZ","wiremod_XZ_thetaXW", "0xSCE","2xSCE","PMTGainFluct", "PMTHighNoise", "PMTLowEff", "ccalm", "ccalp", "alpham", "alphap"]
colors = ["black", "C0","C1","C2","C3","C4","C5","C6"]
labels    = ["CV", r"Wiremod Y-Z",r"Wiremod X$\theta_{xw}$", "0xSCE", "2xSCE","PMTGainFluct", "PMTHighNoise", "PMTLowEff"]
'''
             
detvar_plotter = partial(
    variation_hists,
    var_colors=colors,
    var_labels=labels,
    approval="internal"
)

detvar_plotter_final_vars = partial(
    variation_hists_final_vars,
    var_colors=colors,
    var_labels=labels,
    approval="internal"
)

keys2load = ["cc1pi", "hdr", "histpotdf", "nudf"] ## keys from the configuration file
syst_evt_dfs = {}
syst_maks = {}
for key in syst_keys:
    syst_df = load_df(f"/exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_{key}.df",keys2load,1)
        
    syst_tot_pot = syst_df['hdr']['pot'].sum()
    print("syst_pot: %.3e" %(syst_tot_pot))
    syst_pot_scale = data_tot_pot / syst_tot_pot
    
    syst_df['cc1pi'][pot_weight_col] = syst_pot_scale * np.ones(len(syst_df['cc1pi']))    
    syst_evt_dfs[key] = syst_df['cc1pi']
    syst_maks[key] = build_event_cumulative_masks(syst_evt_dfs[key] , sideband = "")
    
    syst_evt_dfs[key] = (
        syst_evt_dfs[key]
        .groupby(['__ntuple', 'entry', 'rec.slc..index'])
        .first()
    )   
    cols_to_keep = [
    ('nu_categ', '', '', ''),
    ('nu_categ_proton_reduced', '', '', ''),
    ('genie_categ', '', '', ''),
    ('genie_mode', '', '', ''),
    ]
    syst_evt_dfs[key] = perform_truth_matching(syst_evt_dfs[key], syst_df['nudf'][cols_to_keep])
# Out:
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_data_rollingdev_bnblight.df
# Keys: ['/cc1pi_0', '/hdr_0', '/histgenevtdf_0', '/histpotdf_0', '/pot_0', '/split']
# n_split: 1
# dataframes
# loaded!
# duplication for /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_data_rollingdev_bnblight.df
# Empty DataFrame
# Columns: [__ntuple, entry, run, subrun, evt]
# Index: []
# data_tot_pot: 5.931e+18
# data tot gates : 1.247e+06
# keys in /exp/sbnd/data/users/lpelegri/cafpyana_data/cc1pi_SystVarsCV.df
# Keys: ['/cc1pi_0', '/cc1pi_1', '/cc1pi_2', '/cc1pi_3', '/cc1pi_4', '/cc1pi_5', '/cc1pi_6', '/cc1pi_7', '/cc1pi_8', '/hdr_0', '/hdr_1', '/hdr_2', '/hdr_3', '/hdr_4', '/hdr_5', '/hdr_6', '/hdr_7', '/hdr_8', '/histgenevtdf_0', '/histgenevtdf_1', '/histgenevtdf_2', '/histgenevtdf_3', '/histgenevtdf_4', '/histgenevtdf_5', '/histgenevtdf_6', '/histgenevtdf_7', '/histgenevtdf_8', '/histpotdf_0', '/histpotdf_1', '/histpotdf_2', '/histpotdf_3', '/histpotdf_4', '/histpotdf_5', '/histpotdf_6', '/histpotdf_7', '/histpotdf_8', '/nudf_0', '/nudf_1', '/nudf_2', '/nudf_3', '/nudf_4', '/nudf_5', '/nudf_6', '/nudf_7', '/nudf_8', '/split']
# n_split: 9
# dataframes
# KeyboardInterrupt

# %% [markdown]
# # Check t0 distributions

# %%
#CV_evt_df = CV_evt_df[CV_masks["obvious_cosmic"] & CV_masks["inside_FV"]]
for key in syst_evt_dfs:
    mask = syst_maks[key]["cosmic"] & syst_maks[key]["FV"]
    syst_evt_dfs[key] = syst_evt_dfs[key][mask]

# %%
  
def variation_hists(evtdfs=None, 
                    datadf=None,
                    config=None,
                    var_colors=None, var_labels=None,
                    vline=None,
                    textloc=[0.05, 0.55],
                    approval="internal",
                    plot=True,
                    save_fig=False, save_name=None,
                    data_tot_pot=None): 

    if config is None:
        raise ValueError("A config object must be provided")

    # === extract from config ===
    var_name = config.var_evt_reco_col
    bins = config.bins
    slice_levels = ['__ntuple', 'entry', 'rec.slc..index']
    
    pot_str = get_pot_str(data_tot_pot)
    pot_label = f"{config.ylabel} (POT={pot_str})"
    plot_labels = [config.xlabel, pot_label, ""]

    bin_centers = 0.5 * (bins[:-1] + bins[1:])

    if evtdfs is not None:
        n_vars = len(evtdfs)
    else:
        raise ValueError("evtdfs must be provided")

    # ==== preprocess evtdfs according to first_per_slice ====
    vardfs, wgtdfs = [], []
    nevts_list = []
    mc_stat_err_list = []

    for df in evtdfs:
        mc_df = df.copy()

        # apply first_per_slice grouping if requested
        if getattr(config, "first_per_slice", False) and slice_levels is not None:
            mc_df = mc_df.groupby(level=slice_levels, sort=False).first()

        if(config.clip):
            vardf, wgtdf = get_clipped_evts(mc_df, var_name, bins)
        else:
            vardf, wgtdf = get_evts(mc_df, var_name)

        vardfs.append(vardf)
        wgtdfs.append(wgtdf)

        nevts, _ = np.histogram(vardf, bins=bins, weights=wgtdf)
        total_mc_err2, _ = np.histogram(vardf, bins=bins, weights=wgtdf**2)
        mc_stat_err = np.sqrt(total_mc_err2)
        nevts_list.append(nevts)
        mc_stat_err_list.append(mc_stat_err)

    # ==== preprocess data df if provided ====
    if datadf is not None:
        data_df = datadf.copy()
        if getattr(config, "first_per_slice", False) and slice_levels is not None:
            data_df = data_df.groupby(level=slice_levels, sort=False).first()

        if(config.clip):
            vardf_data, _ = get_clipped_evts(data_df, var_name, bins)
        else:
            vardf_data, _ = get_evts(data_df, var_name)
            
        total_data, _ = np.histogram(vardf_data, bins=bins, weights=data_df.pot_weight)
        data_eylow, data_eyhigh = return_data_stat_err(total_data)

    # ===== plot =====
    fig, axs = plt.subplots(2, 1, figsize=(7.5, 7), 
                            sharex=True, gridspec_kw={'height_ratios': [4, 1]})
    fig.subplots_adjust(hspace=0.05)
    ax = axs[0]
    ax_r = axs[1]

    for sidx in range(n_vars):
        ax.hist(bin_centers,
                weights=nevts_list[sidx],
                bins=bins, 
                histtype="step", 
                color=var_colors[sidx], 
                label=var_labels[sidx])

    if datadf is not None:
        ax.errorbar(bin_centers, 
                    total_data, 
                    yerr=np.vstack((data_eylow, data_eyhigh)),
                    color='black', 
                    fmt='o', markersize=5, capsize=3, linewidth=1.5,
                    label='Data')

    ax.set_ylabel(plot_labels[1])
    ax.set_title(plot_labels[2])
    ax.set_xlim(bins[0], bins[-1])
    ax.legend(loc="best")

    # ==== var/CV ratio panel ====
    for sidx in range(n_vars):
        if sidx == 0:
            continue
        ratio = np.full_like(nevts_list[0], np.nan, dtype=float)
        nonzero_mask = nevts_list[0] != 0
        ratio[nonzero_mask] = nevts_list[sidx][nonzero_mask] / nevts_list[0][nonzero_mask]

        valid_mask = (~np.isnan(ratio)) & (ratio != 0)
        ax_r.hist(bin_centers[valid_mask], bins=bins, weights=ratio[valid_mask],
                  linewidth=1, histtype="step", color=var_colors[sidx])

    ax_r.axhline(1.0, color='black', linestyle='--', linewidth=1)
    ax_r.set_xlim(bins[0], bins[-1])
    ax_r.set_ylim(0.5, 1.5)
    ax_r.set_xlabel(plot_labels[0])
    ax_r.set_ylabel("Variation / CV")
    ax_r.grid(True)
    ax_r.minorticks_on()
    ax_r.grid(which='minor', linestyle=':', linewidth=0.5, color='gray', alpha=0.5)

    # ==== vertical lines if requested ====
    if vline is not None:
        for v in vline:
            ymax = ax.get_ylim()[1]
            ax.vlines(x=v, ymin=0, ymax=ymax, color='red', linestyle='--')

    # approval text
    textloc_x, textloc_ha = get_textloc_x(nevts_list[0], bins, textloc)
    textloc_y = textloc[1]
    add_approval_text(approval, textloc_x, textloc_y, textloc_ha)

    if save_fig:
        plt.savefig(save_name+fig_ext, bbox_inches='tight', dpi=dpi)

    if plot:
        plt.show()
    else:
        plt.close()

    return nevts_list

detvar_plotter = partial(
    variation_hists,
    var_colors=colors,
    var_labels=labels,
    approval="internal"
)

# %%
evtdfs = [syst_evt_dfs[syst_key] for syst_key in syst_keys]
save_name = save_fig_dir + "/{}.png".format(config_bc_flash_score.file_name)
bc_flash_matcher_th = CTE.min_bc_score
n = detvar_plotter(evtdfs, 
                   config=config_bc_flash_score, 
                   vline=[bc_flash_matcher_th],
                   save_fig=save_fig, save_name=save_name,
                   data_tot_pot = data_tot_pot)
del evtdfs
gc.collect()

# %% [markdown]
# # Check nu score

# %%
for key, df in syst_evt_dfs.items():
    mask = syst_maks[key]["t0"].reindex(df.index, fill_value=False)
    syst_evt_dfs[key] = df[mask]

# %%
evtdfs = [syst_evt_dfs[syst_key] for syst_key in syst_evt_dfs]
save_name = save_fig_dir + "/{}.png".format(config_bc_flash_score.file_name)
bc_flash_matcher_th = CTE.min_bc_score
n = detvar_plotter(evtdfs, 
                   config=config_bc_flash_score, 
                   vline=[bc_flash_matcher_th],
                   save_fig=save_fig, save_name=save_name,
                   data_tot_pot = data_tot_pot)
del evtdfs
gc.collect()

# %%
evtdfs = [syst_evt_dfs[syst_key] for syst_key in syst_evt_dfs]
save_name = save_fig_dir + "/{}.png".format(config_nu_score.file_name)
nu_score_th = CTE.min_nu_score
n = detvar_plotter(evtdfs, 
                   config=config_nu_score, 
                   vline=[nu_score_th],
                   save_fig=save_fig, save_name=save_name,
                   data_tot_pot = data_tot_pot)
del evtdfs
gc.collect()

# %% [markdown]
# # n tracks

# %%
for key, df in syst_evt_dfs.items():
    mask = syst_maks[key]["nu_score"].reindex(df.index, fill_value=False)
    syst_evt_dfs[key] = df[mask]

# %%
def plot_configs(configs, syst_evt_dfs):
    for config in configs:
    
        this_syst_evt_dfs = {}
        for key, df in syst_evt_dfs.items():
            this_syst_evt_dfs[key] = df[mask_dict[config.extra_mask](df)].copy()
        this_evtdfs = [this_syst_evt_dfs[syst_key] for syst_key in this_syst_evt_dfs]
        
        save_name = save_fig_dir + "/{}.png".format(config.file_name)
        n = detvar_plotter(this_evtdfs, 
                       config=config, 
                       vline=[100000000],
                       save_fig=save_fig, save_name=save_name,
                       data_tot_pot = data_tot_pot)
        del this_syst_evt_dfs
        del this_evtdfs
        gc.collect()

# %%
configs = [config_pandora_primary_vtx_distance, config_analysis_primary_len, config_analysis_primary_track_score, config_n_prim_tracks]
plot_configs(configs, syst_evt_dfs)

# %% [markdown]
# # chi2 vars

# %% [markdown]
# # All

# %%
for key, df in syst_evt_dfs.items():
    mask = syst_maks[key]["track"].reindex(df.index, fill_value=False)
    syst_evt_dfs[key] = df[mask]

# %%
configs = [config_primary_track_chi2_mu, config_primary_track_chi2_p, config_primary_track_len]
plot_configs(configs, syst_evt_dfs)

# %% [markdown]
# # Candidates

# %%
configs = [config_n_MIP_candidates, config_MIP_candidate_chi2_mu, config_MIP_candidate_chi2_p]
plot_configs(configs, syst_evt_dfs)

# %%
configs = [config_exiting_MIP_candidate_chi2_mu, config_exiting_MIP_candidate_chi2_p]
plot_configs(configs, syst_evt_dfs)

# %%
configs = [config_contained_MIP_candidate_chi2_mu, config_contained_MIP_candidate_chi2_p]
plot_configs(configs, syst_evt_dfs)

# %% [markdown]
# # After Cut

# %%
for key, df in syst_evt_dfs.items():
    mask = syst_maks[key]["chi2"].reindex(df.index, fill_value=False)
    syst_evt_dfs[key] = df[mask]

# %% [markdown]
# # Candidates

# %%
configs = [config_n_MIP_candidates, config_MIP_candidate_chi2_mu, config_MIP_candidate_chi2_p]
plot_configs(configs, syst_evt_dfs)

# %% [markdown]
# # Angle

# %%
for key, df in syst_evt_dfs.items():
    mask = syst_maks[key]["shower"].reindex(df.index, fill_value=False) 
    syst_evt_dfs[key] = df[mask]

# %%
configs = [config_angle_between_candidates]
plot_configs(configs, syst_evt_dfs)

# %% [markdown]
# # Proton BDT

# %%
for key, df in syst_evt_dfs.items():
    mask = syst_maks[key]["angle"].reindex(df.index, fill_value=False) 
    syst_evt_dfs[key] = df[mask]

# %%
configs = [config_MIP_candidate_chi2_mu, config_MIP_candidate_chi2_p, config_MIP_candidate_frac50, config_MIP_candidate_chi2_exp_pol, config_MIP_candidate_bdt_score_proton, config_n_MIP_candidates_proton]
plot_configs(configs, syst_evt_dfs)

# %% [markdown]
# # After cut

# %%
for key, df in syst_evt_dfs.items():
    mask = syst_maks[key]["proton_BDT"].reindex(df.index, fill_value=False) 
    syst_evt_dfs[key] = df[mask]

# %%
configs = [config_MIP_candidate_chi2_mu, config_MIP_candidate_chi2_p, config_MIP_candidate_frac50, config_MIP_candidate_chi2_exp_pol, config_MIP_candidate_bdt_score_proton, config_n_MIP_candidates_proton]
plot_configs(configs, syst_evt_dfs)

# %% [markdown]
# # Containment

# %%
configs = [config_n_exiting_pfps, config_n_exiting_z_pfps]
plot_configs(configs, syst_evt_dfs)

# %% [markdown]
# # Michel

# %%
for key, df in syst_evt_dfs.items():
    mask = syst_maks[key]["containment"].reindex(df.index, fill_value=False) 
    syst_evt_dfs[key] = df[mask]

# %%
configs = [config_MIP_candidate_chi2_mu, config_MIP_candidate_chi2_p, config_MIP_candidate_frac50, config_MIP_candidate_chi2_exp_pol, config_MIP_candidate_bdt_score_proton, config_n_MIP_candidates_proton]
plot_configs(configs, syst_evt_dfs)

# %%
for key, df in syst_evt_dfs.items():
    mask = syst_maks[key]["TPC_containment"].reindex(df.index, fill_value=False) 
    syst_evt_dfs[key] = df[mask]

# %%
configs = [config_MIP_candidate_chi2_mu, config_MIP_candidate_chi2_p, config_MIP_candidate_frac50, config_MIP_candidate_chi2_exp_pol, config_MIP_candidate_bdt_score_proton, config_n_MIP_candidates_proton]
plot_configs(configs, syst_evt_dfs)

# %%
configs = [config_n_exiting_pfps, config_n_exiting_z_pfps]
plot_configs(configs, syst_evt_dfs)

# %%
configs = [config_MIP_candidate_max_daughter_hits, config_contained_MIP_candidate_KE, config_contained_MIP_candidate_track_score, config_n_MIP_candidate_michel]
plot_configs(configs, syst_evt_dfs)

# %% [markdown]
# # Extra pion

# %%
for key, df in syst_evt_dfs.items():
    mask = syst_maks[key]["michel"].reindex(df.index, fill_value=False) 
    syst_evt_dfs[key] = df[mask]

# %%
configs = [config_n_extra_pions]
plot_configs(configs, syst_evt_dfs)

# %% [markdown]
# # Final Vars

# %%
for key, df in syst_evt_dfs.items():
    mask = syst_maks[key]["extra_pion"].reindex(df.index, fill_value=False) &syst_maks[key]["energy"].reindex(df.index, fill_value=False)
    syst_evt_dfs[key] = df[mask]

# %%
configs = [config_MIP_candidate_chi2_mu, config_MIP_candidate_chi2_p, config_MIP_candidate_chi2_exp_pol, config_MIP_candidate_max_daughter_hits, config_MIP_candidate_scatter_angle, config_MIP_candidate_bdt_score_muon_pion]
plot_configs(configs, syst_evt_dfs)

# %%
configs = measure_var_vec + TKI_vec
plot_configs(configs, syst_evt_dfs)

# %% [markdown]
# # Get all the syst uncert

# %%
var_config = VariableConfig.all_evts()

# %%
slice_levels = ['__ntuple', 'entry', 'rec.slc..index']
evtdfs = [syst_evt_dfs[syst_key].groupby(level=slice_levels, sort=False).first() for syst_key in syst_evt_dfs.keys()]

var_name = var_config.var_evt_reco_col
bins = var_config.bins
pot_label = f"Candidate Slices (POT={pot_str})"
plot_labels = [var_config.var_labels[1], pot_label, ""]
approval = "internal"
save_name = save_fig_dir + "/{}.png".format(var_config.var_save_name)
n = detvar_plotter_final_vars(evtdfs, 
                    var_name=var_name,
                    bins=bins,
                    plot_labels=plot_labels,
                    approval=approval,
                    vline=[],
                    save_fig=save_fig, save_name=save_name)

# %%
ret_dict = {}
for kidx, syst_key in enumerate(syst_evt_dfs.keys()):
    if syst_key == "SystVarsCV":
        continue

    # take syst variation as a unisim uncertainty
    cv_events = n[0]
    univ_events = np.array([n[kidx]]) 
    ret = get_covariance_matrix(univ_events, cv_events)
    ret_dict[syst_key] = ret
    plot_univ_hists(univ_events, 
                    cv_events,
                    syst_key, 
                    var_config,
                    use_bin_width = False,
                    )

    matrix_type = "cov_frac"
    plot_labels = [var_config.var_labels[2], var_config.var_labels[1], ""]
    save_fig_name = "{}/{}-{}-{}.pdf".format(save_fig_dir, var_config.var_save_name, syst_key, matrix_type)
    title = "{} {}".format(syst_key, matrix_type)
    plot_heatmap(ret[matrix_type], 
                 bins=bins,
                 plot_labels=plot_labels,
                 save_fig=save_fig, 
                 save_name=save_fig_name)

    frac_unc = np.sqrt(np.diag(ret["cov_frac"]))
    plot_frac_unc([(frac_unc, syst_key)], var_config)

# %%
# get total detector variation covariance matrix
for kidx, syst_key in enumerate(ret_dict.keys()):
    if kidx == 0:
        detvar_total_cov = ret_dict[syst_key]["cov_frac"]
    else:
        detvar_total_cov += ret_dict[syst_key]["cov_frac"]

frac_unc = np.sqrt(np.diag(detvar_total_cov))
plot_frac_unc([(frac_unc, "total")], var_config)

# %%
file_dir = "/exp/sbnd/data/users/lpelegri/syst/frac_cov_matrices"
if 'syst_dict' not in locals():
    syst_dict = {}
os.makedirs(file_dir, exist_ok=True)  # create directory if needed

var_configs = [
    VariableConfig.all_evts(), 
    VariableConfig.muon_momentum(),
    VariableConfig.muon_direction(),
    VariableConfig.pion_momentum(),
    VariableConfig.pion_direction(),
    VariableConfig.angle_between_candidates(),
    VariableConfig.num_protons(),
    VariableConfig.delta_pt(),
    VariableConfig.delta_alpha_T(),
    VariableConfig.delta_phi_T()
]
syst_name = "detvar"

unisim_keys = []
paired_syst = {} # e.g., {"ccal": ["ccalm", "ccalp"]}

for key in syst_keys:
    if key == "SystVarsCV": continue
    
    # Check if it's a plus/minus variation
    if key.endswith('m') or key.endswith('p'):
    #if False:
        base = key[:-1] # strip the 'm' or 'p'
        if base not in paired_syst:
            paired_syst[base] = [None, None]
        
        if key.endswith('m'): paired_syst[base][0] = key
        else: paired_syst[base][1] = key
    else:
        unisim_keys.append(key)

print(unisim_keys)
print(paired_syst)

for var_config in var_configs:
    evtdfs = [syst_evt_dfs[syst_key].groupby(level=slice_levels, sort=False).first() for syst_key in syst_evt_dfs.keys()]
    var_name = var_config.var_evt_reco_col
    bins = var_config.bins
    pot_label = f"Candidate Slices (POT={pot_str})"
    plot_labels = [var_config.var_labels[1], pot_label, ""]
    approval = "internal"
    save_name = save_fig_dir + "/{}.png".format(var_config.var_save_name)
    n = detvar_plotter_final_vars(evtdfs, 
                        var_name=var_name,
                        bins=bins,
                        plot_labels=plot_labels,
                        approval=approval,
                        plot = True
                    )

    key_to_idx = {key: i for i, key in enumerate(syst_evt_dfs.keys())}
    cv_events = n[0]
    ret_dict = {}

    for syst_key in unisim_keys:
        kidx = key_to_idx[syst_key]
        univ_events = np.array([n[kidx]]) 
        ret = get_covariance_matrix(univ_events, cv_events)
        ret_dict[syst_key] = ret

        plot_univ_hists(univ_events, 
                        cv_events,
                        syst_name, 
                        var_config,
                        use_bin_width = False,
                )

    for base_name, keys in paired_syst.items():
        m_idx = key_to_idx.get(keys[0])
        p_idx = key_to_idx.get(keys[1])
        
        # Construct univ_events from the pair
        # We assume [variation_minus, variation_plus]
        univ_events = np.array([n[m_idx], n[p_idx]])
        print(
            univ_events
        )
        
        # get_covariance_matrix calculates the spread across these universes
        ret = get_covariance_matrix(univ_events, cv_events)
        ret_dict[base_name] = ret
        
        # For plotting paired histograms, you might need to adapt plot_univ_hists
        # to handle two universes at once.
        plot_univ_hists(univ_events, cv_events, base_name, var_config)

    # 3. Total Detector Variation Calculation
    detvar_total_cov = None
    uncertanties_list = []
    
    for syst_key, ret in ret_dict.items():
        frac_unc = np.sqrt(np.diag(ret["cov_frac"]))
        uncertanties_list.append((frac_unc, syst_key))
        
        if detvar_total_cov is None:
            detvar_total_cov = ret["cov_frac"].copy()
        else:
            detvar_total_cov += ret["cov_frac"]

    # Final Summary Plotting
    total_frac_unc = np.sqrt(np.diag(detvar_total_cov))
    uncertanties_list.append((total_frac_unc, "total"))
    plot_frac_unc(uncertanties_list, var_config)
    
    syst_dict[var_config.var_save_name] = detvar_total_cov
    for key, ret in ret_dict.items():
        syst_dict[f"{var_config.var_save_name}_{key}"] = ret["cov_frac"]
    
# save syst_dict as an npz file in the directory where dfs were loaded from
if save_result:
    print("saving syst_dict as npz in %s" % (file_dir))
    #np.savez(file_dir + "/detvar_syst_dict.npz", **syst_dict)
